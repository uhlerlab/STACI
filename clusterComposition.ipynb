# %%
import sys
sys.path.append('/home/xinyiz/pamrats')

import time
import os

import scanpy
import numpy as np
import scipy.sparse as sp

import torch
from torch import optim

# from sklearn.metrics import roc_auc_score
# from sklearn.metrics import average_precision_score

import gae.gae.optimizer as optimizer
import gae.gae.model
import gae.gae.preprocessing as preprocessing

import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import umap
import pandas as pd
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import DBSCAN,MiniBatchKMeans,AgglomerativeClustering
from sklearn import metrics
from sklearn.linear_model import LogisticRegression

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "1" 
ifplot=True
ifcluster=True

logitL1=0.5 #smaller is sparser
geneThresh=2.5 #times std above mean

inverseAct='leakyRelu'
# inverseAct=None
plottype='umap'
pca=PCA()
minCells=15 #min number of cells for analysis
minCell_clusterDE=5
# clustermethod=['kmeanbatch']
clustermethod=['leiden','agglomerative','kmeanbatch']
#umap/leiden clustering parameters
n_neighbors=10
min_dist=0.25
n_pcs=40 #for clustering
# resolution=[0.5,1,1.5,2]
resolution=[0.05,0.1,0.2,0.3]
plotepoch=9990
savenameAdd=''
#DBscan
epslist= [6,8,10]
min_sampleslist=[15,30,45] 
#agglomerative
nclusterlist=[2,3,4,5,8,10]
aggMetric=['euclidean']


combineCelltype={'glia':['Astro','Micro', 'OPC', 'Oligo'],'CA':['CA1', 'CA2', 'CA3']}

use_cuda=True
fastmode=False #Validate during training pass
seed=3
useSavedMaskedEdges=False
maskedgeName='knn20_connectivity'
hidden1=1024 #Number of units in hidden layer 1
hidden2=1024 #Number of units in hidden layer 2
# hidden3=16
fc_dim1=1024
# fc_dim2=2112
# fc_dim3=2112
# fc_dim4=2112
# gcn_dim1=2048

protein=None #'scaled_binary'
# proteinWeights=0.05
dropout=0.01
# randFeatureSubset=None
model_str='gcn_vae_xa_e2_d1_dca'
adj_decodeName=None #gala or None
plot_samples={'disease13':'AD_mouse9494','control13':'AD_mouse9498','disease8':'AD_mouse9723','control8':'AD_mouse9735'}
plot_sample_X=['logminmax']
plotRecon='' #'meanRecon'
# plot_sample_X=['corrected','scaled']
standardizeX=False
name='allk20XA_01_dca'
logsavepath='/mnt/xinyi/pamrats/log/train_gae_starmap/'+name
modelsavepath='/mnt/xinyi/pamrats/models/train_gae_starmap/'+name
plotsavepath='/mnt/xinyi/pamrats/plots/train_gae_starmap/'+name

# %%
# Set cuda and seed
np.random.seed(seed)
if use_cuda and (not torch.cuda.is_available()):
    print('cuda not available')
    use_cuda=False
torch.manual_seed(seed)
if use_cuda:
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.enabled = True

# %%
#Load data
savedir=os.path.join('/mnt/xinyi/','starmap')
adj_dir=os.path.join(savedir,'a')

featureslist={}
if plot_sample_X[0] in ['corrected','scaled']:
    scaleddata=scanpy.read_h5ad('/mnt/xinyi/2021-01-13-mAD-test-dataset/2020-12-27-starmap-mAD-scaled.h5ad')
    
    for s in plot_samples.keys():
        featureslist[s+'X_'+'corrected']=torch.tensor(scaleddata.layers['corrected'][scaleddata.obs['sample']==plot_samples[s]])
        featureslist[s+'X_'+'scaled']=torch.tensor(scaleddata.layers['scaled'][scaleddata.obs['sample']==plot_samples[s]])
    
else:
    scaleddata=scanpy.read_h5ad('/mnt/xinyi/2021-01-13-mAD-test-dataset/2020-12-27-starmap-mAD-raw.h5ad')
    
    for s in plot_samples.keys():
        scaleddata_train=scaleddata.X[scaleddata.obs['sample']==plot_samples[s]]

        if plot_sample_X[0]=='logminmax':
            featurelog_train=np.log2(scaleddata_train+1/2)
            scaler = MinMaxScaler()
            featurelog_train_minmax=np.transpose(scaler.fit_transform(np.transpose(featurelog_train)))
            featureslist[s+'X_'+plot_sample_X[0]]=torch.tensor(featurelog_train_minmax)

# %%
def plotCTcomp(labels,ctlist,savepath,savenamecluster):
    res=np.zeros((np.unique(labels).size,np.unique(ctlist).size))
    for li in range(res.shape[0]):
        l=np.unique(labels)[li]
        nl=np.sum(labels==l)
        ctlist_l=ctlist[labels==l]
        for ci in range(res.shape[1]):
            c=np.unique(ctlist)[ci]
            res[li,ci]=np.sum(ctlist_l==c)/nl
    
    fig, ax = plt.subplots(figsize=(10, 10))
    im = ax.imshow(res,cmap='binary')
    ax.set_yticks(np.arange(np.unique(labels).size))
    ax.set_yticklabels(np.unique(labels))
    ax.set_xticks(np.arange(np.unique(ctlist).size))
    ax.set_xticklabels(np.unique(ctlist))
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",rotation_mode="anchor")
    fig.tight_layout()
    plt.savefig(os.path.join(savepath,savenamecluster+'_ctComposition.jpg'))
    plt.close()
        
        

def compLeiden(ctlist,n_neighbors,n_pcs,min_dist,resolution):
    for r in resolution:
        savenamecluster='leiden_nn'+str(n_neighbors)+'mdist0'+str(int(min_dist*100))+'n_pcs'+str(n_pcs)+'res'+str(r)+'epoch'+str(plotepoch)
        readpath=os.path.join(clustersavedir,savenamecluster)
        if not os.path.exists(readpath):
            print('DNE: '+readpath)
            continue
        with open(readpath, 'rb') as input:
            labels = pickle.load(input)
        labels=np.array(labels)
        if np.unique(labels).shape[0]==1:
            continue
        
        savepath=clustersavedir
        plotCTcomp(labels,ctlist,savepath,savenamecluster)

def compDBscan(ctlist,epsL,min_samplesL,n_pcs):
    for eps in epsL:
        for min_samples in min_samplesL:
            savenamecluster='dbscan_eps'+str(eps)+'msamples'+str(min_samples)+'n_pcs'+str(n_pcs)+'epoch'+str(plotepoch)
            readpath=os.path.join(clustersavedir,savenamecluster)
            if not os.path.exists(readpath):
                print('DNE: '+readpath)
                continue
            with open(readpath, 'rb') as input:
                labels = pickle.load(input)
            labels=np.array(labels)
            if np.unique(labels).shape[0]==1:
                continue
            
            savepath=clustersavedir
            plotCTcomp(labels,ctlist,savepath,savenamecluster)
                
def compAgg(ctlist,nclusterL,aggmetricL,n_pcs):
    for ncluster in nclusterL:
        for aggmetric in aggmetricL:
            savenamecluster='agg_ncluster'+str(ncluster)+aggmetric+'n_pcs'+str(n_pcs)+'epoch'+str(plotepoch)
            readpath=os.path.join(clustersavedir,savenamecluster)
            if not os.path.exists(readpath):
                print('DNE: '+readpath)
                continue
            with open(readpath, 'rb') as input:
                labels = pickle.load(input)
            labels=np.array(labels)
            if np.unique(labels).shape[0]==1:
                continue
            savepath=clustersavedir
            plotCTcomp(labels,ctlist,savepath,savenamecluster)
            
def compMinibatchKmean(ctlist,nclusterL,n_pcs):
    for ncluster in nclusterL:
        savenamecluster='minibatchkmean_ncluster'+str(ncluster)+'n_pcs'+str(n_pcs)+'epoch'+str(plotepoch)
        readpath=os.path.join(clustersavedir,savenamecluster)
        if not os.path.exists(readpath):
            print('DNE: '+readpath)
            continue
        with open(readpath, 'rb') as input:
            labels = pickle.load(input)
        labels=np.array(labels)
        if np.unique(labels).shape[0]==1:
            continue
            
        savepath=clustersavedir
        plotCTcomp(labels,ctlist,savepath,savenamecluster)

# %%
#all cells
for s in plot_samples.keys():
    sampleidx=plot_samples[s]
    
    celltype_broad=scaleddata.obs.loc[scaleddata.obs['sample']==sampleidx,'top_level']
    celltype_sub=scaleddata.obs.loc[scaleddata.obs['sample']==sampleidx,'cell_type_label']
    region=scaleddata.obs.loc[scaleddata.obs['sample']==sampleidx,'region']
#     sobj_coord_np=scaleddata.obs.loc[scaleddata.obs['sample']==sampleidx,['x','y']].to_numpy()
    for xcorr in plot_sample_X:
        samplename=s+'X_'+xcorr
        
        if inverseAct:
            samplename+='_beforeAct'
       
        sampledir=os.path.join(plotsavepath,samplename)
        clustersavedir=os.path.join(plotsavepath,samplename,'cluster')

        if 'leiden' in clustermethod:
            compLeiden(celltype_broad,n_neighbors,n_pcs,min_dist,resolution)
        if 'dbscan' in clustermethod:
            compDBscan(celltype_broad,epslist,min_sampleslist,n_pcs)
        if 'agglomerative' in clustermethod:
            compAgg(celltype_broad,nclusterlist,aggMetric,n_pcs)
        if 'kmeanbatch' in clustermethod:
            compMinibatchKmean(celltype_broad,nclusterlist,n_pcs)

# %%
# separate plots by region and cell types
for s in plot_samples.keys():
    print(s)
    sampleidx=plot_samples[s]
    celltype_broad=scaleddata.obs.loc[scaleddata.obs['sample']==sampleidx,'top_level']
    celltype_sub=scaleddata.obs.loc[scaleddata.obs['sample']==sampleidx,'cell_type_label']
    region=scaleddata.obs.loc[scaleddata.obs['sample']==sampleidx,'region']
#     sobj_coord_np=scaleddata.obs.loc[scaleddata.obs['sample']==sampleidx,['x','y']].to_numpy()
    
    origCT=np.unique(celltype_broad)
    celltypeplot=np.concatenate((origCT,list(combineCelltype.keys())),axis=None)
    for xcorr in plot_sample_X:
        samplename=s+'X_'+xcorr
        featureDE=np.copy(featureslist[samplename])

        if inverseAct:
            samplename+='_beforeAct'
        sampledir=os.path.join(plotsavepath,samplename)
        if not os.path.exists(sampledir):
            os.mkdir(sampledir)
            
        for r in np.unique(region):
            print(r)
            ridx=scaleddata.obs.loc[scaleddata.obs['sample']==sampleidx,'region']==r
            for reg in celltypeplot:
                print(reg)
                clustersavedir=os.path.join(plotsavepath,samplename,'cluster'+'_'+reg,r)

                if reg in origCT:
                    ct_idx=celltype_broad==reg
                else:
                    ct_idx=False
                    for i in combineCelltype[reg]:
                        ct_idx=np.logical_or(ct_idx,celltype_broad==i)
                
                reg_idx=np.logical_and(ridx,ct_idx)
                
                if np.unique(celltype_sub[reg_idx]).size==1:
                    continue
                
                if 'leiden' in clustermethod:
                    compLeiden(celltype_sub[reg_idx],n_neighbors,n_pcs,min_dist,resolution)
                if 'dbscan' in clustermethod:
                    compDBscan(celltype_sub[reg_idx],epslist,min_sampleslist,n_pcs)
                if 'agglomerative' in clustermethod:
                    compAgg(celltype_sub[reg_idx],nclusterlist,aggMetric,n_pcs)
                if 'kmeanbatch' in clustermethod:
                    compMinibatchKmean(celltype_sub[reg_idx],nclusterlist,n_pcs)
# Out:
# disease13
# Cortex
# Astro
# CA1
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/Cortex/minibatchkmean_ncluster10n_pcs40epoch9990
# CA2
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/Cortex/minibatchkmean_ncluster10n_pcs40epoch9990
# CA3
# DG
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_DG/Cortex/minibatchkmean_ncluster10n_pcs40epoch9990
# Endo
# Ex
# Inhi
# LHb
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/Cortex/minibatchkmean_ncluster10n_pcs40epoch9990
# Micro
# OPC
# Oligo
# SMC
# glia
# CA
# Hippocampus
# Astro
# CA1
# CA2
# CA3
# DG
# Endo
# Ex
# Inhi
# LHb
# Micro
# OPC
# Oligo
# SMC
# glia
# CA
# White Matter
# Astro
# CA1
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA1/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# CA2
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# CA3
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# DG
# Endo
# Ex
# Inhi
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_Inhi/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# LHb
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_LHb/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# Micro
# OPC
# Oligo
# SMC
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_SMC/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# glia
# CA
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/disease13X_logminmax_beforeAct/cluster_CA/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# control13
# Cortex
# Astro
# CA1
# CA2
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/Cortex/minibatchkmean_ncluster10n_pcs40epoch9990
# CA3
# DG
# Endo
# Ex
# Inhi
# LHb
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_LHb/Cortex/minibatchkmean_ncluster10n_pcs40epoch9990
# Micro
# OPC
# Oligo
# SMC
# glia
# CA
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA/Cortex/minibatchkmean_ncluster10n_pcs40epoch9990
# Hippocampus
# Astro
# CA1
# CA2
# CA3
# DG
# Endo
# Ex
# Inhi
# LHb
# Micro
# OPC
# Oligo
# SMC
# glia
# CA
# White Matter
# Astro
# CA1
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA1/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# CA2
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# CA3
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# DG
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_DG/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# Endo
# Ex
# Inhi
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_Inhi/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_Inhi/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_Inhi/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_Inhi/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_Inhi/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control13X_logminmax_beforeAct/cluster_Inhi/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# ...
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA1/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA1/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA1/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# CA2
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA2/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# CA3
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA3/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# DG
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_DG/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# Endo
# Ex
# Inhi
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_Inhi/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# LHb
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_LHb/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
# Micro
# OPC
# Oligo
# SMC
# glia
# CA
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/leiden_nn10mdist025n_pcs40res0.05epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/leiden_nn10mdist025n_pcs40res0.1epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/leiden_nn10mdist025n_pcs40res0.2epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/leiden_nn10mdist025n_pcs40res0.3epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/agg_ncluster2euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/agg_ncluster3euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/agg_ncluster4euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/agg_ncluster5euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/agg_ncluster8euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/agg_ncluster10euclideann_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/minibatchkmean_ncluster2n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/minibatchkmean_ncluster3n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/minibatchkmean_ncluster4n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/minibatchkmean_ncluster5n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/minibatchkmean_ncluster8n_pcs40epoch9990
# DNE: /mnt/xinyi/pamrats/plots/train_gae_starmap/allk20XA_01_dca/control8X_logminmax_beforeAct/cluster_CA/White Matter/minibatchkmean_ncluster10n_pcs40epoch9990
