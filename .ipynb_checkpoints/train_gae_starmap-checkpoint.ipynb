# %%
import sys
sys.path.append('/home/xinyiz/pamrats')

# %%
##This is adapted from https://github.com/tkipf/gae/blob/master/gae/train.py and https://github.com/tkipf/pygcn/blob/master/pygcn/train.py##

import time
import os

# Train on CPU (hide GPU) due to memory constraints
# os.environ['CUDA_VISIBLE_DEVICES'] = ""

import scanpy
import numpy as np
import scipy.sparse as sp

import torch
from torch import optim

# from sklearn.metrics import roc_auc_score
# from sklearn.metrics import average_precision_score

import gae.gae.optimizer as optimizer
import gae.gae.model
import gae.gae.preprocessing as preprocessing

import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import umap
import pandas as pd
from sklearn.preprocessing import scale
from sklearn.preprocessing import MinMaxScaler

# %%
# Settings
use_cuda=True
fastmode=False #Validate during training pass
seed=3
useSavedMaskedEdges=False
maskedgeName='knn20_connectivity'
epochs=5000
saveFreq=10
lr=0.001 #initial learning rate
weight_decay=0 #Weight for L2 loss on embedding matrix.

hidden1=1024 #Number of units in hidden layer 1
hidden2=1024 #Number of units in hidden layer 2
# hidden3=2048
# hidden4=2048
# hidden5=128
fc_dim1=1024
# fc_dim2=128
# fc_dim3=128
# fc_dim4=128
# gcn_dim1=2600
# clf_hidden=256

dropout=0.01
testNodes=0.1 #fraction of total nodes for testing
valNodes=0.05 #fraction of total nodes for validation
XreconWeight=20
# clfweight=20
# randFeatureSubset=None
model_str='gcn_vae_xa_e2_d1_dca'
clf=None
adj_decodeName=None #gala or None
ridgeL=0.01
shareGenePi=True

training_samples='control13'
training_sample_X='scaled'
standardizeX=False
name='c13k20XA_04_dca'
logsavepath='/mnt/xinyi/pamrats/log/train_gae_starmap/'+name
modelsavepath='/mnt/xinyi/pamrats/models/train_gae_starmap/'+name
plotsavepath='/mnt/xinyi/pamrats/plots/train_gae_starmap/'+name

#Load data
sampleidx={'disease13':'AD_mouse9494','control13':'AD_mouse9498','disease8':'AD_mouse9723','control8':'AD_mouse9735'}
savedir=os.path.join('/mnt/xinyi/','starmap')
adj_dir=os.path.join(savedir,'a')

featureslist={}
if training_sample_X in ['corrected','scaled']:
    scaleddata=scanpy.read_h5ad('/mnt/xinyi/2021-01-13-mAD-test-dataset/2020-12-27-starmap-mAD-scaled.h5ad')
    
    for s in sampleidx.keys():
        featureslist[s+'X_'+'corrected']=torch.tensor(scaleddata.layers['corrected'][scaleddata.obs['sample']==sampleidx[s]])
        featureslist[s+'X_'+'scaled']=torch.tensor(scaleddata.layers['scaled'][scaleddata.obs['sample']==sampleidx[s]])

else:
    scaleddata=scanpy.read_h5ad('/mnt/xinyi/2021-01-13-mAD-test-dataset/2020-12-27-starmap-mAD-raw.h5ad')
    
    for s in sampleidx.keys():
        scaleddata_train=scaleddata.X[scaleddata.obs['sample']==sampleidx[s]]

        if training_sample_X=='logminmax':
            featurelog_train=np.log2(scaleddata_train+1/2)
            scaler = MinMaxScaler()
            featurelog_train_minmax=np.transpose(scaler.fit_transform(np.transpose(featurelog_train)))
            featureslist[s+'X_'+training_sample_X]=torch.tensor(featurelog_train_minmax)
        elif training_sample_X=='logminmax10':
            featurelog_train=np.log2(scaleddata_train+1/2)
            scaler = MinMaxScaler(feature_range=(0,10))
            featurelog_train_minmax=np.transpose(scaler.fit_transform(np.transpose(featurelog_train)))
            featureslist[s+'X_'+training_sample_X]=torch.tensor(featurelog_train_minmax)
        
if clf:
    ctlist={}
    ctlist['disease13']=scaleddata.obs.loc[scaleddata.obs['sample']=='AD_mouse9494','top_level'].to_numpy()
    ctlist['control13']=scaleddata.obs.loc[scaleddata.obs['sample']=='AD_mouse9498','top_level'].to_numpy()
    ctlist['disease8']=scaleddata.obs.loc[scaleddata.obs['sample']=='AD_mouse9723','top_level'].to_numpy()
    ctlist['control8']=scaleddata.obs.loc[scaleddata.obs['sample']=='AD_mouse9735','top_level'].to_numpy()
    ct_unique=np.unique(scaleddata.obs.loc[scaleddata.obs['sample']=='AD_mouse9735','top_level'])
    for k in ctlist.keys():
        for i in range(ct_unique.size):
            ctlist[k][ctlist[k]==ct_unique[i]]=i
    


adj_list={}
adj_list['disease13']=sp.load_npz(os.path.join(adj_dir,maskedgeName+'_AD_mouse9494.npz'))
adj_list['control13']=sp.load_npz(os.path.join(adj_dir,maskedgeName+'_AD_mouse9498.npz'))
adj_list['disease8']=sp.load_npz(os.path.join(adj_dir,maskedgeName+'_AD_mouse9723.npz'))
adj_list['control8']=sp.load_npz(os.path.join(adj_dir,maskedgeName+'_AD_mouse9735.npz'))

adj_train=adj_list[training_samples]
features=featureslist[training_samples+'X_'+training_sample_X]
if 'dca' in model_str:
    rawdata=scanpy.read_h5ad('/mnt/xinyi/2021-01-13-mAD-test-dataset/2020-12-27-starmap-mAD-raw.h5ad')
    features_raw=rawdata.X[rawdata.obs['sample']==sampleidx[training_samples]]
    

if clf:
    ct_train=ctlist[training_samples].astype(int)
# features=torch.tensor(np.identity(7000)).float()
# features=features[0:10,:]
if standardizeX:
    features=torch.tensor(scale(features,axis=0, with_mean=True, with_std=True, copy=True))

# Set cuda and seed
np.random.seed(seed)
if use_cuda and (not torch.cuda.is_available()):
    print('cuda not available')
    use_cuda=False
torch.manual_seed(seed)
if use_cuda:
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.enabled = True

# Load data
# if randFeatureSubset != None:
#     idx=np.random.choice(features.shape[1],randFeatureSubset,replace=False)
#     features=features[:,idx]

# %%
maskpath=os.path.join(savedir,'trainMask',training_samples+'_'+maskedgeName+'_seed'+str(seed)+'.pkl')
if useSavedMaskedEdges and os.path.exists(maskpath):
    print('opening saved')
    with open(maskpath, 'rb') as input:
        maskedgeres = pickle.load(input)
else:
    # construct training, validation, and test sets
    maskedgeres= preprocessing.mask_nodes_edges(features.shape[0],testNodeSize=testNodes,valNodeSize=valNodes)
    with open(maskpath, 'wb') as output:
        pickle.dump(maskedgeres, output, pickle.HIGHEST_PROTOCOL)

# %%
if not os.path.exists(logsavepath):
    os.mkdir(logsavepath)
if not os.path.exists(modelsavepath):
    os.mkdir(modelsavepath)
if not os.path.exists(plotsavepath):
    os.mkdir(plotsavepath)

# %%
# loop over all train/validation sets
train_nodes_idx,val_nodes_idx,test_nodes_idx = maskedgeres

adj_norm = preprocessing.preprocess_graph(adj_train)
adj_label=adj_train + sp.eye(adj_train.shape[0])
adj_label=torch.tensor(adj_label.todense())
adj_decode=None
if adj_decodeName == 'gala':
    adj_decode=preprocessing.preprocess_graph_sharp(adj_train)

num_nodes,num_features = features.shape

mse=torch.nn.MSELoss()
# mse=torch.nn.MSELoss(reduction=None)
# Create model
if model_str=='gcn_vae_xa':
    model = gae.gae.model.GCNModelVAE_XA(num_features, hidden1, hidden2,fc_dim1,fc_dim2,fc_dim3,fc_dim4, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
    loss_a=optimizer.optimizer_CE
elif model_str == 'gcn_vae_gcnX_inprA':
    model = gae.gae.model.GCNModelVAE_gcnX_inprA(num_features, hidden1, hidden2,gcn_dim1, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
    loss_a=optimizer.optimizer_CE
    
elif model_str == 'gcn_vae_gcnX_inprA_w':
    model = gae.gae.model.GCNModelVAE_gcnX_inprA_w(num_features, hidden1, hidden2,gcn_dim1, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
    loss_a=optimizer.optimizer_CE    
    
elif model_str=='gcn_vae_xa_e3':
    model = gae.gae.model.GCNModelVAE_XA_e3(num_features, hidden1, hidden2,hidden3,fc_dim1,fc_dim2,fc_dim3,fc_dim4, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
    loss_a=optimizer.optimizer_CE
    
elif model_str == 'gcn_vae_xa_e1':
    model = gae.gae.model.GCNModelVAE_XA_e1(num_features, hidden1, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
    loss_a=optimizer.optimizer_CE

elif model_str == 'gcn_vae_xa_e2_d1':
    model = gae.gae.model.GCNModelVAE_XA_e2_d1(num_features, hidden1,hidden2, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
    loss_a=optimizer.optimizer_CE
    
elif model_str=='gcn_vae_xa_e2_d1_dca':
    model = gae.gae.model.GCNModelVAE_XA_e2_d1_DCA(num_features, hidden1,hidden2,fc_dim1, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_zinb
    loss_a=optimizer.optimizer_CE

elif model_str=='gcn_vae_xa_e2_d1_dcaFork':
    model = gae.gae.model.GCNModelVAE_XA_e2_d1_DCAfork(num_features, hidden1,hidden2,fc_dim1, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_zinb
    loss_a=optimizer.optimizer_CE

elif model_str=='gcn_vae_xa_e2_d1_dcaElemPi':
    model = gae.gae.model.GCNModelVAE_XA_e2_d1_DCAelemPi(num_features, hidden1,hidden2,fc_dim1, dropout,shareGenePi)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_zinb
    loss_a=optimizer.optimizer_CE

elif model_str=='gcn_vae_xa_e2_d1_dcaConstantDisp':
    model = gae.gae.model.GCNModelVAE_XA_e2_d1_DCA_constantDisp(num_features, hidden1,hidden2,fc_dim1, dropout,shareGenePi)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_zinb
    loss_a=optimizer.optimizer_CE    
    
elif model_str == 'gcn_vae_xa_e4_d1':
    model = gae.gae.model.GCNModelVAE_XA_e4_d1(num_features, hidden1,hidden2,hidden3,hidden4, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
    loss_a=optimizer.optimizer_CE    
    
elif model_str=='fc':
    model = gae.gae.model.FCVAE(num_features, hidden1, hidden2,hidden3,hidden4,hidden5,fc_dim1,fc_dim2,fc_dim3,fc_dim4, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
#     loss_x=mse
    loss_a=optimizer.optimizer_CE
elif model_str=='fcae':
    model = gae.gae.model.FCAE(num_features, hidden1, hidden2,hidden3,hidden4,hidden5,fc_dim1,fc_dim2,fc_dim3,fc_dim4, dropout)
    loss_x=optimizer.optimizer_MSE
#     loss_x=mse

elif model_str=='fcae1':
    model = gae.gae.model.FCAE1(num_features, dropout,hidden1)
    loss_x=optimizer.optimizer_MSE
#     loss_x=mse
elif model_str=='fcae2':
    model = gae.gae.model.FCAE2(num_features, dropout,hidden1,hidden2)
    loss_x=optimizer.optimizer_MSE

elif model_str=='fc1':
    model = gae.gae.model.FCVAE1(num_features, hidden1,dropout)
    loss_x=optimizer.optimizer_MSE
    loss_kl=optimizer.optimizer_kl
    loss_a=optimizer.optimizer_CE

elif model_str=='fc1_dca':
    model = gae.gae.model.FCVAE1_DCA(num_features, hidden1,fc_dim1, dropout)
    loss_x=optimizer.optimizer_zinb
    loss_kl=optimizer.optimizer_kl
    loss_a=optimizer.optimizer_CE

if clf=='clf_fc1':
    modelClf=gae.gae.model.Clf_fc1(hidden2, dropout,clf_hidden,ct_unique.size)
    loss_clf=torch.nn.CrossEntropyLoss()
    
pos_weight = float(adj_train.shape[0] * adj_train.shape[0] - adj_train.sum()) / adj_train.sum() #using full unmasked adj
pos_weight=torch.tensor(pos_weight)
norm = adj_train.shape[0] * adj_train.shape[0] / float((adj_train.shape[0] * adj_train.shape[0] - adj_train.sum()) * 2)

if use_cuda:
    model.cuda()
    if clf:
        modelClf.cuda()
        ct_train=torch.tensor(ct_train).cuda()
    features = features.cuda().float()
    adj_norm=adj_norm.cuda()
    adj_label = adj_label.cuda().float()
    if adj_decode is not None:
        adj_decode=adj_decode.cuda()
    train_nodes_idx=train_nodes_idx.cuda()
    val_nodes_idx=val_nodes_idx.cuda()
    test_nodes_idx=test_nodes_idx.cuda()

optimizerVAEXA = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
if clf:
    optimizerClf=optim.Adam(modelClf.parameters(), lr=lr, weight_decay=weight_decay)

# %%
 
def train(epoch):
    t = time.time()
    model.train()
    optimizerVAEXA.zero_grad()
    
    if adj_decodeName==None:
        adj_recon,mu,logvar,z,features_recon = model(features, adj_norm)
    #     features_recon, z, mu, logvar=model(features.float())
    else:
        adj_recon,mu,logvar,z,features_recon = model(features, adj_norm,adj_decode)
        
    
    if clf:
        modelClf.train()
        optimizerClf.zero_grad()
        clfOut=modelClf(z)
        
    
    loss_kl_train=loss_kl(mu, logvar, train_nodes_idx)
    if 'dca' in model_str:
        loss_x_train=loss_x(features_recon, features,train_nodes_idx,XreconWeight,ridgeL,torch.tensor(features_raw).cuda())
    else:
        loss_x_train=loss_x(features_recon, features,train_nodes_idx,XreconWeight,mse)
    loss_a_train=loss_a(adj_recon, adj_label, pos_weight, norm,train_nodes_idx)
    loss = loss_kl_train+loss_x_train+loss_a_train
#     loss=loss_x_train #for lossXreconOnly only
#     loss=loss_kl_train+loss_x_train #for lossXreconOnly_wKL only
#     loss = loss_kl_train+loss_a_train #for lossAreconOnly_wKL only
    if clf:
        loss_clf_train=loss_clf(clfOut[train_nodes_idx],ct_train[train_nodes_idx])
        loss=loss+clfweight*loss_clf_train
    loss.backward()
    optimizerVAEXA.step()
    if clf:
        optimizerClf.step()

    if not fastmode:
        # Evaluate validation set performance separately,
        # deactivates dropout during validation run & no variation in z.
        model.eval()
        if adj_decodeName==None:
            adj_recon,mu,logvar,z, features_recon = model(features, adj_norm)
    #         features_recon, z, mu, logvar=model(features.float())
        else:
            adj_recon,mu,logvar,z, features_recon = model(features, adj_norm,adj_decode)
    
    if clf:
        modelClf.eval()
        clfOut=modelClf(z)
    if 'dca' in model_str:
        loss_x_val=loss_x(features_recon, features,val_nodes_idx,XreconWeight,ridgeL,torch.tensor(features_raw).cuda())
    else:
        loss_x_val=loss_x(features_recon, features,val_nodes_idx,XreconWeight,mse)
    loss_a_val=loss_a(adj_recon, adj_label, pos_weight, norm,val_nodes_idx)
    loss_val = loss_x_val+loss_a_val
#     loss_val=loss_x_val
    if clf:
        loss_clf_val=loss_clf(clfOut[val_nodes_idx],ct_train[val_nodes_idx])
        loss_val=loss_val+clfweight*loss_clf_val
    
#     print(features_recon[:5,:5])
    print('Epoch: {:04d}'.format(epoch),
          'loss_train: {:.4f}'.format(loss.item()),
          'loss_kl_train: {:.4f}'.format(loss_kl_train.item()),
          'loss_x_train: {:.4f}'.format(loss_x_train.item()),
          'loss_a_train: {:.4f}'.format(loss_a_train.item()),
#           'loss_clf_train: {:.4f}'.format(loss_clf_train.item()),
          'loss_val: {:.4f}'.format(loss_val.item()),
          'loss_x_val: {:.4f}'.format(loss_x_val.item()),
          'loss_a_val: {:.4f}'.format(loss_a_val.item()),
#           'loss_clf_val: {:.4f}'.format(loss_clf_val.item()),
          'time: {:.4f}s'.format(time.time() - t))
#     return loss.item(),loss_x_train.item(),loss_val.item(),loss_x_val.item()
#     return loss.item(),loss_kl_train.item(),loss_x_train.item(),loss_val.item(),loss_x_val.item()
    if clf:
        return loss.item(),loss_kl_train.item(),loss_x_train.item(),loss_a_train.item(),loss_val.item(),loss_x_val.item(),loss_a_val.item(),loss_clf_train.item(),loss_clf_val.item()
    else:
        return loss.item(),loss_kl_train.item(),loss_x_train.item(),loss_a_train.item(),loss_val.item(),loss_x_val.item(),loss_a_val.item()

# print('cross-validation ',seti)
train_loss_ep=[None]*epochs
train_loss_kl_ep=[None]*epochs
train_loss_x_ep=[None]*epochs
train_loss_a_ep=[None]*epochs
train_loss_clf_ep=[None]*epochs
val_loss_ep=[None]*epochs
val_loss_x_ep=[None]*epochs
val_loss_a_ep=[None]*epochs
val_loss_clf_ep=[None]*epochs
t_ep=time.time()
for ep in range(epochs):
#     train_loss_ep[ep],train_loss_x_ep[ep],val_loss_ep[ep],val_loss_x_ep[ep]=train(ep)
#     train_loss_ep[ep],train_loss_kl_ep[ep],train_loss_x_ep[ep],val_loss_ep[ep],val_loss_x_ep[ep]=train(ep)
    if clf:
        train_loss_ep[ep],train_loss_kl_ep[ep],train_loss_x_ep[ep],train_loss_a_ep[ep],val_loss_ep[ep],val_loss_x_ep[ep],val_loss_a_ep[ep],train_loss_clf_ep[ep],val_loss_clf_ep[ep]=train(ep)
    else:
        train_loss_ep[ep],train_loss_kl_ep[ep],train_loss_x_ep[ep],train_loss_a_ep[ep],val_loss_ep[ep],val_loss_x_ep[ep],val_loss_a_ep[ep]=train(ep)

        
    if ep%saveFreq == 0:
        torch.save(model.cpu().state_dict(), os.path.join(modelsavepath,str(ep)+'.pt'))
    if use_cuda:
        model.cuda()
print('total time: {:.4f}s'.format(time.time() - t_ep))
# Out:
# Epoch: 0000 loss_train: 21.5864 loss_kl_train: 0.0006 loss_x_train: 7.9477 loss_a_train: 13.6381 loss_val: 8.9771 loss_x_val: 7.8639 loss_a_val: 1.1132 time: 0.7857s
# Epoch: 0001 loss_train: 19.6643 loss_kl_train: 0.0002 loss_x_train: 6.6704 loss_a_train: 12.9937 loss_val: 9.2512 loss_x_val: 7.8022 loss_a_val: 1.4490 time: 0.4709s
# Epoch: 0002 loss_train: 18.5977 loss_kl_train: 0.0003 loss_x_train: 5.6776 loss_a_train: 12.9198 loss_val: 9.1977 loss_x_val: 7.7427 loss_a_val: 1.4550 time: 0.4745s
# Epoch: 0003 loss_train: 17.7792 loss_kl_train: 0.0003 loss_x_train: 4.9220 loss_a_train: 12.8570 loss_val: 8.9665 loss_x_val: 7.6841 loss_a_val: 1.2824 time: 0.4670s
# Epoch: 0004 loss_train: 17.1544 loss_kl_train: 0.0002 loss_x_train: 4.3637 loss_a_train: 12.7905 loss_val: 8.8198 loss_x_val: 7.6068 loss_a_val: 1.2131 time: 0.4645s
# Epoch: 0005 loss_train: 16.6759 loss_kl_train: 0.0002 loss_x_train: 3.9578 loss_a_train: 12.7179 loss_val: 8.8264 loss_x_val: 7.4996 loss_a_val: 1.3268 time: 0.4656s
# Epoch: 0006 loss_train: 16.3129 loss_kl_train: 0.0003 loss_x_train: 3.6675 loss_a_train: 12.6452 loss_val: 8.8127 loss_x_val: 7.3947 loss_a_val: 1.4180 time: 0.4719s
# Epoch: 0007 loss_train: 16.0501 loss_kl_train: 0.0003 loss_x_train: 3.4621 loss_a_train: 12.5876 loss_val: 8.6872 loss_x_val: 7.3164 loss_a_val: 1.3707 time: 0.4730s
# Epoch: 0008 loss_train: 15.8689 loss_kl_train: 0.0003 loss_x_train: 3.3160 loss_a_train: 12.5526 loss_val: 8.5573 loss_x_val: 7.2409 loss_a_val: 1.3163 time: 0.4704s
# Epoch: 0009 loss_train: 15.6312 loss_kl_train: 0.0004 loss_x_train: 3.2107 loss_a_train: 12.4201 loss_val: 8.6082 loss_x_val: 7.1171 loss_a_val: 1.4911 time: 0.4668s
# Epoch: 0010 loss_train: 15.3796 loss_kl_train: 0.0005 loss_x_train: 3.1331 loss_a_train: 12.2461 loss_val: 8.6020 loss_x_val: 6.9911 loss_a_val: 1.6108 time: 0.4727s
# Epoch: 0011 loss_train: 15.2812 loss_kl_train: 0.0005 loss_x_train: 3.0743 loss_a_train: 12.2064 loss_val: 8.6802 loss_x_val: 6.8418 loss_a_val: 1.8384 time: 0.4717s
# Epoch: 0012 loss_train: 15.1289 loss_kl_train: 0.0006 loss_x_train: 3.0271 loss_a_train: 12.1011 loss_val: 8.7506 loss_x_val: 6.6956 loss_a_val: 2.0551 time: 0.4696s
# Epoch: 0013 loss_train: 14.9560 loss_kl_train: 0.0008 loss_x_train: 2.9869 loss_a_train: 11.9684 loss_val: 8.6042 loss_x_val: 6.5877 loss_a_val: 2.0165 time: 0.4718s
# Epoch: 0014 loss_train: 14.8468 loss_kl_train: 0.0008 loss_x_train: 2.9519 loss_a_train: 11.8941 loss_val: 8.4182 loss_x_val: 6.5026 loss_a_val: 1.9155 time: 0.4739s
# Epoch: 0015 loss_train: 14.7392 loss_kl_train: 0.0008 loss_x_train: 2.9187 loss_a_train: 11.8197 loss_val: 8.3386 loss_x_val: 6.3940 loss_a_val: 1.9446 time: 0.4709s
# Epoch: 0016 loss_train: 14.5878 loss_kl_train: 0.0009 loss_x_train: 2.8868 loss_a_train: 11.7001 loss_val: 8.3112 loss_x_val: 6.2827 loss_a_val: 2.0284 time: 0.4657s
# Epoch: 0017 loss_train: 14.4827 loss_kl_train: 0.0010 loss_x_train: 2.8562 loss_a_train: 11.6255 loss_val: 8.1801 loss_x_val: 6.2090 loss_a_val: 1.9711 time: 0.4649s
# Epoch: 0018 loss_train: 14.3456 loss_kl_train: 0.0009 loss_x_train: 2.8269 loss_a_train: 11.5178 loss_val: 7.9908 loss_x_val: 6.1459 loss_a_val: 1.8449 time: 0.4728s
# Epoch: 0019 loss_train: 14.1966 loss_kl_train: 0.0010 loss_x_train: 2.7981 loss_a_train: 11.3975 loss_val: 7.9869 loss_x_val: 6.0716 loss_a_val: 1.9153 time: 0.4706s
# Epoch: 0020 loss_train: 14.0887 loss_kl_train: 0.0011 loss_x_train: 2.7702 loss_a_train: 11.3174 loss_val: 7.9420 loss_x_val: 6.0009 loss_a_val: 1.9411 time: 0.4741s
# Epoch: 0021 loss_train: 13.8634 loss_kl_train: 0.0011 loss_x_train: 2.7436 loss_a_train: 11.1187 loss_val: 7.8164 loss_x_val: 5.9173 loss_a_val: 1.8991 time: 0.4669s
# Epoch: 0022 loss_train: 13.7778 loss_kl_train: 0.0012 loss_x_train: 2.7177 loss_a_train: 11.0590 loss_val: 7.7703 loss_x_val: 5.8669 loss_a_val: 1.9035 time: 0.4719s
# Epoch: 0023 loss_train: 13.6733 loss_kl_train: 0.0012 loss_x_train: 2.6934 loss_a_train: 10.9787 loss_val: 7.8265 loss_x_val: 5.7969 loss_a_val: 2.0295 time: 0.4787s
# Epoch: 0024 loss_train: 13.4942 loss_kl_train: 0.0014 loss_x_train: 2.6697 loss_a_train: 10.8231 loss_val: 7.6821 loss_x_val: 5.7510 loss_a_val: 1.9311 time: 0.4759s
# Epoch: 0025 loss_train: 13.3355 loss_kl_train: 0.0014 loss_x_train: 2.6473 loss_a_train: 10.6868 loss_val: 7.6923 loss_x_val: 5.7087 loss_a_val: 1.9835 time: 0.4722s
# Epoch: 0026 loss_train: 13.2979 loss_kl_train: 0.0015 loss_x_train: 2.6261 loss_a_train: 10.6702 loss_val: 7.6620 loss_x_val: 5.6843 loss_a_val: 1.9777 time: 0.4667s
# Epoch: 0027 loss_train: 13.0612 loss_kl_train: 0.0016 loss_x_train: 2.6059 loss_a_train: 10.4537 loss_val: 7.5654 loss_x_val: 5.6681 loss_a_val: 1.8973 time: 0.4717s
# Epoch: 0028 loss_train: 12.8260 loss_kl_train: 0.0017 loss_x_train: 2.5865 loss_a_train: 10.2378 loss_val: 7.5365 loss_x_val: 5.6339 loss_a_val: 1.9026 time: 0.4714s
# Epoch: 0029 loss_train: 12.6939 loss_kl_train: 0.0019 loss_x_train: 2.5683 loss_a_train: 10.1236 loss_val: 7.5856 loss_x_val: 5.5858 loss_a_val: 1.9998 time: 0.4711s
# Epoch: 0030 loss_train: 12.5363 loss_kl_train: 0.0021 loss_x_train: 2.5512 loss_a_train: 9.9830 loss_val: 7.3731 loss_x_val: 5.6242 loss_a_val: 1.7489 time: 0.4697s
# Epoch: 0031 loss_train: 12.3719 loss_kl_train: 0.0022 loss_x_train: 2.5351 loss_a_train: 9.8346 loss_val: 7.6309 loss_x_val: 5.4987 loss_a_val: 2.1322 time: 0.4683s
# Epoch: 0032 loss_train: 12.1751 loss_kl_train: 0.0026 loss_x_train: 2.5194 loss_a_train: 9.6531 loss_val: 7.3551 loss_x_val: 5.5319 loss_a_val: 1.8231 time: 0.4741s
# Epoch: 0033 loss_train: 11.9446 loss_kl_train: 0.0028 loss_x_train: 2.5050 loss_a_train: 9.4369 loss_val: 7.4388 loss_x_val: 5.4740 loss_a_val: 1.9648 time: 0.4707s
# Epoch: 0034 loss_train: 11.8386 loss_kl_train: 0.0030 loss_x_train: 2.4911 loss_a_train: 9.3445 loss_val: 7.4029 loss_x_val: 5.4513 loss_a_val: 1.9515 time: 0.4676s
# Epoch: 0035 loss_train: 11.6056 loss_kl_train: 0.0034 loss_x_train: 2.4782 loss_a_train: 9.1240 loss_val: 7.5191 loss_x_val: 5.3853 loss_a_val: 2.1337 time: 0.4724s
# Epoch: 0036 loss_train: 11.4282 loss_kl_train: 0.0038 loss_x_train: 2.4660 loss_a_train: 8.9583 loss_val: 7.2313 loss_x_val: 5.4615 loss_a_val: 1.7697 time: 0.4717s
# Epoch: 0037 loss_train: 11.1904 loss_kl_train: 0.0041 loss_x_train: 2.4547 loss_a_train: 8.7316 loss_val: 7.2814 loss_x_val: 5.3582 loss_a_val: 1.9232 time: 0.4717s
# Epoch: 0038 loss_train: 11.0182 loss_kl_train: 0.0046 loss_x_train: 2.4439 loss_a_train: 8.5698 loss_val: 7.4354 loss_x_val: 5.2851 loss_a_val: 2.1503 time: 0.4691s
# Epoch: 0039 loss_train: 10.8955 loss_kl_train: 0.0053 loss_x_train: 2.4342 loss_a_train: 8.4560 loss_val: 7.2017 loss_x_val: 5.3533 loss_a_val: 1.8484 time: 0.4697s
# Epoch: 0040 loss_train: 10.6674 loss_kl_train: 0.0057 loss_x_train: 2.4248 loss_a_train: 8.2369 loss_val: 7.1768 loss_x_val: 5.2942 loss_a_val: 1.8826 time: 0.4719s
# Epoch: 0041 loss_train: 10.4485 loss_kl_train: 0.0063 loss_x_train: 2.4161 loss_a_train: 8.0260 loss_val: 7.2544 loss_x_val: 5.2170 loss_a_val: 2.0374 time: 0.4695s
# Epoch: 0042 loss_train: 10.3182 loss_kl_train: 0.0071 loss_x_train: 2.4084 loss_a_train: 7.9027 loss_val: 6.9103 loss_x_val: 5.3874 loss_a_val: 1.5229 time: 0.4732s
# Epoch: 0043 loss_train: 10.0232 loss_kl_train: 0.0076 loss_x_train: 2.4006 loss_a_train: 7.6150 loss_val: 7.0961 loss_x_val: 5.2469 loss_a_val: 1.8492 time: 0.4701s
# Epoch: 0044 loss_train: 9.9001 loss_kl_train: 0.0086 loss_x_train: 2.3935 loss_a_train: 7.4981 loss_val: 7.1898 loss_x_val: 5.1621 loss_a_val: 2.0278 time: 0.4730s
# Epoch: 0045 loss_train: 9.7257 loss_kl_train: 0.0095 loss_x_train: 2.3869 loss_a_train: 7.3293 loss_val: 6.8898 loss_x_val: 5.3794 loss_a_val: 1.5104 time: 0.4719s
# Epoch: 0046 loss_train: 9.4977 loss_kl_train: 0.0103 loss_x_train: 2.3815 loss_a_train: 7.1059 loss_val: 7.3293 loss_x_val: 5.2624 loss_a_val: 2.0669 time: 0.4716s
# Epoch: 0047 loss_train: 9.5377 loss_kl_train: 0.0114 loss_x_train: 2.3757 loss_a_train: 7.1506 loss_val: 7.0606 loss_x_val: 5.3153 loss_a_val: 1.7453 time: 0.4675s
# Epoch: 0048 loss_train: 9.2353 loss_kl_train: 0.0123 loss_x_train: 2.3709 loss_a_train: 6.8521 loss_val: 6.8339 loss_x_val: 5.1869 loss_a_val: 1.6470 time: 0.4731s
# Epoch: 0049 loss_train: 9.0541 loss_kl_train: 0.0136 loss_x_train: 2.3648 loss_a_train: 6.6757 loss_val: 6.8029 loss_x_val: 5.1771 loss_a_val: 1.6259 time: 0.4740s
# Epoch: 0050 loss_train: 8.7901 loss_kl_train: 0.0146 loss_x_train: 2.3611 loss_a_train: 6.4143 loss_val: 7.1674 loss_x_val: 5.0860 loss_a_val: 2.0814 time: 0.4754s
# Epoch: 0051 loss_train: 8.7826 loss_kl_train: 0.0160 loss_x_train: 2.3570 loss_a_train: 6.4096 loss_val: 6.6631 loss_x_val: 5.4360 loss_a_val: 1.2271 time: 0.4668s
# Epoch: 0052 loss_train: 8.5236 loss_kl_train: 0.0170 loss_x_train: 2.3537 loss_a_train: 6.1530 loss_val: 6.8491 loss_x_val: 5.2366 loss_a_val: 1.6125 time: 0.4735s
# Epoch: 0053 loss_train: 8.4177 loss_kl_train: 0.0185 loss_x_train: 2.3495 loss_a_train: 6.0497 loss_val: 6.7262 loss_x_val: 5.0783 loss_a_val: 1.6479 time: 0.4721s
# Epoch: 0054 loss_train: 8.1744 loss_kl_train: 0.0198 loss_x_train: 2.3467 loss_a_train: 5.8079 loss_val: 6.5636 loss_x_val: 5.1071 loss_a_val: 1.4565 time: 0.4724s
# Epoch: 0055 loss_train: 8.0090 loss_kl_train: 0.0212 loss_x_train: 2.3432 loss_a_train: 5.6446 loss_val: 6.5737 loss_x_val: 5.0344 loss_a_val: 1.5392 time: 0.4666s
# Epoch: 0056 loss_train: 7.8788 loss_kl_train: 0.0227 loss_x_train: 2.3393 loss_a_train: 5.5168 loss_val: 6.5324 loss_x_val: 4.9879 loss_a_val: 1.5445 time: 0.4724s
# Epoch: 0057 loss_train: 7.7700 loss_kl_train: 0.0243 loss_x_train: 2.3369 loss_a_train: 5.4088 loss_val: 6.5238 loss_x_val: 4.9779 loss_a_val: 1.5459 time: 0.4679s
# Epoch: 0058 loss_train: 7.6290 loss_kl_train: 0.0258 loss_x_train: 2.3359 loss_a_train: 5.2673 loss_val: 6.5313 loss_x_val: 4.9888 loss_a_val: 1.5424 time: 0.4765s
# Epoch: 0059 loss_train: 7.5357 loss_kl_train: 0.0275 loss_x_train: 2.3318 loss_a_train: 5.1764 loss_val: 6.5850 loss_x_val: 4.8525 loss_a_val: 1.7325 time: 0.4789s
# Epoch: 0060 loss_train: 7.4581 loss_kl_train: 0.0292 loss_x_train: 2.3290 loss_a_train: 5.0999 loss_val: 6.1109 loss_x_val: 4.8857 loss_a_val: 1.2252 time: 0.4722s
# Epoch: 0061 loss_train: 7.1303 loss_kl_train: 0.0307 loss_x_train: 2.3273 loss_a_train: 4.7723 loss_val: 6.4952 loss_x_val: 4.5781 loss_a_val: 1.9171 time: 0.4670s
# Epoch: 0062 loss_train: 7.2617 loss_kl_train: 0.0326 loss_x_train: 2.3235 loss_a_train: 4.9056 loss_val: 6.1532 loss_x_val: 4.9046 loss_a_val: 1.2486 time: 0.4739s
# Epoch: 0063 loss_train: 6.9944 loss_kl_train: 0.0341 loss_x_train: 2.3225 loss_a_train: 4.6377 loss_val: 6.7922 loss_x_val: 4.8326 loss_a_val: 1.9597 time: 0.4687s
# Epoch: 0064 loss_train: 7.1630 loss_kl_train: 0.0361 loss_x_train: 2.3219 loss_a_train: 4.8050 loss_val: 6.1292 loss_x_val: 4.7704 loss_a_val: 1.3588 time: 0.4735s
# Epoch: 0065 loss_train: 6.7473 loss_kl_train: 0.0377 loss_x_train: 2.3204 loss_a_train: 4.3892 loss_val: 6.0588 loss_x_val: 4.4822 loss_a_val: 1.5766 time: 0.4710s
# Epoch: 0066 loss_train: 6.7340 loss_kl_train: 0.0396 loss_x_train: 2.3193 loss_a_train: 4.3751 loss_val: 6.2192 loss_x_val: 4.4663 loss_a_val: 1.7529 time: 0.4734s
# Epoch: 0067 loss_train: 6.7520 loss_kl_train: 0.0413 loss_x_train: 2.3154 loss_a_train: 4.3953 loss_val: 6.3396 loss_x_val: 4.5408 loss_a_val: 1.7988 time: 0.4722s
# Epoch: 0068 loss_train: 6.8431 loss_kl_train: 0.0430 loss_x_train: 2.3143 loss_a_train: 4.4857 loss_val: 6.1886 loss_x_val: 4.5062 loss_a_val: 1.6823 time: 0.4703s
# Epoch: 0069 loss_train: 6.5884 loss_kl_train: 0.0447 loss_x_train: 2.3131 loss_a_train: 4.2307 loss_val: 6.1718 loss_x_val: 4.3778 loss_a_val: 1.7940 time: 0.4685s
# Epoch: 0070 loss_train: 6.6190 loss_kl_train: 0.0464 loss_x_train: 2.3115 loss_a_train: 4.2611 loss_val: 5.8045 loss_x_val: 4.2187 loss_a_val: 1.5858 time: 0.4747s
# Epoch: 0071 loss_train: 6.3249 loss_kl_train: 0.0480 loss_x_train: 2.3074 loss_a_train: 3.9695 loss_val: 6.2998 loss_x_val: 4.0341 loss_a_val: 2.2657 time: 0.4688s
# Epoch: 0072 loss_train: 6.7326 loss_kl_train: 0.0499 loss_x_train: 2.3039 loss_a_train: 4.3788 loss_val: 5.2369 loss_x_val: 4.0304 loss_a_val: 1.2065 time: 0.4731s
# Epoch: 0073 loss_train: 6.0358 loss_kl_train: 0.0511 loss_x_train: 2.3023 loss_a_train: 3.6824 loss_val: 6.0127 loss_x_val: 3.8693 loss_a_val: 2.1434 time: 0.4704s
# Epoch: 0074 loss_train: 6.4495 loss_kl_train: 0.0529 loss_x_train: 2.2988 loss_a_train: 4.0978 loss_val: 5.1728 loss_x_val: 3.9859 loss_a_val: 1.1869 time: 0.4740s
# Epoch: 0075 loss_train: 5.9080 loss_kl_train: 0.0541 loss_x_train: 2.2972 loss_a_train: 3.5567 loss_val: 5.4193 loss_x_val: 3.8788 loss_a_val: 1.5405 time: 0.4741s
# Epoch: 0076 loss_train: 5.9733 loss_kl_train: 0.0559 loss_x_train: 2.2919 loss_a_train: 3.6255 loss_val: 5.2343 loss_x_val: 3.8921 loss_a_val: 1.3422 time: 0.4705s
# Epoch: 0077 loss_train: 5.8157 loss_kl_train: 0.0573 loss_x_train: 2.2915 loss_a_train: 3.4668 loss_val: 5.5233 loss_x_val: 3.8415 loss_a_val: 1.6819 time: 0.4719s
# Epoch: 0078 loss_train: 5.9178 loss_kl_train: 0.0590 loss_x_train: 2.2881 loss_a_train: 3.5706 loss_val: 5.3495 loss_x_val: 3.9512 loss_a_val: 1.3983 time: 0.4734s
# Epoch: 0079 loss_train: 5.7470 loss_kl_train: 0.0605 loss_x_train: 2.2872 loss_a_train: 3.3993 loss_val: 5.5033 loss_x_val: 3.8762 loss_a_val: 1.6270 time: 0.4736s
# Epoch: 0080 loss_train: 5.7959 loss_kl_train: 0.0622 loss_x_train: 2.2852 loss_a_train: 3.4485 loss_val: 5.4194 loss_x_val: 3.9278 loss_a_val: 1.4916 time: 0.4756s
# Epoch: 0081 loss_train: 5.6827 loss_kl_train: 0.0637 loss_x_train: 2.2819 loss_a_train: 3.3372 loss_val: 5.3212 loss_x_val: 3.8746 loss_a_val: 1.4465 time: 0.4724s
# Epoch: 0082 loss_train: 5.6133 loss_kl_train: 0.0653 loss_x_train: 2.2806 loss_a_train: 3.2674 loss_val: 5.2909 loss_x_val: 3.8016 loss_a_val: 1.4893 time: 0.4717s
# Epoch: 0083 loss_train: 5.5588 loss_kl_train: 0.0668 loss_x_train: 2.2761 loss_a_train: 3.2159 loss_val: 5.4784 loss_x_val: 3.7568 loss_a_val: 1.7216 time: 0.4745s
# Epoch: 0084 loss_train: 5.6915 loss_kl_train: 0.0684 loss_x_train: 2.2745 loss_a_train: 3.3486 loss_val: 5.3310 loss_x_val: 3.7163 loss_a_val: 1.6147 time: 0.4770s
# Epoch: 0085 loss_train: 5.5509 loss_kl_train: 0.0699 loss_x_train: 2.2724 loss_a_train: 3.2087 loss_val: 5.5045 loss_x_val: 3.7358 loss_a_val: 1.7686 time: 0.4697s
# Epoch: 0086 loss_train: 5.6269 loss_kl_train: 0.0714 loss_x_train: 2.2713 loss_a_train: 3.2842 loss_val: 5.3584 loss_x_val: 3.7126 loss_a_val: 1.6459 time: 0.4707s
# Epoch: 0087 loss_train: 5.5060 loss_kl_train: 0.0728 loss_x_train: 2.2685 loss_a_train: 3.1647 loss_val: 5.2854 loss_x_val: 3.7091 loss_a_val: 1.5763 time: 0.4738s
# Epoch: 0088 loss_train: 5.4062 loss_kl_train: 0.0742 loss_x_train: 2.2659 loss_a_train: 3.0660 loss_val: 5.1599 loss_x_val: 3.6972 loss_a_val: 1.4627 time: 0.4771s
# Epoch: 0089 loss_train: 5.3193 loss_kl_train: 0.0755 loss_x_train: 2.2629 loss_a_train: 2.9809 loss_val: 5.2025 loss_x_val: 3.6669 loss_a_val: 1.5356 time: 0.4766s
# Epoch: 0090 loss_train: 5.3277 loss_kl_train: 0.0770 loss_x_train: 2.2614 loss_a_train: 2.9892 loss_val: 5.1907 loss_x_val: 3.6609 loss_a_val: 1.5299 time: 0.4741s
# Epoch: 0091 loss_train: 5.2771 loss_kl_train: 0.0783 loss_x_train: 2.2599 loss_a_train: 2.9389 loss_val: 5.2706 loss_x_val: 3.6694 loss_a_val: 1.6012 time: 0.4740s
# Epoch: 0092 loss_train: 5.3086 loss_kl_train: 0.0797 loss_x_train: 2.2576 loss_a_train: 2.9713 loss_val: 5.2019 loss_x_val: 3.6430 loss_a_val: 1.5589 time: 0.4768s
# Epoch: 0093 loss_train: 5.2292 loss_kl_train: 0.0811 loss_x_train: 2.2554 loss_a_train: 2.8927 loss_val: 5.1805 loss_x_val: 3.6648 loss_a_val: 1.5157 time: 0.4719s
# Epoch: 0094 loss_train: 5.1640 loss_kl_train: 0.0824 loss_x_train: 2.2533 loss_a_train: 2.8283 loss_val: 5.1910 loss_x_val: 3.6598 loss_a_val: 1.5311 time: 0.4766s
# Epoch: 0095 loss_train: 5.1594 loss_kl_train: 0.0837 loss_x_train: 2.2510 loss_a_train: 2.8247 loss_val: 5.2670 loss_x_val: 3.6672 loss_a_val: 1.5998 time: 0.4740s
# Epoch: 0096 loss_train: 5.1659 loss_kl_train: 0.0850 loss_x_train: 2.2497 loss_a_train: 2.8312 loss_val: 5.2164 loss_x_val: 3.6931 loss_a_val: 1.5232 time: 0.4742s
# Epoch: 0097 loss_train: 5.0841 loss_kl_train: 0.0862 loss_x_train: 2.2479 loss_a_train: 2.7499 loss_val: 5.2281 loss_x_val: 3.6893 loss_a_val: 1.5388 time: 0.4741s
# Epoch: 0098 loss_train: 5.0796 loss_kl_train: 0.0875 loss_x_train: 2.2460 loss_a_train: 2.7461 loss_val: 5.2101 loss_x_val: 3.6480 loss_a_val: 1.5621 time: 0.4724s
# Epoch: 0099 loss_train: 5.0455 loss_kl_train: 0.0888 loss_x_train: 2.2429 loss_a_train: 2.7138 loss_val: 5.2177 loss_x_val: 3.6820 loss_a_val: 1.5357 time: 0.4699s
# Epoch: 0100 loss_train: 5.0299 loss_kl_train: 0.0900 loss_x_train: 2.2430 loss_a_train: 2.6970 loss_val: 5.2100 loss_x_val: 3.6681 loss_a_val: 1.5419 time: 0.4732s
# Epoch: 0101 loss_train: 4.9861 loss_kl_train: 0.0912 loss_x_train: 2.2396 loss_a_train: 2.6554 loss_val: 5.2334 loss_x_val: 3.6798 loss_a_val: 1.5536 time: 0.4708s
# Epoch: 0102 loss_train: 4.9798 loss_kl_train: 0.0924 loss_x_train: 2.2382 loss_a_train: 2.6493 loss_val: 5.2091 loss_x_val: 3.6783 loss_a_val: 1.5308 time: 0.4712s
# Epoch: 0103 loss_train: 4.9566 loss_kl_train: 0.0935 loss_x_train: 2.2369 loss_a_train: 2.6263 loss_val: 5.2277 loss_x_val: 3.6620 loss_a_val: 1.5657 time: 0.4716s
# Epoch: 0104 loss_train: 4.9425 loss_kl_train: 0.0947 loss_x_train: 2.2351 loss_a_train: 2.6126 loss_val: 5.2179 loss_x_val: 3.6573 loss_a_val: 1.5606 time: 0.4737s
# Epoch: 0105 loss_train: 4.9317 loss_kl_train: 0.0958 loss_x_train: 2.2327 loss_a_train: 2.6032 loss_val: 5.1539 loss_x_val: 3.6331 loss_a_val: 1.5208 time: 0.4771s
# Epoch: 0106 loss_train: 4.8669 loss_kl_train: 0.0969 loss_x_train: 2.2310 loss_a_train: 2.5391 loss_val: 5.1713 loss_x_val: 3.6848 loss_a_val: 1.4865 time: 0.4733s
# Epoch: 0107 loss_train: 4.8430 loss_kl_train: 0.0979 loss_x_train: 2.2300 loss_a_train: 2.5151 loss_val: 5.1684 loss_x_val: 3.6663 loss_a_val: 1.5021 time: 0.4732s
# Epoch: 0108 loss_train: 4.8275 loss_kl_train: 0.0990 loss_x_train: 2.2280 loss_a_train: 2.5005 loss_val: 5.2025 loss_x_val: 3.6403 loss_a_val: 1.5622 time: 0.4718s
# Epoch: 0109 loss_train: 4.8351 loss_kl_train: 0.1001 loss_x_train: 2.2256 loss_a_train: 2.5094 loss_val: 5.1684 loss_x_val: 3.7081 loss_a_val: 1.4603 time: 0.4751s
# Epoch: 0110 loss_train: 4.7747 loss_kl_train: 0.1010 loss_x_train: 2.2262 loss_a_train: 2.4475 loss_val: 5.1822 loss_x_val: 3.6693 loss_a_val: 1.5129 time: 0.4744s
# Epoch: 0111 loss_train: 4.7630 loss_kl_train: 0.1021 loss_x_train: 2.2238 loss_a_train: 2.4372 loss_val: 5.1585 loss_x_val: 3.6956 loss_a_val: 1.4629 time: 0.4725s
# Epoch: 0112 loss_train: 4.7374 loss_kl_train: 0.1030 loss_x_train: 2.2223 loss_a_train: 2.4120 loss_val: 5.1239 loss_x_val: 3.6775 loss_a_val: 1.4464 time: 0.4757s
# Epoch: 0113 loss_train: 4.7022 loss_kl_train: 0.1039 loss_x_train: 2.2208 loss_a_train: 2.3774 loss_val: 5.0942 loss_x_val: 3.6438 loss_a_val: 1.4505 time: 0.4752s
# Epoch: 0114 loss_train: 4.6799 loss_kl_train: 0.1049 loss_x_train: 2.2182 loss_a_train: 2.3569 loss_val: 5.0726 loss_x_val: 3.6479 loss_a_val: 1.4247 time: 0.4772s
# Epoch: 0115 loss_train: 4.6671 loss_kl_train: 0.1058 loss_x_train: 2.2176 loss_a_train: 2.3437 loss_val: 5.0547 loss_x_val: 3.6398 loss_a_val: 1.4148 time: 0.4778s
# Epoch: 0116 loss_train: 4.6404 loss_kl_train: 0.1067 loss_x_train: 2.2159 loss_a_train: 2.3178 loss_val: 5.0011 loss_x_val: 3.5869 loss_a_val: 1.4142 time: 0.4727s
# Epoch: 0117 loss_train: 4.6142 loss_kl_train: 0.1077 loss_x_train: 2.2147 loss_a_train: 2.2918 loss_val: 5.0089 loss_x_val: 3.5792 loss_a_val: 1.4297 time: 0.4731s
# Epoch: 0118 loss_train: 4.6099 loss_kl_train: 0.1085 loss_x_train: 2.2132 loss_a_train: 2.2881 loss_val: 5.0176 loss_x_val: 3.5855 loss_a_val: 1.4321 time: 0.4745s
# Epoch: 0119 loss_train: 4.6020 loss_kl_train: 0.1094 loss_x_train: 2.2118 loss_a_train: 2.2808 loss_val: 4.9528 loss_x_val: 3.5876 loss_a_val: 1.3651 time: 0.4747s
# Epoch: 0120 loss_train: 4.5255 loss_kl_train: 0.1103 loss_x_train: 2.2120 loss_a_train: 2.2033 loss_val: 4.9103 loss_x_val: 3.5391 loss_a_val: 1.3711 time: 0.4749s
# Epoch: 0121 loss_train: 4.5272 loss_kl_train: 0.1112 loss_x_train: 2.2092 loss_a_train: 2.2067 loss_val: 4.8883 loss_x_val: 3.5532 loss_a_val: 1.3351 time: 0.4731s
# Epoch: 0122 loss_train: 4.4905 loss_kl_train: 0.1120 loss_x_train: 2.2090 loss_a_train: 2.1695 loss_val: 4.9060 loss_x_val: 3.5199 loss_a_val: 1.3861 time: 0.4759s
# Epoch: 0123 loss_train: 4.5175 loss_kl_train: 0.1129 loss_x_train: 2.2070 loss_a_train: 2.1976 loss_val: 4.8199 loss_x_val: 3.4905 loss_a_val: 1.3294 time: 0.4789s
# Epoch: 0124 loss_train: 4.4504 loss_kl_train: 0.1137 loss_x_train: 2.2063 loss_a_train: 2.1304 loss_val: 4.8261 loss_x_val: 3.5247 loss_a_val: 1.3014 time: 0.4778s
# Epoch: 0125 loss_train: 4.4234 loss_kl_train: 0.1145 loss_x_train: 2.2057 loss_a_train: 2.1031 loss_val: 4.7821 loss_x_val: 3.4855 loss_a_val: 1.2966 time: 0.4701s
# Epoch: 0126 loss_train: 4.4093 loss_kl_train: 0.1154 loss_x_train: 2.2037 loss_a_train: 2.0902 loss_val: 4.7749 loss_x_val: 3.4870 loss_a_val: 1.2879 time: 0.4749s
# Epoch: 0127 loss_train: 4.3864 loss_kl_train: 0.1162 loss_x_train: 2.2028 loss_a_train: 2.0675 loss_val: 4.7387 loss_x_val: 3.4802 loss_a_val: 1.2585 time: 0.4747s
# Epoch: 0128 loss_train: 4.3493 loss_kl_train: 0.1170 loss_x_train: 2.2020 loss_a_train: 2.0303 loss_val: 4.6951 loss_x_val: 3.4481 loss_a_val: 1.2469 time: 0.4723s
# Epoch: 0129 loss_train: 4.3249 loss_kl_train: 0.1178 loss_x_train: 2.2001 loss_a_train: 2.0069 loss_val: 4.6246 loss_x_val: 3.3871 loss_a_val: 1.2375 time: 0.4770s
# Epoch: 0130 loss_train: 4.2961 loss_kl_train: 0.1187 loss_x_train: 2.1981 loss_a_train: 1.9793 loss_val: 4.6198 loss_x_val: 3.4135 loss_a_val: 1.2063 time: 0.4789s
# Epoch: 0131 loss_train: 4.2808 loss_kl_train: 0.1195 loss_x_train: 2.1991 loss_a_train: 1.9621 loss_val: 4.5747 loss_x_val: 3.3676 loss_a_val: 1.2072 time: 0.4744s
# Epoch: 0132 loss_train: 4.2666 loss_kl_train: 0.1204 loss_x_train: 2.1981 loss_a_train: 1.9481 loss_val: 4.5451 loss_x_val: 3.3579 loss_a_val: 1.1871 time: 0.4800s
# Epoch: 0133 loss_train: 4.2308 loss_kl_train: 0.1212 loss_x_train: 2.1960 loss_a_train: 1.9135 loss_val: 4.5437 loss_x_val: 3.3734 loss_a_val: 1.1703 time: 0.4808s
# Epoch: 0134 loss_train: 4.2078 loss_kl_train: 0.1220 loss_x_train: 2.1953 loss_a_train: 1.8904 loss_val: 4.4911 loss_x_val: 3.3412 loss_a_val: 1.1499 time: 0.4738s
# Epoch: 0135 loss_train: 4.1777 loss_kl_train: 0.1229 loss_x_train: 2.1946 loss_a_train: 1.8601 loss_val: 4.4340 loss_x_val: 3.2950 loss_a_val: 1.1390 time: 0.4731s
# Epoch: 0136 loss_train: 4.1577 loss_kl_train: 0.1238 loss_x_train: 2.1934 loss_a_train: 1.8405 loss_val: 4.4070 loss_x_val: 3.2900 loss_a_val: 1.1170 time: 0.4765s
# Epoch: 0137 loss_train: 4.1411 loss_kl_train: 0.1247 loss_x_train: 2.1923 loss_a_train: 1.8241 loss_val: 4.3729 loss_x_val: 3.2680 loss_a_val: 1.1049 time: 0.4755s
# Epoch: 0138 loss_train: 4.1176 loss_kl_train: 0.1255 loss_x_train: 2.1922 loss_a_train: 1.7999 loss_val: 4.3388 loss_x_val: 3.2574 loss_a_val: 1.0814 time: 0.4760s
# Epoch: 0139 loss_train: 4.0851 loss_kl_train: 0.1265 loss_x_train: 2.1918 loss_a_train: 1.7668 loss_val: 4.3189 loss_x_val: 3.2325 loss_a_val: 1.0864 time: 0.4765s
# Epoch: 0140 loss_train: 4.0724 loss_kl_train: 0.1274 loss_x_train: 2.1899 loss_a_train: 1.7550 loss_val: 4.2656 loss_x_val: 3.2098 loss_a_val: 1.0558 time: 0.4714s
# Epoch: 0141 loss_train: 4.0420 loss_kl_train: 0.1282 loss_x_train: 2.1901 loss_a_train: 1.7237 loss_val: 4.2302 loss_x_val: 3.1805 loss_a_val: 1.0497 time: 0.4759s
# Epoch: 0142 loss_train: 4.0236 loss_kl_train: 0.1291 loss_x_train: 2.1890 loss_a_train: 1.7055 loss_val: 4.1925 loss_x_val: 3.1588 loss_a_val: 1.0337 time: 0.4771s
# Epoch: 0143 loss_train: 4.0025 loss_kl_train: 0.1301 loss_x_train: 2.1886 loss_a_train: 1.6839 loss_val: 4.1383 loss_x_val: 3.1113 loss_a_val: 1.0270 time: 0.4722s
# Epoch: 0144 loss_train: 3.9831 loss_kl_train: 0.1310 loss_x_train: 2.1874 loss_a_train: 1.6647 loss_val: 4.1244 loss_x_val: 3.0859 loss_a_val: 1.0385 time: 0.4771s
# Epoch: 0145 loss_train: 3.9898 loss_kl_train: 0.1320 loss_x_train: 2.1861 loss_a_train: 1.6718 loss_val: 4.0811 loss_x_val: 3.0652 loss_a_val: 1.0159 time: 0.4757s
# Epoch: 0146 loss_train: 3.9450 loss_kl_train: 0.1328 loss_x_train: 2.1861 loss_a_train: 1.6261 loss_val: 4.1243 loss_x_val: 3.1030 loss_a_val: 1.0213 time: 0.4737s
# Epoch: 0147 loss_train: 3.9497 loss_kl_train: 0.1338 loss_x_train: 2.1849 loss_a_train: 1.6310 loss_val: 4.0646 loss_x_val: 3.0520 loss_a_val: 1.0125 time: 0.4768s
# Epoch: 0148 loss_train: 3.9136 loss_kl_train: 0.1347 loss_x_train: 2.1842 loss_a_train: 1.5947 loss_val: 4.0096 loss_x_val: 3.0318 loss_a_val: 0.9778 time: 0.4770s
# Epoch: 0149 loss_train: 3.8969 loss_kl_train: 0.1356 loss_x_train: 2.1836 loss_a_train: 1.5777 loss_val: 3.9759 loss_x_val: 2.9895 loss_a_val: 0.9864 time: 0.4726s
# Epoch: 0150 loss_train: 3.8896 loss_kl_train: 0.1366 loss_x_train: 2.1823 loss_a_train: 1.5707 loss_val: 3.9571 loss_x_val: 2.9870 loss_a_val: 0.9702 time: 0.4785s
# Epoch: 0151 loss_train: 3.8656 loss_kl_train: 0.1375 loss_x_train: 2.1824 loss_a_train: 1.5456 loss_val: 3.9403 loss_x_val: 2.9650 loss_a_val: 0.9754 time: 0.4768s
# Epoch: 0152 loss_train: 3.8516 loss_kl_train: 0.1385 loss_x_train: 2.1803 loss_a_train: 1.5328 loss_val: 3.9415 loss_x_val: 2.9804 loss_a_val: 0.9611 time: 0.4752s
# Epoch: 0153 loss_train: 3.8482 loss_kl_train: 0.1394 loss_x_train: 2.1810 loss_a_train: 1.5278 loss_val: 3.9049 loss_x_val: 2.9479 loss_a_val: 0.9570 time: 0.4757s
# Epoch: 0154 loss_train: 3.8285 loss_kl_train: 0.1405 loss_x_train: 2.1802 loss_a_train: 1.5078 loss_val: 3.8460 loss_x_val: 2.8881 loss_a_val: 0.9579 time: 0.4764s
# Epoch: 0155 loss_train: 3.8115 loss_kl_train: 0.1415 loss_x_train: 2.1790 loss_a_train: 1.4910 loss_val: 3.8359 loss_x_val: 2.8946 loss_a_val: 0.9413 time: 0.4765s
# Epoch: 0156 loss_train: 3.8040 loss_kl_train: 0.1424 loss_x_train: 2.1788 loss_a_train: 1.4828 loss_val: 3.8375 loss_x_val: 2.8797 loss_a_val: 0.9579 time: 0.4755s
# Epoch: 0157 loss_train: 3.7908 loss_kl_train: 0.1434 loss_x_train: 2.1777 loss_a_train: 1.4698 loss_val: 3.8004 loss_x_val: 2.8619 loss_a_val: 0.9386 time: 0.4773s
# Epoch: 0158 loss_train: 3.7827 loss_kl_train: 0.1444 loss_x_train: 2.1766 loss_a_train: 1.4617 loss_val: 3.7514 loss_x_val: 2.8015 loss_a_val: 0.9500 time: 0.4784s
# Epoch: 0159 loss_train: 3.7761 loss_kl_train: 0.1453 loss_x_train: 2.1761 loss_a_train: 1.4546 loss_val: 3.7245 loss_x_val: 2.7921 loss_a_val: 0.9325 time: 0.4721s
# Epoch: 0160 loss_train: 3.7516 loss_kl_train: 0.1463 loss_x_train: 2.1749 loss_a_train: 1.4303 loss_val: 3.6944 loss_x_val: 2.7688 loss_a_val: 0.9256 time: 0.4762s
# Epoch: 0161 loss_train: 3.7351 loss_kl_train: 0.1472 loss_x_train: 2.1751 loss_a_train: 1.4128 loss_val: 3.6905 loss_x_val: 2.7389 loss_a_val: 0.9517 time: 0.4704s
# Epoch: 0162 loss_train: 3.7459 loss_kl_train: 0.1483 loss_x_train: 2.1734 loss_a_train: 1.4242 loss_val: 3.6718 loss_x_val: 2.7493 loss_a_val: 0.9224 time: 0.4772s
# Epoch: 0163 loss_train: 3.7096 loss_kl_train: 0.1492 loss_x_train: 2.1747 loss_a_train: 1.3857 loss_val: 3.6426 loss_x_val: 2.7021 loss_a_val: 0.9405 time: 0.4767s
# Epoch: 0164 loss_train: 3.7183 loss_kl_train: 0.1502 loss_x_train: 2.1715 loss_a_train: 1.3966 loss_val: 3.6296 loss_x_val: 2.7197 loss_a_val: 0.9100 time: 0.4749s
# Epoch: 0165 loss_train: 3.6919 loss_kl_train: 0.1511 loss_x_train: 2.1724 loss_a_train: 1.3683 loss_val: 3.6437 loss_x_val: 2.7117 loss_a_val: 0.9319 time: 0.4751s
# Epoch: 0166 loss_train: 3.7017 loss_kl_train: 0.1521 loss_x_train: 2.1719 loss_a_train: 1.3777 loss_val: 3.6029 loss_x_val: 2.6861 loss_a_val: 0.9168 time: 0.4790s
# Epoch: 0167 loss_train: 3.6863 loss_kl_train: 0.1530 loss_x_train: 2.1715 loss_a_train: 1.3618 loss_val: 3.5754 loss_x_val: 2.6623 loss_a_val: 0.9130 time: 0.4791s
# Epoch: 0168 loss_train: 3.6640 loss_kl_train: 0.1540 loss_x_train: 2.1702 loss_a_train: 1.3398 loss_val: 3.5670 loss_x_val: 2.6559 loss_a_val: 0.9110 time: 0.4727s
# Epoch: 0169 loss_train: 3.6591 loss_kl_train: 0.1549 loss_x_train: 2.1704 loss_a_train: 1.3338 loss_val: 3.5612 loss_x_val: 2.6533 loss_a_val: 0.9079 time: 0.4755s
# Epoch: 0170 loss_train: 3.6501 loss_kl_train: 0.1559 loss_x_train: 2.1696 loss_a_train: 1.3245 loss_val: 3.5486 loss_x_val: 2.6441 loss_a_val: 0.9044 time: 0.4762s
# Epoch: 0171 loss_train: 3.6456 loss_kl_train: 0.1568 loss_x_train: 2.1691 loss_a_train: 1.3197 loss_val: 3.5429 loss_x_val: 2.6388 loss_a_val: 0.9041 time: 0.4741s
# Epoch: 0172 loss_train: 3.6250 loss_kl_train: 0.1578 loss_x_train: 2.1678 loss_a_train: 1.2994 loss_val: 3.5578 loss_x_val: 2.6322 loss_a_val: 0.9255 time: 0.4768s
# Epoch: 0173 loss_train: 3.6620 loss_kl_train: 0.1588 loss_x_train: 2.1679 loss_a_train: 1.3354 loss_val: 3.5188 loss_x_val: 2.6103 loss_a_val: 0.9085 time: 0.4770s
# Epoch: 0174 loss_train: 3.6128 loss_kl_train: 0.1596 loss_x_train: 2.1672 loss_a_train: 1.2861 loss_val: 3.4836 loss_x_val: 2.5856 loss_a_val: 0.8980 time: 0.4763s
# Epoch: 0175 loss_train: 3.6161 loss_kl_train: 0.1605 loss_x_train: 2.1660 loss_a_train: 1.2896 loss_val: 3.4942 loss_x_val: 2.5972 loss_a_val: 0.8970 time: 0.4770s
# Epoch: 0176 loss_train: 3.6032 loss_kl_train: 0.1613 loss_x_train: 2.1664 loss_a_train: 1.2755 loss_val: 3.4674 loss_x_val: 2.5705 loss_a_val: 0.8969 time: 0.4752s
# Epoch: 0177 loss_train: 3.6000 loss_kl_train: 0.1623 loss_x_train: 2.1644 loss_a_train: 1.2734 loss_val: 3.4549 loss_x_val: 2.5642 loss_a_val: 0.8907 time: 0.4690s
# Epoch: 0178 loss_train: 3.5855 loss_kl_train: 0.1632 loss_x_train: 2.1643 loss_a_train: 1.2580 loss_val: 3.4392 loss_x_val: 2.5485 loss_a_val: 0.8907 time: 0.4775s
# Epoch: 0179 loss_train: 3.5791 loss_kl_train: 0.1640 loss_x_train: 2.1633 loss_a_train: 1.2517 loss_val: 3.4241 loss_x_val: 2.5350 loss_a_val: 0.8890 time: 0.4769s
# Epoch: 0180 loss_train: 3.5677 loss_kl_train: 0.1649 loss_x_train: 2.1633 loss_a_train: 1.2394 loss_val: 3.4112 loss_x_val: 2.5220 loss_a_val: 0.8892 time: 0.4757s
# Epoch: 0181 loss_train: 3.5600 loss_kl_train: 0.1657 loss_x_train: 2.1631 loss_a_train: 1.2312 loss_val: 3.3669 loss_x_val: 2.4919 loss_a_val: 0.8750 time: 0.4749s
# Epoch: 0182 loss_train: 3.5559 loss_kl_train: 0.1666 loss_x_train: 2.1624 loss_a_train: 1.2268 loss_val: 3.3861 loss_x_val: 2.5033 loss_a_val: 0.8827 time: 0.4762s
# Epoch: 0183 loss_train: 3.5418 loss_kl_train: 0.1675 loss_x_train: 2.1624 loss_a_train: 1.2120 loss_val: 3.4033 loss_x_val: 2.5045 loss_a_val: 0.8988 time: 0.4772s
# Epoch: 0184 loss_train: 3.5721 loss_kl_train: 0.1684 loss_x_train: 2.1612 loss_a_train: 1.2425 loss_val: 3.3872 loss_x_val: 2.5035 loss_a_val: 0.8837 time: 0.4753s
# Epoch: 0185 loss_train: 3.5309 loss_kl_train: 0.1692 loss_x_train: 2.1617 loss_a_train: 1.2001 loss_val: 3.3726 loss_x_val: 2.4764 loss_a_val: 0.8962 time: 0.4770s
# Epoch: 0186 loss_train: 3.5634 loss_kl_train: 0.1700 loss_x_train: 2.1600 loss_a_train: 1.2334 loss_val: 3.3416 loss_x_val: 2.4586 loss_a_val: 0.8830 time: 0.4766s
# Epoch: 0187 loss_train: 3.5296 loss_kl_train: 0.1708 loss_x_train: 2.1606 loss_a_train: 1.1982 loss_val: 3.3384 loss_x_val: 2.4559 loss_a_val: 0.8825 time: 0.4728s
# Epoch: 0188 loss_train: 3.5333 loss_kl_train: 0.1716 loss_x_train: 2.1600 loss_a_train: 1.2017 loss_val: 3.3310 loss_x_val: 2.4451 loss_a_val: 0.8859 time: 0.4776s
# Epoch: 0189 loss_train: 3.5257 loss_kl_train: 0.1724 loss_x_train: 2.1596 loss_a_train: 1.1938 loss_val: 3.3212 loss_x_val: 2.4457 loss_a_val: 0.8755 time: 0.4773s
# Epoch: 0190 loss_train: 3.5123 loss_kl_train: 0.1731 loss_x_train: 2.1587 loss_a_train: 1.1805 loss_val: 3.3094 loss_x_val: 2.4312 loss_a_val: 0.8782 time: 0.4819s
# Epoch: 0191 loss_train: 3.5138 loss_kl_train: 0.1739 loss_x_train: 2.1578 loss_a_train: 1.1820 loss_val: 3.3204 loss_x_val: 2.4286 loss_a_val: 0.8918 time: 0.4766s
# Epoch: 0192 loss_train: 3.5131 loss_kl_train: 0.1747 loss_x_train: 2.1573 loss_a_train: 1.1811 loss_val: 3.3082 loss_x_val: 2.4211 loss_a_val: 0.8871 time: 0.4770s
# Epoch: 0193 loss_train: 3.5102 loss_kl_train: 0.1755 loss_x_train: 2.1578 loss_a_train: 1.1768 loss_val: 3.3082 loss_x_val: 2.4100 loss_a_val: 0.8983 time: 0.4787s
# Epoch: 0194 loss_train: 3.5312 loss_kl_train: 0.1763 loss_x_train: 2.1567 loss_a_train: 1.1983 loss_val: 3.3189 loss_x_val: 2.4241 loss_a_val: 0.8948 time: 0.4808s
# Epoch: 0195 loss_train: 3.5079 loss_kl_train: 0.1769 loss_x_train: 2.1577 loss_a_train: 1.1732 loss_val: 3.3842 loss_x_val: 2.4220 loss_a_val: 0.9622 time: 0.4831s
# Epoch: 0196 loss_train: 3.5946 loss_kl_train: 0.1777 loss_x_train: 2.1555 loss_a_train: 1.2614 loss_val: 3.2905 loss_x_val: 2.3967 loss_a_val: 0.8937 time: 0.4799s
# Epoch: 0197 loss_train: 3.5052 loss_kl_train: 0.1783 loss_x_train: 2.1571 loss_a_train: 1.1698 loss_val: 3.2651 loss_x_val: 2.3706 loss_a_val: 0.8946 time: 0.4741s
# Epoch: 0198 loss_train: 3.5103 loss_kl_train: 0.1791 loss_x_train: 2.1547 loss_a_train: 1.1766 loss_val: 3.2640 loss_x_val: 2.3724 loss_a_val: 0.8916 time: 0.4737s
# Epoch: 0199 loss_train: 3.5038 loss_kl_train: 0.1797 loss_x_train: 2.1561 loss_a_train: 1.1680 loss_val: 3.2594 loss_x_val: 2.3603 loss_a_val: 0.8991 time: 0.4760s
# Epoch: 0200 loss_train: 3.5056 loss_kl_train: 0.1804 loss_x_train: 2.1540 loss_a_train: 1.1713 loss_val: 3.2665 loss_x_val: 2.3601 loss_a_val: 0.9064 time: 0.4764s
# Epoch: 0201 loss_train: 3.5040 loss_kl_train: 0.1810 loss_x_train: 2.1547 loss_a_train: 1.1683 loss_val: 3.2606 loss_x_val: 2.3625 loss_a_val: 0.8981 time: 0.4746s
# Epoch: 0202 loss_train: 3.5068 loss_kl_train: 0.1816 loss_x_train: 2.1542 loss_a_train: 1.1710 loss_val: 3.2649 loss_x_val: 2.3642 loss_a_val: 0.9007 time: 0.4759s
# Epoch: 0203 loss_train: 3.4962 loss_kl_train: 0.1823 loss_x_train: 2.1539 loss_a_train: 1.1600 loss_val: 3.2602 loss_x_val: 2.3623 loss_a_val: 0.8979 time: 0.4760s
# Epoch: 0204 loss_train: 3.4966 loss_kl_train: 0.1829 loss_x_train: 2.1531 loss_a_train: 1.1606 loss_val: 3.2489 loss_x_val: 2.3506 loss_a_val: 0.8983 time: 0.4778s
# Epoch: 0205 loss_train: 3.5003 loss_kl_train: 0.1835 loss_x_train: 2.1533 loss_a_train: 1.1636 loss_val: 3.2345 loss_x_val: 2.3400 loss_a_val: 0.8945 time: 0.4768s
# Epoch: 0206 loss_train: 3.4867 loss_kl_train: 0.1842 loss_x_train: 2.1521 loss_a_train: 1.1505 loss_val: 3.2309 loss_x_val: 2.3344 loss_a_val: 0.8964 time: 0.4723s
# Epoch: 0207 loss_train: 3.4796 loss_kl_train: 0.1847 loss_x_train: 2.1511 loss_a_train: 1.1438 loss_val: 3.2266 loss_x_val: 2.3310 loss_a_val: 0.8957 time: 0.4745s
# Epoch: 0208 loss_train: 3.4781 loss_kl_train: 0.1854 loss_x_train: 2.1509 loss_a_train: 1.1418 loss_val: 3.2280 loss_x_val: 2.3333 loss_a_val: 0.8947 time: 0.4769s
# Epoch: 0209 loss_train: 3.4720 loss_kl_train: 0.1859 loss_x_train: 2.1508 loss_a_train: 1.1353 loss_val: 3.2196 loss_x_val: 2.3338 loss_a_val: 0.8858 time: 0.4764s
# Epoch: 0210 loss_train: 3.4668 loss_kl_train: 0.1866 loss_x_train: 2.1514 loss_a_train: 1.1288 loss_val: 3.2197 loss_x_val: 2.3328 loss_a_val: 0.8869 time: 0.4798s
# Epoch: 0211 loss_train: 3.4631 loss_kl_train: 0.1871 loss_x_train: 2.1502 loss_a_train: 1.1258 loss_val: 3.2046 loss_x_val: 2.3200 loss_a_val: 0.8845 time: 0.4769s
# Epoch: 0212 loss_train: 3.4572 loss_kl_train: 0.1877 loss_x_train: 2.1497 loss_a_train: 1.1199 loss_val: 3.2051 loss_x_val: 2.3253 loss_a_val: 0.8799 time: 0.4778s
# Epoch: 0213 loss_train: 3.4513 loss_kl_train: 0.1882 loss_x_train: 2.1502 loss_a_train: 1.1129 loss_val: 3.2023 loss_x_val: 2.3196 loss_a_val: 0.8827 time: 0.4808s
# Epoch: 0214 loss_train: 3.4556 loss_kl_train: 0.1888 loss_x_train: 2.1490 loss_a_train: 1.1178 loss_val: 3.2010 loss_x_val: 2.3198 loss_a_val: 0.8812 time: 0.4843s
# Epoch: 0215 loss_train: 3.4431 loss_kl_train: 0.1893 loss_x_train: 2.1498 loss_a_train: 1.1041 loss_val: 3.1848 loss_x_val: 2.3109 loss_a_val: 0.8740 time: 0.4780s
# Epoch: 0216 loss_train: 3.4447 loss_kl_train: 0.1898 loss_x_train: 2.1482 loss_a_train: 1.1067 loss_val: 3.1799 loss_x_val: 2.3084 loss_a_val: 0.8715 time: 0.4734s
# Epoch: 0217 loss_train: 3.4299 loss_kl_train: 0.1903 loss_x_train: 2.1482 loss_a_train: 1.0913 loss_val: 3.1732 loss_x_val: 2.3083 loss_a_val: 0.8649 time: 0.4742s
# Epoch: 0218 loss_train: 3.4354 loss_kl_train: 0.1909 loss_x_train: 2.1480 loss_a_train: 1.0966 loss_val: 3.1762 loss_x_val: 2.3086 loss_a_val: 0.8676 time: 0.4786s
# Epoch: 0219 loss_train: 3.4231 loss_kl_train: 0.1915 loss_x_train: 2.1482 loss_a_train: 1.0835 loss_val: 3.1609 loss_x_val: 2.2997 loss_a_val: 0.8612 time: 0.4742s
# Epoch: 0220 loss_train: 3.4192 loss_kl_train: 0.1920 loss_x_train: 2.1468 loss_a_train: 1.0804 loss_val: 3.1560 loss_x_val: 2.2967 loss_a_val: 0.8592 time: 0.4767s
# Epoch: 0221 loss_train: 3.4067 loss_kl_train: 0.1925 loss_x_train: 2.1472 loss_a_train: 1.0669 loss_val: 3.1465 loss_x_val: 2.2908 loss_a_val: 0.8557 time: 0.4760s
# Epoch: 0222 loss_train: 3.4103 loss_kl_train: 0.1930 loss_x_train: 2.1464 loss_a_train: 1.0709 loss_val: 3.1452 loss_x_val: 2.2913 loss_a_val: 0.8539 time: 0.4756s
# Epoch: 0223 loss_train: 3.3950 loss_kl_train: 0.1935 loss_x_train: 2.1464 loss_a_train: 1.0551 loss_val: 3.1302 loss_x_val: 2.2833 loss_a_val: 0.8469 time: 0.4760s
# Epoch: 0224 loss_train: 3.3900 loss_kl_train: 0.1941 loss_x_train: 2.1456 loss_a_train: 1.0503 loss_val: 3.1271 loss_x_val: 2.2813 loss_a_val: 0.8458 time: 0.4751s
# Epoch: 0225 loss_train: 3.3887 loss_kl_train: 0.1946 loss_x_train: 2.1460 loss_a_train: 1.0480 loss_val: 3.1337 loss_x_val: 2.2830 loss_a_val: 0.8507 time: 0.4749s
# Epoch: 0226 loss_train: 3.3926 loss_kl_train: 0.1951 loss_x_train: 2.1457 loss_a_train: 1.0518 loss_val: 3.1251 loss_x_val: 2.2756 loss_a_val: 0.8494 time: 0.4743s
# Epoch: 0227 loss_train: 3.3891 loss_kl_train: 0.1956 loss_x_train: 2.1454 loss_a_train: 1.0481 loss_val: 3.1189 loss_x_val: 2.2743 loss_a_val: 0.8446 time: 0.4774s
# Epoch: 0228 loss_train: 3.3910 loss_kl_train: 0.1961 loss_x_train: 2.1452 loss_a_train: 1.0497 loss_val: 3.1163 loss_x_val: 2.2701 loss_a_val: 0.8462 time: 0.4779s
# Epoch: 0229 loss_train: 3.3768 loss_kl_train: 0.1965 loss_x_train: 2.1451 loss_a_train: 1.0352 loss_val: 3.1070 loss_x_val: 2.2666 loss_a_val: 0.8404 time: 0.4803s
# Epoch: 0230 loss_train: 3.3748 loss_kl_train: 0.1971 loss_x_train: 2.1438 loss_a_train: 1.0339 loss_val: 3.1147 loss_x_val: 2.2672 loss_a_val: 0.8476 time: 0.4790s
# Epoch: 0231 loss_train: 3.3705 loss_kl_train: 0.1975 loss_x_train: 2.1440 loss_a_train: 1.0290 loss_val: 3.0978 loss_x_val: 2.2606 loss_a_val: 0.8372 time: 0.4750s
# Epoch: 0232 loss_train: 3.3839 loss_kl_train: 0.1981 loss_x_train: 2.1444 loss_a_train: 1.0415 loss_val: 3.1146 loss_x_val: 2.2582 loss_a_val: 0.8564 time: 0.4795s
# Epoch: 0233 loss_train: 3.3713 loss_kl_train: 0.1985 loss_x_train: 2.1436 loss_a_train: 1.0292 loss_val: 3.1082 loss_x_val: 2.2557 loss_a_val: 0.8525 time: 0.4814s
# Epoch: 0234 loss_train: 3.3741 loss_kl_train: 0.1990 loss_x_train: 2.1430 loss_a_train: 1.0322 loss_val: 3.0916 loss_x_val: 2.2517 loss_a_val: 0.8398 time: 0.4778s
# Epoch: 0235 loss_train: 3.3762 loss_kl_train: 0.1994 loss_x_train: 2.1431 loss_a_train: 1.0336 loss_val: 3.1001 loss_x_val: 2.2516 loss_a_val: 0.8484 time: 0.4736s
# Epoch: 0236 loss_train: 3.3703 loss_kl_train: 0.1999 loss_x_train: 2.1424 loss_a_train: 1.0280 loss_val: 3.1020 loss_x_val: 2.2511 loss_a_val: 0.8509 time: 0.4759s
# Epoch: 0237 loss_train: 3.3762 loss_kl_train: 0.2004 loss_x_train: 2.1419 loss_a_train: 1.0339 loss_val: 3.1023 loss_x_val: 2.2495 loss_a_val: 0.8528 time: 0.4776s
# Epoch: 0238 loss_train: 3.3769 loss_kl_train: 0.2009 loss_x_train: 2.1424 loss_a_train: 1.0335 loss_val: 3.0994 loss_x_val: 2.2474 loss_a_val: 0.8519 time: 0.4744s
# Epoch: 0239 loss_train: 3.3659 loss_kl_train: 0.2013 loss_x_train: 2.1425 loss_a_train: 1.0221 loss_val: 3.0892 loss_x_val: 2.2386 loss_a_val: 0.8506 time: 0.4773s
# Epoch: 0240 loss_train: 3.3712 loss_kl_train: 0.2019 loss_x_train: 2.1409 loss_a_train: 1.0284 loss_val: 3.0955 loss_x_val: 2.2444 loss_a_val: 0.8512 time: 0.4752s
# Epoch: 0241 loss_train: 3.3639 loss_kl_train: 0.2022 loss_x_train: 2.1419 loss_a_train: 1.0198 loss_val: 3.0940 loss_x_val: 2.2413 loss_a_val: 0.8527 time: 0.4703s
# Epoch: 0242 loss_train: 3.3733 loss_kl_train: 0.2027 loss_x_train: 2.1407 loss_a_train: 1.0299 loss_val: 3.0980 loss_x_val: 2.2394 loss_a_val: 0.8585 time: 0.4774s
# Epoch: 0243 loss_train: 3.3604 loss_kl_train: 0.2031 loss_x_train: 2.1414 loss_a_train: 1.0159 loss_val: 3.0825 loss_x_val: 2.2358 loss_a_val: 0.8467 time: 0.4785s
# Epoch: 0244 loss_train: 3.3701 loss_kl_train: 0.2035 loss_x_train: 2.1404 loss_a_train: 1.0261 loss_val: 3.1006 loss_x_val: 2.2367 loss_a_val: 0.8639 time: 0.4750s
# Epoch: 0245 loss_train: 3.3689 loss_kl_train: 0.2040 loss_x_train: 2.1413 loss_a_train: 1.0236 loss_val: 3.0858 loss_x_val: 2.2304 loss_a_val: 0.8555 time: 0.4729s
# Epoch: 0246 loss_train: 3.3726 loss_kl_train: 0.2044 loss_x_train: 2.1401 loss_a_train: 1.0281 loss_val: 3.0827 loss_x_val: 2.2278 loss_a_val: 0.8549 time: 0.4777s
# Epoch: 0247 loss_train: 3.3569 loss_kl_train: 0.2048 loss_x_train: 2.1403 loss_a_train: 1.0118 loss_val: 3.0761 loss_x_val: 2.2228 loss_a_val: 0.8534 time: 0.4769s
# Epoch: 0248 loss_train: 3.3620 loss_kl_train: 0.2053 loss_x_train: 2.1394 loss_a_train: 1.0173 loss_val: 3.0850 loss_x_val: 2.2233 loss_a_val: 0.8617 time: 0.4759s
# Epoch: 0249 loss_train: 3.3581 loss_kl_train: 0.2056 loss_x_train: 2.1399 loss_a_train: 1.0126 loss_val: 3.0848 loss_x_val: 2.2212 loss_a_val: 0.8636 time: 0.4745s
# Epoch: 0250 loss_train: 3.3625 loss_kl_train: 0.2060 loss_x_train: 2.1393 loss_a_train: 1.0172 loss_val: 3.0732 loss_x_val: 2.2185 loss_a_val: 0.8546 time: 0.4716s
# Epoch: 0251 loss_train: 3.3589 loss_kl_train: 0.2063 loss_x_train: 2.1391 loss_a_train: 1.0135 loss_val: 3.0709 loss_x_val: 2.2195 loss_a_val: 0.8514 time: 0.4757s
# Epoch: 0252 loss_train: 3.3567 loss_kl_train: 0.2067 loss_x_train: 2.1392 loss_a_train: 1.0107 loss_val: 3.0722 loss_x_val: 2.2197 loss_a_val: 0.8525 time: 0.4785s
# Epoch: 0253 loss_train: 3.3526 loss_kl_train: 0.2071 loss_x_train: 2.1388 loss_a_train: 1.0068 loss_val: 3.0812 loss_x_val: 2.2209 loss_a_val: 0.8603 time: 0.4753s
# Epoch: 0254 loss_train: 3.3530 loss_kl_train: 0.2074 loss_x_train: 2.1384 loss_a_train: 1.0072 loss_val: 3.0769 loss_x_val: 2.2180 loss_a_val: 0.8589 time: 0.4737s
# Epoch: 0255 loss_train: 3.3446 loss_kl_train: 0.2077 loss_x_train: 2.1376 loss_a_train: 0.9993 loss_val: 3.0595 loss_x_val: 2.2125 loss_a_val: 0.8471 time: 0.4782s
# Epoch: 0256 loss_train: 3.3494 loss_kl_train: 0.2081 loss_x_train: 2.1375 loss_a_train: 1.0038 loss_val: 3.0674 loss_x_val: 2.2116 loss_a_val: 0.8558 time: 0.4788s
# Epoch: 0257 loss_train: 3.3450 loss_kl_train: 0.2085 loss_x_train: 2.1379 loss_a_train: 0.9987 loss_val: 3.0576 loss_x_val: 2.2096 loss_a_val: 0.8480 time: 0.4816s
# Epoch: 0258 loss_train: 3.3346 loss_kl_train: 0.2087 loss_x_train: 2.1374 loss_a_train: 0.9886 loss_val: 3.0486 loss_x_val: 2.2063 loss_a_val: 0.8423 time: 0.4826s
# Epoch: 0259 loss_train: 3.3329 loss_kl_train: 0.2092 loss_x_train: 2.1370 loss_a_train: 0.9867 loss_val: 3.0478 loss_x_val: 2.2068 loss_a_val: 0.8411 time: 0.4796s
# Epoch: 0260 loss_train: 3.3308 loss_kl_train: 0.2094 loss_x_train: 2.1372 loss_a_train: 0.9842 loss_val: 3.0463 loss_x_val: 2.2059 loss_a_val: 0.8404 time: 0.4705s
# Epoch: 0261 loss_train: 3.3295 loss_kl_train: 0.2097 loss_x_train: 2.1365 loss_a_train: 0.9833 loss_val: 3.0485 loss_x_val: 2.2079 loss_a_val: 0.8405 time: 0.4770s
# Epoch: 0262 loss_train: 3.3256 loss_kl_train: 0.2101 loss_x_train: 2.1366 loss_a_train: 0.9789 loss_val: 3.0400 loss_x_val: 2.2056 loss_a_val: 0.8344 time: 0.4787s
# Epoch: 0263 loss_train: 3.3142 loss_kl_train: 0.2104 loss_x_train: 2.1369 loss_a_train: 0.9670 loss_val: 3.0322 loss_x_val: 2.2033 loss_a_val: 0.8289 time: 0.4793s
# Epoch: 0264 loss_train: 3.3117 loss_kl_train: 0.2107 loss_x_train: 2.1362 loss_a_train: 0.9648 loss_val: 3.0271 loss_x_val: 2.2018 loss_a_val: 0.8253 time: 0.4797s
# Epoch: 0265 loss_train: 3.3040 loss_kl_train: 0.2110 loss_x_train: 2.1366 loss_a_train: 0.9563 loss_val: 3.0249 loss_x_val: 2.2006 loss_a_val: 0.8242 time: 0.4827s
# Epoch: 0266 loss_train: 3.3038 loss_kl_train: 0.2114 loss_x_train: 2.1352 loss_a_train: 0.9572 loss_val: 3.0265 loss_x_val: 2.1998 loss_a_val: 0.8267 time: 0.4830s
# Epoch: 0267 loss_train: 3.2967 loss_kl_train: 0.2116 loss_x_train: 2.1365 loss_a_train: 0.9486 loss_val: 3.0164 loss_x_val: 2.1945 loss_a_val: 0.8219 time: 0.4831s
# Epoch: 0268 loss_train: 3.3070 loss_kl_train: 0.2120 loss_x_train: 2.1345 loss_a_train: 0.9605 loss_val: 3.0194 loss_x_val: 2.1941 loss_a_val: 0.8253 time: 0.4827s
# Epoch: 0269 loss_train: 3.2899 loss_kl_train: 0.2123 loss_x_train: 2.1357 loss_a_train: 0.9419 loss_val: 3.0038 loss_x_val: 2.1913 loss_a_val: 0.8126 time: 0.4820s
# Epoch: 0270 loss_train: 3.2887 loss_kl_train: 0.2126 loss_x_train: 2.1345 loss_a_train: 0.9416 loss_val: 3.0132 loss_x_val: 2.1930 loss_a_val: 0.8202 time: 0.4810s
# Epoch: 0271 loss_train: 3.2894 loss_kl_train: 0.2129 loss_x_train: 2.1354 loss_a_train: 0.9410 loss_val: 3.0021 loss_x_val: 2.1930 loss_a_val: 0.8090 time: 0.4767s
# Epoch: 0272 loss_train: 3.2858 loss_kl_train: 0.2133 loss_x_train: 2.1345 loss_a_train: 0.9379 loss_val: 3.0137 loss_x_val: 2.1939 loss_a_val: 0.8198 time: 0.4815s
# Epoch: 0273 loss_train: 3.2801 loss_kl_train: 0.2136 loss_x_train: 2.1358 loss_a_train: 0.9308 loss_val: 3.0002 loss_x_val: 2.1898 loss_a_val: 0.8103 time: 0.4815s
# Epoch: 0274 loss_train: 3.2834 loss_kl_train: 0.2139 loss_x_train: 2.1340 loss_a_train: 0.9355 loss_val: 3.0024 loss_x_val: 2.1883 loss_a_val: 0.8142 time: 0.4824s
# Epoch: 0275 loss_train: 3.2756 loss_kl_train: 0.2142 loss_x_train: 2.1347 loss_a_train: 0.9268 loss_val: 2.9889 loss_x_val: 2.1836 loss_a_val: 0.8053 time: 0.4815s
# Epoch: 0276 loss_train: 3.2724 loss_kl_train: 0.2146 loss_x_train: 2.1337 loss_a_train: 0.9241 loss_val: 2.9954 loss_x_val: 2.1844 loss_a_val: 0.8111 time: 0.4780s
# Epoch: 0277 loss_train: 3.2729 loss_kl_train: 0.2148 loss_x_train: 2.1337 loss_a_train: 0.9244 loss_val: 2.9874 loss_x_val: 2.1848 loss_a_val: 0.8026 time: 0.4747s
# Epoch: 0278 loss_train: 3.2653 loss_kl_train: 0.2152 loss_x_train: 2.1339 loss_a_train: 0.9162 loss_val: 2.9905 loss_x_val: 2.1851 loss_a_val: 0.8054 time: 0.4740s
# Epoch: 0279 loss_train: 3.2685 loss_kl_train: 0.2155 loss_x_train: 2.1338 loss_a_train: 0.9192 loss_val: 2.9942 loss_x_val: 2.1835 loss_a_val: 0.8107 time: 0.4773s
# Epoch: 0280 loss_train: 3.2629 loss_kl_train: 0.2159 loss_x_train: 2.1330 loss_a_train: 0.9141 loss_val: 2.9844 loss_x_val: 2.1831 loss_a_val: 0.8012 time: 0.4758s
# Epoch: 0281 loss_train: 3.2683 loss_kl_train: 0.2162 loss_x_train: 2.1335 loss_a_train: 0.9185 loss_val: 2.9802 loss_x_val: 2.1810 loss_a_val: 0.7992 time: 0.4716s
# Epoch: 0282 loss_train: 3.2579 loss_kl_train: 0.2166 loss_x_train: 2.1331 loss_a_train: 0.9082 loss_val: 2.9893 loss_x_val: 2.1813 loss_a_val: 0.8079 time: 0.4786s
# Epoch: 0283 loss_train: 3.2590 loss_kl_train: 0.2168 loss_x_train: 2.1330 loss_a_train: 0.9092 loss_val: 2.9734 loss_x_val: 2.1801 loss_a_val: 0.7933 time: 0.4790s
# Epoch: 0284 loss_train: 3.2589 loss_kl_train: 0.2173 loss_x_train: 2.1319 loss_a_train: 0.9097 loss_val: 2.9827 loss_x_val: 2.1806 loss_a_val: 0.8022 time: 0.4823s
# Epoch: 0285 loss_train: 3.2532 loss_kl_train: 0.2175 loss_x_train: 2.1339 loss_a_train: 0.9018 loss_val: 2.9785 loss_x_val: 2.1774 loss_a_val: 0.8010 time: 0.4802s
# Epoch: 0286 loss_train: 3.2619 loss_kl_train: 0.2179 loss_x_train: 2.1312 loss_a_train: 0.9127 loss_val: 2.9782 loss_x_val: 2.1782 loss_a_val: 0.8000 time: 0.4755s
# Epoch: 0287 loss_train: 3.2528 loss_kl_train: 0.2181 loss_x_train: 2.1335 loss_a_train: 0.9012 loss_val: 2.9636 loss_x_val: 2.1745 loss_a_val: 0.7890 time: 0.4749s
# Epoch: 0288 loss_train: 3.2520 loss_kl_train: 0.2185 loss_x_train: 2.1319 loss_a_train: 0.9017 loss_val: 2.9665 loss_x_val: 2.1725 loss_a_val: 0.7940 time: 0.4755s
# Epoch: 0289 loss_train: 3.2436 loss_kl_train: 0.2188 loss_x_train: 2.1317 loss_a_train: 0.8932 loss_val: 2.9632 loss_x_val: 2.1726 loss_a_val: 0.7907 time: 0.4763s
# Epoch: 0290 loss_train: 3.2473 loss_kl_train: 0.2190 loss_x_train: 2.1316 loss_a_train: 0.8967 loss_val: 2.9565 loss_x_val: 2.1697 loss_a_val: 0.7868 time: 0.4762s
# Epoch: 0291 loss_train: 3.2449 loss_kl_train: 0.2194 loss_x_train: 2.1309 loss_a_train: 0.8946 loss_val: 2.9792 loss_x_val: 2.1713 loss_a_val: 0.8079 time: 0.4768s
# ...
# Epoch: 4903 loss_train: 2.7125 loss_kl_train: 0.2373 loss_x_train: 2.0573 loss_a_train: 0.4180 loss_val: 2.5148 loss_x_val: 2.1578 loss_a_val: 0.3570 time: 0.4778s
# Epoch: 4904 loss_train: 2.7129 loss_kl_train: 0.2373 loss_x_train: 2.0576 loss_a_train: 0.4180 loss_val: 2.5143 loss_x_val: 2.1576 loss_a_val: 0.3567 time: 0.4803s
# Epoch: 4905 loss_train: 2.7114 loss_kl_train: 0.2369 loss_x_train: 2.0574 loss_a_train: 0.4171 loss_val: 2.5142 loss_x_val: 2.1578 loss_a_val: 0.3563 time: 0.4813s
# Epoch: 4906 loss_train: 2.7118 loss_kl_train: 0.2368 loss_x_train: 2.0571 loss_a_train: 0.4179 loss_val: 2.5140 loss_x_val: 2.1577 loss_a_val: 0.3563 time: 0.4801s
# Epoch: 4907 loss_train: 2.7109 loss_kl_train: 0.2370 loss_x_train: 2.0572 loss_a_train: 0.4167 loss_val: 2.5136 loss_x_val: 2.1571 loss_a_val: 0.3566 time: 0.4765s
# Epoch: 4908 loss_train: 2.7121 loss_kl_train: 0.2370 loss_x_train: 2.0576 loss_a_train: 0.4175 loss_val: 2.5141 loss_x_val: 2.1577 loss_a_val: 0.3563 time: 0.4755s
# Epoch: 4909 loss_train: 2.7114 loss_kl_train: 0.2370 loss_x_train: 2.0574 loss_a_train: 0.4170 loss_val: 2.5139 loss_x_val: 2.1581 loss_a_val: 0.3558 time: 0.4789s
# Epoch: 4910 loss_train: 2.7105 loss_kl_train: 0.2373 loss_x_train: 2.0570 loss_a_train: 0.4162 loss_val: 2.5138 loss_x_val: 2.1576 loss_a_val: 0.3562 time: 0.4776s
# Epoch: 4911 loss_train: 2.7116 loss_kl_train: 0.2375 loss_x_train: 2.0573 loss_a_train: 0.4168 loss_val: 2.5138 loss_x_val: 2.1577 loss_a_val: 0.3561 time: 0.4751s
# Epoch: 4912 loss_train: 2.7106 loss_kl_train: 0.2375 loss_x_train: 2.0576 loss_a_train: 0.4155 loss_val: 2.5139 loss_x_val: 2.1580 loss_a_val: 0.3559 time: 0.4742s
# Epoch: 4913 loss_train: 2.7112 loss_kl_train: 0.2374 loss_x_train: 2.0573 loss_a_train: 0.4165 loss_val: 2.5140 loss_x_val: 2.1581 loss_a_val: 0.3559 time: 0.4740s
# Epoch: 4914 loss_train: 2.7115 loss_kl_train: 0.2374 loss_x_train: 2.0572 loss_a_train: 0.4169 loss_val: 2.5143 loss_x_val: 2.1579 loss_a_val: 0.3564 time: 0.4786s
# Epoch: 4915 loss_train: 2.7118 loss_kl_train: 0.2376 loss_x_train: 2.0572 loss_a_train: 0.4170 loss_val: 2.5139 loss_x_val: 2.1573 loss_a_val: 0.3566 time: 0.4801s
# Epoch: 4916 loss_train: 2.7117 loss_kl_train: 0.2374 loss_x_train: 2.0574 loss_a_train: 0.4170 loss_val: 2.5143 loss_x_val: 2.1576 loss_a_val: 0.3566 time: 0.4812s
# Epoch: 4917 loss_train: 2.7120 loss_kl_train: 0.2374 loss_x_train: 2.0576 loss_a_train: 0.4171 loss_val: 2.5150 loss_x_val: 2.1585 loss_a_val: 0.3564 time: 0.4756s
# Epoch: 4918 loss_train: 2.7115 loss_kl_train: 0.2373 loss_x_train: 2.0571 loss_a_train: 0.4171 loss_val: 2.5154 loss_x_val: 2.1584 loss_a_val: 0.3570 time: 0.4761s
# Epoch: 4919 loss_train: 2.7116 loss_kl_train: 0.2372 loss_x_train: 2.0571 loss_a_train: 0.4173 loss_val: 2.5160 loss_x_val: 2.1579 loss_a_val: 0.3581 time: 0.4763s
# Epoch: 4920 loss_train: 2.7131 loss_kl_train: 0.2370 loss_x_train: 2.0576 loss_a_train: 0.4184 loss_val: 2.5156 loss_x_val: 2.1582 loss_a_val: 0.3574 time: 0.4787s
# Epoch: 4921 loss_train: 2.7119 loss_kl_train: 0.2367 loss_x_train: 2.0573 loss_a_train: 0.4179 loss_val: 2.5159 loss_x_val: 2.1588 loss_a_val: 0.3571 time: 0.4758s
# Epoch: 4922 loss_train: 2.7137 loss_kl_train: 0.2370 loss_x_train: 2.0572 loss_a_train: 0.4195 loss_val: 2.5157 loss_x_val: 2.1582 loss_a_val: 0.3575 time: 0.4760s
# Epoch: 4923 loss_train: 2.7125 loss_kl_train: 0.2372 loss_x_train: 2.0573 loss_a_train: 0.4180 loss_val: 2.5158 loss_x_val: 2.1577 loss_a_val: 0.3582 time: 0.4731s
# Epoch: 4924 loss_train: 2.7130 loss_kl_train: 0.2372 loss_x_train: 2.0576 loss_a_train: 0.4181 loss_val: 2.5164 loss_x_val: 2.1583 loss_a_val: 0.3582 time: 0.4780s
# Epoch: 4925 loss_train: 2.7128 loss_kl_train: 0.2373 loss_x_train: 2.0571 loss_a_train: 0.4184 loss_val: 2.5168 loss_x_val: 2.1586 loss_a_val: 0.3582 time: 0.4815s
# Epoch: 4926 loss_train: 2.7136 loss_kl_train: 0.2372 loss_x_train: 2.0571 loss_a_train: 0.4192 loss_val: 2.5164 loss_x_val: 2.1580 loss_a_val: 0.3584 time: 0.4800s
# Epoch: 4927 loss_train: 2.7142 loss_kl_train: 0.2371 loss_x_train: 2.0574 loss_a_train: 0.4196 loss_val: 2.5159 loss_x_val: 2.1574 loss_a_val: 0.3585 time: 0.4739s
# Epoch: 4928 loss_train: 2.7134 loss_kl_train: 0.2368 loss_x_train: 2.0574 loss_a_train: 0.4192 loss_val: 2.5158 loss_x_val: 2.1574 loss_a_val: 0.3584 time: 0.4756s
# Epoch: 4929 loss_train: 2.7133 loss_kl_train: 0.2368 loss_x_train: 2.0571 loss_a_train: 0.4194 loss_val: 2.5159 loss_x_val: 2.1577 loss_a_val: 0.3583 time: 0.4776s
# Epoch: 4930 loss_train: 2.7130 loss_kl_train: 0.2368 loss_x_train: 2.0571 loss_a_train: 0.4191 loss_val: 2.5162 loss_x_val: 2.1579 loss_a_val: 0.3583 time: 0.4746s
# Epoch: 4931 loss_train: 2.7136 loss_kl_train: 0.2370 loss_x_train: 2.0575 loss_a_train: 0.4191 loss_val: 2.5164 loss_x_val: 2.1583 loss_a_val: 0.3581 time: 0.4717s
# Epoch: 4932 loss_train: 2.7129 loss_kl_train: 0.2373 loss_x_train: 2.0571 loss_a_train: 0.4185 loss_val: 2.5161 loss_x_val: 2.1581 loss_a_val: 0.3580 time: 0.4772s
# Epoch: 4933 loss_train: 2.7125 loss_kl_train: 0.2371 loss_x_train: 2.0575 loss_a_train: 0.4178 loss_val: 2.5158 loss_x_val: 2.1579 loss_a_val: 0.3578 time: 0.4752s
# Epoch: 4934 loss_train: 2.7130 loss_kl_train: 0.2371 loss_x_train: 2.0575 loss_a_train: 0.4184 loss_val: 2.5155 loss_x_val: 2.1580 loss_a_val: 0.3575 time: 0.4796s
# Epoch: 4935 loss_train: 2.7122 loss_kl_train: 0.2371 loss_x_train: 2.0574 loss_a_train: 0.4177 loss_val: 2.5152 loss_x_val: 2.1580 loss_a_val: 0.3572 time: 0.4812s
# Epoch: 4936 loss_train: 2.7120 loss_kl_train: 0.2370 loss_x_train: 2.0571 loss_a_train: 0.4179 loss_val: 2.5148 loss_x_val: 2.1578 loss_a_val: 0.3570 time: 0.4796s
# Epoch: 4937 loss_train: 2.7113 loss_kl_train: 0.2368 loss_x_train: 2.0570 loss_a_train: 0.4175 loss_val: 2.5145 loss_x_val: 2.1578 loss_a_val: 0.3567 time: 0.4715s
# Epoch: 4938 loss_train: 2.7123 loss_kl_train: 0.2368 loss_x_train: 2.0574 loss_a_train: 0.4181 loss_val: 2.5143 loss_x_val: 2.1580 loss_a_val: 0.3564 time: 0.4776s
# Epoch: 4939 loss_train: 2.7116 loss_kl_train: 0.2369 loss_x_train: 2.0571 loss_a_train: 0.4177 loss_val: 2.5142 loss_x_val: 2.1576 loss_a_val: 0.3565 time: 0.4786s
# Epoch: 4940 loss_train: 2.7123 loss_kl_train: 0.2366 loss_x_train: 2.0574 loss_a_train: 0.4183 loss_val: 2.5142 loss_x_val: 2.1578 loss_a_val: 0.3565 time: 0.4808s
# Epoch: 4941 loss_train: 2.7111 loss_kl_train: 0.2369 loss_x_train: 2.0574 loss_a_train: 0.4168 loss_val: 2.5147 loss_x_val: 2.1582 loss_a_val: 0.3566 time: 0.4754s
# Epoch: 4942 loss_train: 2.7115 loss_kl_train: 0.2372 loss_x_train: 2.0574 loss_a_train: 0.4169 loss_val: 2.5150 loss_x_val: 2.1580 loss_a_val: 0.3569 time: 0.4760s
# Epoch: 4943 loss_train: 2.7111 loss_kl_train: 0.2372 loss_x_train: 2.0573 loss_a_train: 0.4165 loss_val: 2.5150 loss_x_val: 2.1579 loss_a_val: 0.3571 time: 0.4749s
# Epoch: 4944 loss_train: 2.7107 loss_kl_train: 0.2371 loss_x_train: 2.0573 loss_a_train: 0.4164 loss_val: 2.5151 loss_x_val: 2.1581 loss_a_val: 0.3569 time: 0.4740s
# Epoch: 4945 loss_train: 2.7112 loss_kl_train: 0.2373 loss_x_train: 2.0570 loss_a_train: 0.4168 loss_val: 2.5153 loss_x_val: 2.1587 loss_a_val: 0.3565 time: 0.4762s
# Epoch: 4946 loss_train: 2.7115 loss_kl_train: 0.2372 loss_x_train: 2.0573 loss_a_train: 0.4170 loss_val: 2.5150 loss_x_val: 2.1587 loss_a_val: 0.3563 time: 0.4782s
# Epoch: 4947 loss_train: 2.7114 loss_kl_train: 0.2371 loss_x_train: 2.0571 loss_a_train: 0.4172 loss_val: 2.5144 loss_x_val: 2.1581 loss_a_val: 0.3563 time: 0.4739s
# Epoch: 4948 loss_train: 2.7110 loss_kl_train: 0.2371 loss_x_train: 2.0572 loss_a_train: 0.4166 loss_val: 2.5143 loss_x_val: 2.1580 loss_a_val: 0.3563 time: 0.4777s
# Epoch: 4949 loss_train: 2.7108 loss_kl_train: 0.2369 loss_x_train: 2.0574 loss_a_train: 0.4165 loss_val: 2.5147 loss_x_val: 2.1587 loss_a_val: 0.3560 time: 0.4781s
# Epoch: 4950 loss_train: 2.7109 loss_kl_train: 0.2372 loss_x_train: 2.0571 loss_a_train: 0.4166 loss_val: 2.5147 loss_x_val: 2.1588 loss_a_val: 0.3559 time: 0.4772s
# Epoch: 4951 loss_train: 2.7109 loss_kl_train: 0.2370 loss_x_train: 2.0571 loss_a_train: 0.4168 loss_val: 2.5144 loss_x_val: 2.1585 loss_a_val: 0.3559 time: 0.4746s
# Epoch: 4952 loss_train: 2.7109 loss_kl_train: 0.2369 loss_x_train: 2.0573 loss_a_train: 0.4168 loss_val: 2.5141 loss_x_val: 2.1579 loss_a_val: 0.3562 time: 0.4753s
# Epoch: 4953 loss_train: 2.7105 loss_kl_train: 0.2369 loss_x_train: 2.0573 loss_a_train: 0.4163 loss_val: 2.5144 loss_x_val: 2.1586 loss_a_val: 0.3558 time: 0.4760s
# Epoch: 4954 loss_train: 2.7105 loss_kl_train: 0.2369 loss_x_train: 2.0571 loss_a_train: 0.4165 loss_val: 2.5146 loss_x_val: 2.1590 loss_a_val: 0.3556 time: 0.4791s
# Epoch: 4955 loss_train: 2.7103 loss_kl_train: 0.2372 loss_x_train: 2.0568 loss_a_train: 0.4163 loss_val: 2.5143 loss_x_val: 2.1584 loss_a_val: 0.3559 time: 0.4805s
# Epoch: 4956 loss_train: 2.7099 loss_kl_train: 0.2373 loss_x_train: 2.0572 loss_a_train: 0.4154 loss_val: 2.5145 loss_x_val: 2.1583 loss_a_val: 0.3562 time: 0.4803s
# Epoch: 4957 loss_train: 2.7106 loss_kl_train: 0.2374 loss_x_train: 2.0574 loss_a_train: 0.4158 loss_val: 2.5149 loss_x_val: 2.1591 loss_a_val: 0.3559 time: 0.4739s
# Epoch: 4958 loss_train: 2.7108 loss_kl_train: 0.2371 loss_x_train: 2.0574 loss_a_train: 0.4162 loss_val: 2.5152 loss_x_val: 2.1596 loss_a_val: 0.3556 time: 0.4778s
# Epoch: 4959 loss_train: 2.7102 loss_kl_train: 0.2371 loss_x_train: 2.0567 loss_a_train: 0.4164 loss_val: 2.5151 loss_x_val: 2.1591 loss_a_val: 0.3560 time: 0.4782s
# Epoch: 4960 loss_train: 2.7101 loss_kl_train: 0.2369 loss_x_train: 2.0572 loss_a_train: 0.4160 loss_val: 2.5148 loss_x_val: 2.1589 loss_a_val: 0.3559 time: 0.4774s
# Epoch: 4961 loss_train: 2.7100 loss_kl_train: 0.2367 loss_x_train: 2.0575 loss_a_train: 0.4158 loss_val: 2.5145 loss_x_val: 2.1589 loss_a_val: 0.3556 time: 0.4712s
# Epoch: 4962 loss_train: 2.7099 loss_kl_train: 0.2369 loss_x_train: 2.0570 loss_a_train: 0.4159 loss_val: 2.5143 loss_x_val: 2.1589 loss_a_val: 0.3553 time: 0.4762s
# Epoch: 4963 loss_train: 2.7098 loss_kl_train: 0.2371 loss_x_train: 2.0570 loss_a_train: 0.4157 loss_val: 2.5141 loss_x_val: 2.1587 loss_a_val: 0.3554 time: 0.4763s
# Epoch: 4964 loss_train: 2.7104 loss_kl_train: 0.2371 loss_x_train: 2.0574 loss_a_train: 0.4159 loss_val: 2.5140 loss_x_val: 2.1588 loss_a_val: 0.3553 time: 0.4789s
# Epoch: 4965 loss_train: 2.7098 loss_kl_train: 0.2371 loss_x_train: 2.0569 loss_a_train: 0.4158 loss_val: 2.5139 loss_x_val: 2.1586 loss_a_val: 0.3553 time: 0.4800s
# Epoch: 4966 loss_train: 2.7099 loss_kl_train: 0.2374 loss_x_train: 2.0571 loss_a_train: 0.4154 loss_val: 2.5138 loss_x_val: 2.1583 loss_a_val: 0.3555 time: 0.4744s
# Epoch: 4967 loss_train: 2.7092 loss_kl_train: 0.2373 loss_x_train: 2.0570 loss_a_train: 0.4149 loss_val: 2.5138 loss_x_val: 2.1581 loss_a_val: 0.3557 time: 0.4768s
# Epoch: 4968 loss_train: 2.7103 loss_kl_train: 0.2371 loss_x_train: 2.0574 loss_a_train: 0.4157 loss_val: 2.5139 loss_x_val: 2.1583 loss_a_val: 0.3555 time: 0.4760s
# Epoch: 4969 loss_train: 2.7101 loss_kl_train: 0.2371 loss_x_train: 2.0572 loss_a_train: 0.4157 loss_val: 2.5140 loss_x_val: 2.1587 loss_a_val: 0.3553 time: 0.4759s
# Epoch: 4970 loss_train: 2.7097 loss_kl_train: 0.2373 loss_x_train: 2.0569 loss_a_train: 0.4155 loss_val: 2.5138 loss_x_val: 2.1583 loss_a_val: 0.3554 time: 0.4744s
# Epoch: 4971 loss_train: 2.7094 loss_kl_train: 0.2371 loss_x_train: 2.0570 loss_a_train: 0.4153 loss_val: 2.5140 loss_x_val: 2.1584 loss_a_val: 0.3556 time: 0.4701s
# Epoch: 4972 loss_train: 2.7095 loss_kl_train: 0.2370 loss_x_train: 2.0573 loss_a_train: 0.4152 loss_val: 2.5147 loss_x_val: 2.1594 loss_a_val: 0.3554 time: 0.4762s
# Epoch: 4973 loss_train: 2.7106 loss_kl_train: 0.2371 loss_x_train: 2.0572 loss_a_train: 0.4164 loss_val: 2.5155 loss_x_val: 2.1597 loss_a_val: 0.3558 time: 0.4758s
# Epoch: 4974 loss_train: 2.7099 loss_kl_train: 0.2372 loss_x_train: 2.0569 loss_a_train: 0.4158 loss_val: 2.5152 loss_x_val: 2.1595 loss_a_val: 0.3557 time: 0.4738s
# Epoch: 4975 loss_train: 2.7097 loss_kl_train: 0.2370 loss_x_train: 2.0571 loss_a_train: 0.4155 loss_val: 2.5153 loss_x_val: 2.1591 loss_a_val: 0.3562 time: 0.4772s
# Epoch: 4976 loss_train: 2.7105 loss_kl_train: 0.2371 loss_x_train: 2.0573 loss_a_train: 0.4161 loss_val: 2.5157 loss_x_val: 2.1598 loss_a_val: 0.3559 time: 0.4771s
# Epoch: 4977 loss_train: 2.7107 loss_kl_train: 0.2369 loss_x_train: 2.0570 loss_a_train: 0.4169 loss_val: 2.5158 loss_x_val: 2.1598 loss_a_val: 0.3560 time: 0.4748s
# Epoch: 4978 loss_train: 2.7103 loss_kl_train: 0.2368 loss_x_train: 2.0569 loss_a_train: 0.4166 loss_val: 2.5154 loss_x_val: 2.1587 loss_a_val: 0.3567 time: 0.4752s
# Epoch: 4979 loss_train: 2.7104 loss_kl_train: 0.2366 loss_x_train: 2.0571 loss_a_train: 0.4168 loss_val: 2.5153 loss_x_val: 2.1582 loss_a_val: 0.3571 time: 0.4770s
# Epoch: 4980 loss_train: 2.7111 loss_kl_train: 0.2366 loss_x_train: 2.0573 loss_a_train: 0.4171 loss_val: 2.5159 loss_x_val: 2.1589 loss_a_val: 0.3570 time: 0.4802s
# Epoch: 4981 loss_train: 2.7114 loss_kl_train: 0.2369 loss_x_train: 2.0572 loss_a_train: 0.4173 loss_val: 2.5162 loss_x_val: 2.1592 loss_a_val: 0.3570 time: 0.4746s
# Epoch: 4982 loss_train: 2.7126 loss_kl_train: 0.2373 loss_x_train: 2.0569 loss_a_train: 0.4183 loss_val: 2.5162 loss_x_val: 2.1588 loss_a_val: 0.3574 time: 0.4732s
# Epoch: 4983 loss_train: 2.7118 loss_kl_train: 0.2371 loss_x_train: 2.0570 loss_a_train: 0.4177 loss_val: 2.5163 loss_x_val: 2.1586 loss_a_val: 0.3577 time: 0.4778s
# Epoch: 4984 loss_train: 2.7122 loss_kl_train: 0.2368 loss_x_train: 2.0572 loss_a_train: 0.4182 loss_val: 2.5169 loss_x_val: 2.1594 loss_a_val: 0.3575 time: 0.4797s
# Epoch: 4985 loss_train: 2.7125 loss_kl_train: 0.2368 loss_x_train: 2.0568 loss_a_train: 0.4189 loss_val: 2.5173 loss_x_val: 2.1595 loss_a_val: 0.3578 time: 0.4777s
# Epoch: 4986 loss_train: 2.7130 loss_kl_train: 0.2370 loss_x_train: 2.0569 loss_a_train: 0.4192 loss_val: 2.5170 loss_x_val: 2.1587 loss_a_val: 0.3584 time: 0.4760s
# Epoch: 4987 loss_train: 2.7123 loss_kl_train: 0.2371 loss_x_train: 2.0570 loss_a_train: 0.4182 loss_val: 2.5173 loss_x_val: 2.1586 loss_a_val: 0.3588 time: 0.4762s
# Epoch: 4988 loss_train: 2.7123 loss_kl_train: 0.2370 loss_x_train: 2.0570 loss_a_train: 0.4182 loss_val: 2.5180 loss_x_val: 2.1595 loss_a_val: 0.3585 time: 0.4764s
# Epoch: 4989 loss_train: 2.7124 loss_kl_train: 0.2371 loss_x_train: 2.0569 loss_a_train: 0.4184 loss_val: 2.5180 loss_x_val: 2.1594 loss_a_val: 0.3586 time: 0.4771s
# Epoch: 4990 loss_train: 2.7128 loss_kl_train: 0.2371 loss_x_train: 2.0568 loss_a_train: 0.4189 loss_val: 2.5177 loss_x_val: 2.1588 loss_a_val: 0.3589 time: 0.4807s
# Epoch: 4991 loss_train: 2.7128 loss_kl_train: 0.2366 loss_x_train: 2.0571 loss_a_train: 0.4192 loss_val: 2.5177 loss_x_val: 2.1592 loss_a_val: 0.3585 time: 0.4730s
# Epoch: 4992 loss_train: 2.7126 loss_kl_train: 0.2367 loss_x_train: 2.0572 loss_a_train: 0.4188 loss_val: 2.5182 loss_x_val: 2.1598 loss_a_val: 0.3583 time: 0.4756s
# Epoch: 4993 loss_train: 2.7129 loss_kl_train: 0.2364 loss_x_train: 2.0568 loss_a_train: 0.4197 loss_val: 2.5177 loss_x_val: 2.1592 loss_a_val: 0.3585 time: 0.4769s
# Epoch: 4994 loss_train: 2.7131 loss_kl_train: 0.2363 loss_x_train: 2.0575 loss_a_train: 0.4193 loss_val: 2.5172 loss_x_val: 2.1585 loss_a_val: 0.3588 time: 0.4793s
# Epoch: 4995 loss_train: 2.7125 loss_kl_train: 0.2362 loss_x_train: 2.0572 loss_a_train: 0.4191 loss_val: 2.5171 loss_x_val: 2.1586 loss_a_val: 0.3585 time: 0.4747s
# Epoch: 4996 loss_train: 2.7130 loss_kl_train: 0.2366 loss_x_train: 2.0569 loss_a_train: 0.4194 loss_val: 2.5169 loss_x_val: 2.1589 loss_a_val: 0.3580 time: 0.4764s
# Epoch: 4997 loss_train: 2.7123 loss_kl_train: 0.2364 loss_x_train: 2.0569 loss_a_train: 0.4190 loss_val: 2.5165 loss_x_val: 2.1584 loss_a_val: 0.3580 time: 0.4792s
# Epoch: 4998 loss_train: 2.7116 loss_kl_train: 0.2367 loss_x_train: 2.0572 loss_a_train: 0.4177 loss_val: 2.5162 loss_x_val: 2.1578 loss_a_val: 0.3584 time: 0.4775s
# Epoch: 4999 loss_train: 2.7121 loss_kl_train: 0.2367 loss_x_train: 2.0573 loss_a_train: 0.4182 loss_val: 2.5165 loss_x_val: 2.1586 loss_a_val: 0.3579 time: 0.4755s
# total time: 2433.9915s

# %%
with open(os.path.join(logsavepath,'train_loss'), 'wb') as output:
    pickle.dump(train_loss_ep, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_loss_kl'), 'wb') as output:
    pickle.dump(train_loss_kl_ep, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_loss_x'), 'wb') as output:
    pickle.dump(train_loss_x_ep, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_loss_a'), 'wb') as output:
    pickle.dump(train_loss_a_ep, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'val_loss'), 'wb') as output:
    pickle.dump(val_loss_ep, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'val_loss_x'), 'wb') as output:
    pickle.dump(val_loss_x_ep, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'val_loss_a'), 'wb') as output:
    pickle.dump(val_loss_a_ep, output, pickle.HIGHEST_PROTOCOL)
# with open(os.path.join(logsavepath,'ct_unique'), 'wb') as output:
#     pickle.dump(ct_unique, output, pickle.HIGHEST_PROTOCOL)
    
model.cuda()
model.eval()
if adj_decodeName==None:
    # features_recon, z, mu, logvar=model(features)
    adj_recon,mu,logvar,z, features_recon = model(features, adj_norm)
else:
    adj_recon,mu,logvar,z, features_recon = model(features, adj_norm,adj_decode)
if clf:
        modelClf.eval()
        clfOut=modelClf(z)
if 'dca' in model_str:
    loss_x_test=loss_x(features_recon, features,test_nodes_idx,XreconWeight,ridgeL,torch.tensor(features_raw).cuda())
else:
    loss_x_test=loss_x(features_recon, features,test_nodes_idx,XreconWeight,mse)
loss_a_test=loss_a(adj_recon, adj_label, pos_weight, norm,test_nodes_idx)
loss_test = loss_x_test+loss_a_test
if clf:
    loss_clf_test=loss_clf(clfOut[test_nodes_idx],ct_train[test_nodes_idx])
    loss_test=loss_test+clfweight*loss_clf_test
print('test results',
      'loss_test: {:.4f}'.format(loss_test.item()),
      'loss_x_test: {:.4f}'.format(loss_x_test.item()),
      'loss_a_test: {:.4f}'.format(loss_a_test.item()))
#      'loss_clf_test: {:.4f}'.format(loss_clf_test.item()),)
# Out:
# test results loss_test: 2.5495 loss_x_test: 2.1909 loss_a_test: 0.3586

# %%
plt.plot(np.arange(epochs),train_loss_ep)
plt.plot(np.arange(epochs),val_loss_ep)
plt.plot(np.arange(epochs),train_loss_x_ep)
plt.plot(np.arange(epochs),val_loss_x_ep)
plt.plot(np.arange(epochs),train_loss_a_ep)
plt.plot(np.arange(epochs),val_loss_a_ep)
plt.plot(np.arange(epochs),train_loss_kl_ep)
# plt.plot(np.arange(epochs),np.array(train_loss_clf_ep)*clfweight)
# plt.plot(np.arange(epochs),np.array(val_loss_clf_ep)*clfweight)
plt.ylim((0,30))
# plt.xlim((0,1000))
# plt.legend(['training loss','validation loss','training x recon loss','validation x recon loss','training kl loss'],loc='upper right')
plt.legend(['training loss','validation loss','training x recon loss','validation x recon loss','training a recon loss','validation a recon loss','training kl loss','training classifier loss','validation classifier loss'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'loss_seed3.jpg'))
plt.show()

# %%
# name='c13k20XA_07_dca'
# logsavepath='/mnt/xinyi/pamrats/log/train_gae_starmap/'+name
# with open(os.path.join(logsavepath,'val_loss_a'), 'rb') as output:
#     val_loss_a_ep=pickle.load(output)
# np.argmin(loss[:3280])
np.argmin(val_loss_x_ep[:4991])
val_loss_a_ep[1040]
# Out:
# 0.41516223549842834

# %%
testepoch=0
model.load_state_dict(torch.load(os.path.join(modelsavepath,str(testepoch)+'.pt')))
model.eval()
for s in sampleidx.keys():
    print(s)
    features=featureslist[s+'X_'+training_sample_X]
    if 'dca' in model_str:
        features_raw=torch.tensor(rawdata.X[rawdata.obs['sample']==sampleidx[s]])
    num_nodes,num_features = features.shape
    nodesmask=torch.tensor(np.arange(num_nodes))
    
    adj=adj_list[s]
    adj_norm = preprocessing.preprocess_graph(adj)
    adj_label=adj + sp.eye(adj.shape[0])
    adj_label=torch.tensor(adj_label.todense())
    adj_decode=None
    if adj_decodeName == 'gala':
        adj_decode=preprocessing.preprocess_graph_sharp(adj)
    pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum() 
    pos_weight=torch.tensor(pos_weight)
    norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0] - adj.sum()) * 2)

    if use_cuda:
        features = features.cuda().float()
        adj_norm=adj_norm.cuda()
        adj_label = adj_label.cuda().float()
        nodesmask=nodesmask.cuda()
        if 'dca' in model_str:
            features_raw=features_raw.cuda().float()
    if adj_decodeName==None:
        adj_recon,mu,logvar,z, features_recon = model(features, adj_norm)
    else:
        adj_decode=adj_decode.cuda()
        adj_recon,mu,logvar,z, features_recon = model(features, adj_norm,adj_decode)
    if 'dca' in model_str:
        loss_x_test=loss_x(features_recon, features,nodesmask,XreconWeight,ridgeL,features_raw)
    else:
        loss_x_test=loss_x(features_recon, features,nodesmask,XreconWeight,mse)
    loss_a_test=loss_a(adj_recon, adj_label, pos_weight, norm,nodesmask)
    loss_test = loss_x_test+loss_a_test
    
    if 'dca' in model_str:
        features_raw=features_raw.cpu()
    print('test results',
          'loss_test: {:.4f}'.format(loss_test.item()),
          'loss_x_test: {:.4f}'.format(loss_x_test.item()),
          'loss_a_test: {:.4f}'.format(loss_a_test.item()))
# Out:
# disease13
# test results loss_test: 12.4927 loss_x_test: 10.4046 loss_a_test: 2.0881
# control13
# test results loss_test: 11.4050 loss_x_test: 10.0164 loss_a_test: 1.3886
# disease8
# test results loss_test: 12.3639 loss_x_test: 9.8964 loss_a_test: 2.4675
# control8
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-f9b9e96eeb81> in <module>
#      37     else:
#      38         loss_x_test=loss_x(features_recon, features,nodesmask,XreconWeight,mse)
# ---> 39     loss_a_test=loss_a(adj_recon, adj_label, pos_weight, norm,nodesmask)
#      40     loss_test = loss_x_test+loss_a_test
#      41
#
# ~/pamrats/gae/gae/optimizer.py in optimizer_CE(preds, labels, pos_weight, norm, nodemask)
#      25
#      26 def optimizer_CE(preds, labels, pos_weight, norm,nodemask):
# ---> 27     cost=norm * F.binary_cross_entropy_with_logits(preds[nodemask,:][:,nodemask], labels[nodemask,:][:,nodemask], pos_weight=pos_weight,reduction='mean')
#      28     return cost
#      29
#
# ~/anaconda3/envs/pytorch/lib/python3.7/site-packages/torch/nn/functional.py in binary_cross_entropy_with_logits(input, target, weight, size_average, reduce, reduction, pos_weight)
#    2161         raise ValueError("Target size ({}) must be the same as input size ({})".format(target.size(), input.size()))
#    2162
# -> 2163     return torch.binary_cross_entropy_with_logits(input, target, weight, pos_weight, reduction_enum)
#    2164
#    2165
#
# RuntimeError: CUDA out of memory. Tried to allocate 248.00 MiB (GPU 0; 11.91 GiB total capacity; 8.11 GiB already allocated; 232.56 MiB free; 3.00 GiB cached)

# %%
s='control13'
print(s)
features=featureslist[s+'X_'+training_sample_X]
if 'dca' in model_str:
    features_raw=torch.tensor(rawdata.X[rawdata.obs['sample']==sampleidx[s]])
num_nodes,num_features = features.shape
nodesmask=torch.tensor(np.arange(num_nodes))

adj=adj_list[s]
adj_norm = preprocessing.preprocess_graph(adj)
adj_label=adj + sp.eye(adj.shape[0])
adj_label=torch.tensor(adj_label.todense())
adj_decode=None
if adj_decodeName == 'gala':
    adj_decode=preprocessing.preprocess_graph_sharp(adj)
pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum() 
pos_weight=torch.tensor(pos_weight)
norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0] - adj.sum()) * 2)

if use_cuda:
    features = features.cuda().float()
    adj_norm=adj_norm.cuda()
    adj_label = adj_label.cuda().float()
    nodesmask=nodesmask.cuda()
    if 'dca' in model_str:
        features_raw=features_raw.cuda().float()
if adj_decodeName==None:
    adj_recon,mu,logvar,z, features_recon = model(features, adj_norm)
else:
    adj_decode=adj_decode.cuda()
    adj_recon,mu,logvar,z, features_recon = model(features, adj_norm,adj_decode)# loss_x_test=loss_x(features_recon, features,test_nodes_idx,XreconWeight,mse)
loss_a_test=loss_a(adj_recon, adj_label, pos_weight, norm,test_nodes_idx)
if 'dca' in model_str:
#     loss_x_test=loss_x(features_recon, features,nodesmask,XreconWeight,ridgeL,features_raw)
    loss_x_test=loss_x(features_recon, features,test_nodes_idx,XreconWeight,ridgeL,features_raw)
else:
#     loss_x_test=loss_x(features_recon, features,nodesmask,XreconWeight,mse)
    loss_x_test=loss_x(features_recon, features,test_nodes_idx,XreconWeight,mse)
# loss_x_test=loss_x(features_recon, features,nodesmask,XreconWeight,mse)
# loss_a_test=loss_a(adj_recon, adj_label, pos_weight, norm,nodesmask)
# loss_a_test=loss_a(adj_recon, adj_label, pos_weight, norm,test_nodes_idx)
loss_test = loss_x_test+loss_a_test
print('test results',
      'loss_test: {:.4f}'.format(loss_test.item()),
      'loss_x_test: {:.4f}'.format(loss_x_test.item()),
      'loss_a_test: {:.4f}'.format(loss_a_test.item()))
# Out:
# control13
# test results loss_test: 3.2601 loss_x_test: 2.8062 loss_a_test: 0.4540

# %%
y_true=features
y_true_raw=features_raw
preds=features_recon
mask=nodesmask=torch.tensor(np.arange(num_nodes))
reconWeight=20
eps = 1e-10

output,pi,theta,y_pred=preds
nb_case=optimizer.optimizer_nb(preds,y_true,mask,reconWeight,eps = 1e-10,ifmean=False)- torch.log(pi+eps)

zero_nb = torch.pow(theta/(theta+y_pred+eps), theta)
zero_case = -torch.log(pi + ((1.0-pi)*zero_nb)+eps)
result = torch.where(torch.lt(y_true_raw, 1), zero_case, nb_case)
# ridge = ridgePi*pi*pi
# result += ridge

# %%
result[:8,:6]
# Out:
# tensor([[2.6402e-02, 2.4067e-02, 2.5978e-02, 2.0095e-02, 2.9534e-02, 2.6715e-02],
#         [9.6916e-04, 8.0558e-04, 8.7240e-04, 5.2913e-04, 6.0678e-04, 1.6413e+00],
#         [7.8781e-04, 6.9792e-04, 6.8796e-04, 6.2915e-04, 8.1197e-04, 9.8116e-04],
#         [9.2012e-04, 7.3144e-04, 8.7788e-04, 7.1551e-04, 2.1110e+00, 1.0636e-03],
#         [7.9228e-04, 6.5897e-04, 7.0615e-04, 4.2501e-04, 4.7975e-04, 1.7123e+00],
#         [5.4678e-04, 4.9013e-04, 4.6687e-04, 4.3891e-04, 5.6247e-04, 6.8551e-04],
#         [1.4460e-03, 1.2043e-03, 1.3117e-03, 8.1906e-04, 9.4327e-04, 1.1714e-03],
#         [1.4460e-03, 1.2043e-03, 1.3117e-03, 8.1906e-04, 9.4327e-04, 1.1714e-03]],
#        device='cuda:0', grad_fn=<SliceBackward>)

# %%
ridge = 0.01*pi*pi
ridge[:8,:8]
# torch.mean(ridge)
# Out:
# tensor([[0.0094, 0.0095, 0.0095, 0.0096, 0.0094, 0.0094, 0.0091, 0.0092],
#         [0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100],
#         [0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100],
#         [0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100],
#         [0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100],
#         [0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100],
#         [0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0099, 0.0100],
#         [0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0100, 0.0099, 0.0100]],
#        device='cuda:0', grad_fn=<SliceBackward>)

# %%
features[:8,:6]
# Out:
# tensor([[-0.2504, -0.1938, -0.1941, -0.1474, -0.1934, -0.2717],
#         [-0.2504, -0.1938, -0.1941, -0.1474, -0.1934,  3.1390],
#         [-0.2504, -0.1938, -0.1941, -0.1474, -0.1934, -0.2717],
#         [-0.2504, -0.1938, -0.1941, -0.1474,  5.7623, -0.2717],
#         [-0.2504, -0.1938, -0.1941, -0.1474, -0.1934,  3.5326],
#         [-0.2504, -0.1938, -0.1941, -0.1474, -0.1934, -0.2717],
#         [-0.2504, -0.1938, -0.1941, -0.1474, -0.1934, -0.2717],
#         [-0.2504, -0.1938, -0.1941, -0.1474, -0.1934, -0.2717]],
#        device='cuda:0')

# %%
zeroidx=(features_raw==0)
nonzeroidx=(features_raw!=0)
torch.sum(result[zeroidx])/torch.sum(result)
# Out:
# tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)

# %%
torch.sum(result[nonzeroidx])/torch.sum(result)
# Out:
# tensor(0.9961, device='cuda:0', grad_fn=<DivBackward0>)

# %%
features_recon[3][:8,:6]
# Out:
# tensor([[2.8657, 3.5613, 4.5057, 4.9731, 5.0515, 3.2854],
#         [2.4956, 4.5268, 8.2924, 3.9105, 4.5425, 3.2845],
#         [3.1710, 4.2593, 5.3327, 5.4882, 5.0153, 4.0579],
#         [2.8641, 3.2520, 5.8698, 4.8077, 4.7432, 3.3465],
#         [2.4757, 4.6132, 8.5509, 3.9008, 4.5554, 3.2782],
#         [3.1596, 4.3181, 5.3601, 5.5689, 5.0421, 4.1195],
#         [2.5660, 4.3950, 7.7780, 3.9677, 4.5476, 3.2890],
#         [2.5660, 4.3950, 7.7780, 3.9677, 4.5476, 3.2890]], device='cuda:0',
#        grad_fn=<SliceBackward>)

# %%
# model.pi.weight[:8,:8]
model_str
# Out:
# 'gcn_vae_xa_e2_d1_dca'
