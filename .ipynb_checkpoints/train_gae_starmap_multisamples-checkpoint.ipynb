# %%
import sys
sys.path.append('/home/xinyiz/pamrats')

# %%
##This is adapted from https://github.com/tkipf/gae/blob/master/gae/train.py and https://github.com/tkipf/pygcn/blob/master/pygcn/train.py##

import time
import os

# Train on CPU (hide GPU) due to memory constraints
# os.environ['CUDA_VISIBLE_DEVICES'] = ""

import scanpy
import numpy as np
import scipy.sparse as sp

import torch
from torch import optim

# from sklearn.metrics import roc_auc_score
# from sklearn.metrics import average_precision_score

import gae.gae.optimizer as optimizer
import gae.gae.model
import gae.gae.preprocessing as preprocessing

import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import umap
import pandas as pd
from sklearn.preprocessing import scale
from sklearn.preprocessing import MinMaxScaler

# %%
# Settings
use_cuda=True
fastmode=False #Validate during training pass
seed=3
useSavedMaskedEdges=True
maskedgeName='knn20_connectivity'
epochs=10000
saveFreq=10
lr=0.001 #initial learning rate
weight_decay=0 #Weight for L2 loss on embedding matrix.

hidden1=1024 #Number of units in hidden layer 1
hidden2=1024 #Number of units in hidden layer 2
# hidden3=2048
# hidden4=2048
# hidden5=128
fc_dim1=1024
# fc_dim2=128
# fc_dim3=128
# fc_dim4=128
# gcn_dim1=2600
# clf_hidden=256

dropout=0.01
testNodes=0.1 #fraction of total nodes for testing
valNodes=0.05 #fraction of total nodes for validation
XreconWeight=20
# clfweight=20
# randFeatureSubset=None
model_str='gcn_vae_xa_e2_d1_dca'
clf=None
adj_decodeName=None #gala or None
ridgeL=0.01
shareGenePi=True

num_features=2112
training_samples=['control13','disease13','disease8']
training_sample_X='logminmax'
switchFreq=100
standardizeX=False
name='allk20XA_01_dca_noD8' ###rename and retrain D8 C8
logsavepath='/mnt/xinyi/pamrats/log/train_gae_starmap/'+name
modelsavepath='/mnt/xinyi/pamrats/models/train_gae_starmap/'+name
plotsavepath='/mnt/xinyi/pamrats/plots/train_gae_starmap/'+name

#Load data
sampleidx={'disease13':'AD_mouse9494','control13':'AD_mouse9498','disease8':'AD_mouse9723','control8':'AD_mouse9735'}
savedir=os.path.join('/mnt/xinyi/','starmap')
adj_dir=os.path.join(savedir,'a')

featureslist={}
if training_sample_X in ['corrected','scaled']:
    scaleddata=scanpy.read_h5ad('/mnt/xinyi/2021-01-13-mAD-test-dataset/2020-12-27-starmap-mAD-scaled.h5ad')
    
    for s in sampleidx.keys():
        featureslist[s+'X_'+'corrected']=torch.tensor(scaleddata.layers['corrected'][scaleddata.obs['sample']==sampleidx[s]])
        featureslist[s+'X_'+'scaled']=torch.tensor(scaleddata.layers['scaled'][scaleddata.obs['sample']==sampleidx[s]])

else:
    scaleddata=scanpy.read_h5ad('/mnt/xinyi/2021-01-13-mAD-test-dataset/2020-12-27-starmap-mAD-raw.h5ad')
    
    for s in sampleidx.keys():
        scaleddata_train=scaleddata.X[scaleddata.obs['sample']==sampleidx[s]]

        if training_sample_X=='logminmax':
            featurelog_train=np.log2(scaleddata_train+1/2)
            scaler = MinMaxScaler()
            featurelog_train_minmax=np.transpose(scaler.fit_transform(np.transpose(featurelog_train)))
            featureslist[s+'X_'+training_sample_X]=torch.tensor(featurelog_train_minmax)
        elif training_sample_X=='logminmax10':
            featurelog_train=np.log2(scaleddata_train+1/2)
            scaler = MinMaxScaler(feature_range=(0,10))
            featurelog_train_minmax=np.transpose(scaler.fit_transform(np.transpose(featurelog_train)))
            featureslist[s+'X_'+training_sample_X]=torch.tensor(featurelog_train_minmax)
        
if clf:
    ctlist={}
    ctlist['disease13']=scaleddata.obs.loc[scaleddata.obs['sample']=='AD_mouse9494','top_level'].to_numpy()
    ctlist['control13']=scaleddata.obs.loc[scaleddata.obs['sample']=='AD_mouse9498','top_level'].to_numpy()
    ctlist['disease8']=scaleddata.obs.loc[scaleddata.obs['sample']=='AD_mouse9723','top_level'].to_numpy()
    ctlist['control8']=scaleddata.obs.loc[scaleddata.obs['sample']=='AD_mouse9735','top_level'].to_numpy()
    ct_unique=np.unique(scaleddata.obs.loc[scaleddata.obs['sample']=='AD_mouse9735','top_level'])
    for k in ctlist.keys():
        for i in range(ct_unique.size):
            ctlist[k][ctlist[k]==ct_unique[i]]=i
    


adj_list={}
adj_list['disease13']=sp.load_npz(os.path.join(adj_dir,maskedgeName+'_AD_mouse9494.npz'))
adj_list['control13']=sp.load_npz(os.path.join(adj_dir,maskedgeName+'_AD_mouse9498.npz'))
adj_list['disease8']=sp.load_npz(os.path.join(adj_dir,maskedgeName+'_AD_mouse9723.npz'))
adj_list['control8']=sp.load_npz(os.path.join(adj_dir,maskedgeName+'_AD_mouse9735.npz'))

adjnormlist={}
pos_weightlist={}
normlist={}
for ai in adj_list.keys():
    adjnormlist[ai]=preprocessing.preprocess_graph(adj_list[ai])
    
    pos_weightlist[ai] = torch.tensor(float(adj_list[ai].shape[0] * adj_list[ai].shape[0] - adj_list[ai].sum()) / adj_list[ai].sum()) #using full unmasked adj
    normlist[ai] = adj_list[ai].shape[0] * adj_list[ai].shape[0] / float((adj_list[ai].shape[0] * adj_list[ai].shape[0] - adj_list[ai].sum()) * 2)
    
    adj_label=adj_list[ai] + sp.eye(adj_list[ai].shape[0])
    adj_list[ai]=torch.tensor(adj_label.todense())
    
    
# adj_decode=None
# if adj_decodeName == 'gala':
#     adj_decode=preprocessing.preprocess_graph_sharp(adj_train)



if 'dca' in model_str:
    rawdata=scanpy.read_h5ad('/mnt/xinyi/2021-01-13-mAD-test-dataset/2020-12-27-starmap-mAD-raw.h5ad')
    features_raw_list={}
    for s in sampleidx.keys():
        features_raw_list[s+'X_'+'raw']=torch.tensor(rawdata.X[rawdata.obs['sample']==sampleidx[s]]).cuda()
    

if clf:
    ct_train=ctlist[training_samples].astype(int)
# features=torch.tensor(np.identity(7000)).float()
# features=features[0:10,:]
if standardizeX:
    features=torch.tensor(scale(features,axis=0, with_mean=True, with_std=True, copy=True))

# Set cuda and seed
np.random.seed(seed)
if use_cuda and (not torch.cuda.is_available()):
    print('cuda not available')
    use_cuda=False
torch.manual_seed(seed)
if use_cuda:
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.enabled = True

# Load data
# if randFeatureSubset != None:
#     idx=np.random.choice(features.shape[1],randFeatureSubset,replace=False)
#     features=features[:,idx]

# %%
if not os.path.exists(logsavepath):
    os.mkdir(logsavepath)
if not os.path.exists(modelsavepath):
    os.mkdir(modelsavepath)
if not os.path.exists(plotsavepath):
    os.mkdir(plotsavepath)

# %%
# loop over all train/validation sets

mse=torch.nn.MSELoss()
# mse=torch.nn.MSELoss(reduction=None)
# Create model
if model_str=='gcn_vae_xa':
    model = gae.gae.model.GCNModelVAE_XA(num_features, hidden1, hidden2,fc_dim1,fc_dim2,fc_dim3,fc_dim4, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
    loss_a=optimizer.optimizer_CE
elif model_str == 'gcn_vae_gcnX_inprA':
    model = gae.gae.model.GCNModelVAE_gcnX_inprA(num_features, hidden1, hidden2,gcn_dim1, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
    loss_a=optimizer.optimizer_CE
    
elif model_str == 'gcn_vae_gcnX_inprA_w':
    model = gae.gae.model.GCNModelVAE_gcnX_inprA_w(num_features, hidden1, hidden2,gcn_dim1, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
    loss_a=optimizer.optimizer_CE    
    
elif model_str=='gcn_vae_xa_e3':
    model = gae.gae.model.GCNModelVAE_XA_e3(num_features, hidden1, hidden2,hidden3,fc_dim1,fc_dim2,fc_dim3,fc_dim4, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
    loss_a=optimizer.optimizer_CE
    
elif model_str == 'gcn_vae_xa_e1':
    model = gae.gae.model.GCNModelVAE_XA_e1(num_features, hidden1, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
    loss_a=optimizer.optimizer_CE

elif model_str == 'gcn_vae_xa_e2_d1':
    model = gae.gae.model.GCNModelVAE_XA_e2_d1(num_features, hidden1,hidden2, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
    loss_a=optimizer.optimizer_CE
    
elif model_str=='gcn_vae_xa_e2_d1_dca':
    model = gae.gae.model.GCNModelVAE_XA_e2_d1_DCA(num_features, hidden1,hidden2,fc_dim1, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_zinb
    loss_a=optimizer.optimizer_CE

elif model_str=='gcn_vae_xa_e2_d1_dcaFork':
    model = gae.gae.model.GCNModelVAE_XA_e2_d1_DCAfork(num_features, hidden1,hidden2,fc_dim1, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_zinb
    loss_a=optimizer.optimizer_CE

elif model_str=='gcn_vae_xa_e2_d1_dcaElemPi':
    model = gae.gae.model.GCNModelVAE_XA_e2_d1_DCAelemPi(num_features, hidden1,hidden2,fc_dim1, dropout,shareGenePi)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_zinb
    loss_a=optimizer.optimizer_CE

elif model_str=='gcn_vae_xa_e2_d1_dcaConstantDisp':
    model = gae.gae.model.GCNModelVAE_XA_e2_d1_DCA_constantDisp(num_features, hidden1,hidden2,fc_dim1, dropout,shareGenePi)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_zinb
    loss_a=optimizer.optimizer_CE    
    
elif model_str == 'gcn_vae_xa_e4_d1':
    model = gae.gae.model.GCNModelVAE_XA_e4_d1(num_features, hidden1,hidden2,hidden3,hidden4, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
    loss_a=optimizer.optimizer_CE    
    
elif model_str=='fc':
    model = gae.gae.model.FCVAE(num_features, hidden1, hidden2,hidden3,hidden4,hidden5,fc_dim1,fc_dim2,fc_dim3,fc_dim4, dropout)
    loss_kl=optimizer.optimizer_kl
    loss_x=optimizer.optimizer_MSE
#     loss_x=mse
    loss_a=optimizer.optimizer_CE
elif model_str=='fcae':
    model = gae.gae.model.FCAE(num_features, hidden1, hidden2,hidden3,hidden4,hidden5,fc_dim1,fc_dim2,fc_dim3,fc_dim4, dropout)
    loss_x=optimizer.optimizer_MSE
#     loss_x=mse

elif model_str=='fcae1':
    model = gae.gae.model.FCAE1(num_features, dropout,hidden1)
    loss_x=optimizer.optimizer_MSE
#     loss_x=mse
elif model_str=='fcae2':
    model = gae.gae.model.FCAE2(num_features, dropout,hidden1,hidden2)
    loss_x=optimizer.optimizer_MSE

elif model_str=='fc1':
    model = gae.gae.model.FCVAE1(num_features, hidden1,dropout)
    loss_x=optimizer.optimizer_MSE
    loss_kl=optimizer.optimizer_kl
    loss_a=optimizer.optimizer_CE

elif model_str=='fc1_dca':
    model = gae.gae.model.FCVAE1_DCA(num_features, hidden1,fc_dim1, dropout)
    loss_x=optimizer.optimizer_zinb
    loss_kl=optimizer.optimizer_kl
    loss_a=optimizer.optimizer_CE

if clf=='clf_fc1':
    modelClf=gae.gae.model.Clf_fc1(hidden2, dropout,clf_hidden,ct_unique.size)
    loss_clf=torch.nn.CrossEntropyLoss()
    

if use_cuda:
    model.cuda()
    if clf:
        modelClf.cuda()
        ct_train=torch.tensor(ct_train).cuda()
    for fk in featureslist.keys():
        featureslist[fk] = featureslist[fk].cuda().float()
    for ak in adj_list.keys():
        adjnormlist[ak] =adjnormlist[ak].cuda()
        adj_list[ak] = adj_list[ak].cuda().float()
#     if adj_decode is not None:
#         adj_decode=adj_decode.cuda()
    

optimizerVAEXA = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
if clf:
    optimizerClf=optim.Adam(modelClf.parameters(), lr=lr, weight_decay=weight_decay)

# %%
 
def train(epoch):
    t = time.time()
    model.train()
    optimizerVAEXA.zero_grad()
    
    if adj_decodeName==None:
        adj_recon,mu,logvar,z,features_recon = model(features, adj_norm)
    #     features_recon, z, mu, logvar=model(features.float())
    else:
        adj_recon,mu,logvar,z,features_recon = model(features, adj_norm,adj_decode)
        
    
    if clf:
        modelClf.train()
        optimizerClf.zero_grad()
        clfOut=modelClf(z)
        
    
    loss_kl_train=loss_kl(mu, logvar, train_nodes_idx)
    if 'dca' in model_str:
        loss_x_train=loss_x(features_recon, features,train_nodes_idx,XreconWeight,ridgeL,features_raw)
    else:
        loss_x_train=loss_x(features_recon, features,train_nodes_idx,XreconWeight,mse)
    loss_a_train=loss_a(adj_recon, adj_label, pos_weight, norm,train_nodes_idx)
    loss = loss_kl_train+loss_x_train+loss_a_train
#     loss=loss_x_train #for lossXreconOnly only
#     loss=loss_kl_train+loss_x_train #for lossXreconOnly_wKL only
#     loss = loss_kl_train+loss_a_train #for lossAreconOnly_wKL only
    if clf:
        loss_clf_train=loss_clf(clfOut[train_nodes_idx],ct_train[train_nodes_idx])
        loss=loss+clfweight*loss_clf_train
    loss.backward()
    optimizerVAEXA.step()
    if clf:
        optimizerClf.step()

    if not fastmode:
        # Evaluate validation set performance separately,
        # deactivates dropout during validation run & no variation in z.
        model.eval()
        if adj_decodeName==None:
            adj_recon,mu,logvar,z, features_recon = model(features, adj_norm)
    #         features_recon, z, mu, logvar=model(features.float())
        else:
            adj_recon,mu,logvar,z, features_recon = model(features, adj_norm,adj_decode)
    
    if clf:
        modelClf.eval()
        clfOut=modelClf(z)
    if 'dca' in model_str:
        loss_x_val=loss_x(features_recon, features,val_nodes_idx,XreconWeight,ridgeL,features_raw)
    else:
        loss_x_val=loss_x(features_recon, features,val_nodes_idx,XreconWeight,mse)
    loss_a_val=loss_a(adj_recon, adj_label, pos_weight, norm,val_nodes_idx)
    loss_val = loss_x_val+loss_a_val
#     loss_val=loss_x_val
    if clf:
        loss_clf_val=loss_clf(clfOut[val_nodes_idx],ct_train[val_nodes_idx])
        loss_val=loss_val+clfweight*loss_clf_val
    
#     print(features_recon[:5,:5])
    print(training_samples_t+' Epoch: {:04d}'.format(epoch),
          'loss_train: {:.4f}'.format(loss.item()),
          'loss_kl_train: {:.4f}'.format(loss_kl_train.item()),
          'loss_x_train: {:.4f}'.format(loss_x_train.item()),
          'loss_a_train: {:.4f}'.format(loss_a_train.item()),
#           'loss_clf_train: {:.4f}'.format(loss_clf_train.item()),
          'loss_val: {:.4f}'.format(loss_val.item()),
          'loss_x_val: {:.4f}'.format(loss_x_val.item()),
          'loss_a_val: {:.4f}'.format(loss_a_val.item()),
#           'loss_clf_val: {:.4f}'.format(loss_clf_val.item()),
          'time: {:.4f}s'.format(time.time() - t))
#     return loss.item(),loss_x_train.item(),loss_val.item(),loss_x_val.item()
#     return loss.item(),loss_kl_train.item(),loss_x_train.item(),loss_val.item(),loss_x_val.item()
    if clf:
        return loss.item(),loss_kl_train.item(),loss_x_train.item(),loss_a_train.item(),loss_val.item(),loss_x_val.item(),loss_a_val.item(),loss_clf_train.item(),loss_clf_val.item()
    else:
        return loss.item(),loss_kl_train.item(),loss_x_train.item(),loss_a_train.item(),loss_val.item(),loss_x_val.item(),loss_a_val.item()

# print('cross-validation ',seti)
train_loss_ep=[None]*epochs
train_loss_kl_ep=[None]*epochs
train_loss_x_ep=[None]*epochs
train_loss_a_ep=[None]*epochs
train_loss_clf_ep=[None]*epochs
val_loss_ep=[None]*epochs
val_loss_x_ep=[None]*epochs
val_loss_a_ep=[None]*epochs
val_loss_clf_ep=[None]*epochs
t_ep=time.time()
for ep in range(epochs):
    t=int(ep/switchFreq)%len(training_samples)
    training_samples_t=training_samples[t]
    
    adj_norm=adjnormlist[training_samples_t]
    adj_label=adj_list[training_samples_t]
    features=featureslist[training_samples_t+'X_'+training_sample_X]
    pos_weight=pos_weightlist[training_samples_t]
    norm=normlist[training_samples_t]
    if 'dca' in model_str:
        features_raw=features_raw_list[training_samples_t+'X_raw']
    num_nodes,_ = features.shape
    
    maskpath=os.path.join(savedir,'trainMask',training_samples_t+'_'+maskedgeName+'_seed'+str(seed)+'.pkl')
    if useSavedMaskedEdges and os.path.exists(maskpath):
#         print('opening saved')
        with open(maskpath, 'rb') as input:
            maskedgeres = pickle.load(input)
    else:
        # construct training, validation, and test sets
        maskedgeres= preprocessing.mask_nodes_edges(features.shape[0],testNodeSize=testNodes,valNodeSize=valNodes)
        with open(maskpath, 'wb') as output:
            pickle.dump(maskedgeres, output, pickle.HIGHEST_PROTOCOL)
    train_nodes_idx,val_nodes_idx,test_nodes_idx = maskedgeres
    if use_cuda:
        train_nodes_idx=train_nodes_idx.cuda()
        val_nodes_idx=val_nodes_idx.cuda()
        test_nodes_idx=test_nodes_idx.cuda()
    
    if clf:
        train_loss_ep[ep],train_loss_kl_ep[ep],train_loss_x_ep[ep],train_loss_a_ep[ep],val_loss_ep[ep],val_loss_x_ep[ep],val_loss_a_ep[ep],train_loss_clf_ep[ep],val_loss_clf_ep[ep]=train(ep)
    else:
        train_loss_ep[ep],train_loss_kl_ep[ep],train_loss_x_ep[ep],train_loss_a_ep[ep],val_loss_ep[ep],val_loss_x_ep[ep],val_loss_a_ep[ep]=train(ep)

        
    if ep%saveFreq == 0:
        torch.save(model.cpu().state_dict(), os.path.join(modelsavepath,str(ep)+'.pt'))
    if use_cuda:
        model.cuda()
print(' total time: {:.4f}s'.format(time.time() - t_ep))
# Out:
# control13 Epoch: 0000 loss_train: 21.3837 loss_kl_train: 0.0006 loss_x_train: 7.7450 loss_a_train: 13.6381 loss_val: 8.7758 loss_x_val: 7.6626 loss_a_val: 1.1132 time: 0.7226s
# control13 Epoch: 0001 loss_train: 19.4200 loss_kl_train: 0.0002 loss_x_train: 6.4261 loss_a_train: 12.9937 loss_val: 9.0480 loss_x_val: 7.5991 loss_a_val: 1.4489 time: 0.4525s
# control13 Epoch: 0002 loss_train: 18.3083 loss_kl_train: 0.0003 loss_x_train: 5.3883 loss_a_train: 12.9198 loss_val: 8.9928 loss_x_val: 7.5378 loss_a_val: 1.4550 time: 0.4393s
# control13 Epoch: 0003 loss_train: 17.4427 loss_kl_train: 0.0003 loss_x_train: 4.5855 loss_a_train: 12.8570 loss_val: 8.7601 loss_x_val: 7.4774 loss_a_val: 1.2827 time: 0.4399s
# control13 Epoch: 0004 loss_train: 16.7707 loss_kl_train: 0.0002 loss_x_train: 3.9800 loss_a_train: 12.7905 loss_val: 8.6089 loss_x_val: 7.3965 loss_a_val: 1.2125 time: 0.4392s
# control13 Epoch: 0005 loss_train: 16.2463 loss_kl_train: 0.0002 loss_x_train: 3.5282 loss_a_train: 12.7179 loss_val: 8.6113 loss_x_val: 7.2853 loss_a_val: 1.3261 time: 0.4419s
# control13 Epoch: 0006 loss_train: 15.8404 loss_kl_train: 0.0003 loss_x_train: 3.1949 loss_a_train: 12.6452 loss_val: 8.5929 loss_x_val: 7.1741 loss_a_val: 1.4188 time: 0.4413s
# control13 Epoch: 0007 loss_train: 15.5382 loss_kl_train: 0.0003 loss_x_train: 2.9503 loss_a_train: 12.5876 loss_val: 8.4624 loss_x_val: 7.0908 loss_a_val: 1.3716 time: 0.4401s
# control13 Epoch: 0008 loss_train: 15.3219 loss_kl_train: 0.0003 loss_x_train: 2.7690 loss_a_train: 12.5525 loss_val: 8.3278 loss_x_val: 7.0099 loss_a_val: 1.3179 time: 0.4397s
# control13 Epoch: 0009 loss_train: 15.0531 loss_kl_train: 0.0004 loss_x_train: 2.6326 loss_a_train: 12.4201 loss_val: 8.3672 loss_x_val: 6.8766 loss_a_val: 1.4906 time: 0.4403s
# control13 Epoch: 0010 loss_train: 14.7754 loss_kl_train: 0.0005 loss_x_train: 2.5277 loss_a_train: 12.2472 loss_val: 8.3570 loss_x_val: 6.7395 loss_a_val: 1.6174 time: 0.4404s
# control13 Epoch: 0011 loss_train: 14.6524 loss_kl_train: 0.0005 loss_x_train: 2.4457 loss_a_train: 12.2061 loss_val: 8.4208 loss_x_val: 6.5794 loss_a_val: 1.8414 time: 0.4425s
# control13 Epoch: 0012 loss_train: 14.4808 loss_kl_train: 0.0006 loss_x_train: 2.3787 loss_a_train: 12.1014 loss_val: 8.4764 loss_x_val: 6.4258 loss_a_val: 2.0505 time: 0.4451s
# control13 Epoch: 0013 loss_train: 14.2900 loss_kl_train: 0.0008 loss_x_train: 2.3216 loss_a_train: 11.9677 loss_val: 8.3314 loss_x_val: 6.3151 loss_a_val: 2.0163 time: 0.4438s
# control13 Epoch: 0014 loss_train: 14.1676 loss_kl_train: 0.0008 loss_x_train: 2.2721 loss_a_train: 11.8947 loss_val: 8.1359 loss_x_val: 6.2217 loss_a_val: 1.9142 time: 0.4410s
# control13 Epoch: 0015 loss_train: 14.0474 loss_kl_train: 0.0008 loss_x_train: 2.2265 loss_a_train: 11.8200 loss_val: 8.0549 loss_x_val: 6.0983 loss_a_val: 1.9565 time: 0.4429s
# control13 Epoch: 0016 loss_train: 13.8861 loss_kl_train: 0.0009 loss_x_train: 2.1842 loss_a_train: 11.7011 loss_val: 8.0038 loss_x_val: 5.9701 loss_a_val: 2.0337 time: 0.4408s
# control13 Epoch: 0017 loss_train: 13.7742 loss_kl_train: 0.0010 loss_x_train: 2.1445 loss_a_train: 11.6287 loss_val: 7.8449 loss_x_val: 5.8851 loss_a_val: 1.9597 time: 0.4397s
# control13 Epoch: 0018 loss_train: 13.6266 loss_kl_train: 0.0009 loss_x_train: 2.1074 loss_a_train: 11.5183 loss_val: 7.6527 loss_x_val: 5.8059 loss_a_val: 1.8467 time: 0.4406s
# control13 Epoch: 0019 loss_train: 13.4749 loss_kl_train: 0.0010 loss_x_train: 2.0719 loss_a_train: 11.4021 loss_val: 7.6095 loss_x_val: 5.7127 loss_a_val: 1.8968 time: 0.4452s
# control13 Epoch: 0020 loss_train: 13.3604 loss_kl_train: 0.0011 loss_x_train: 2.0380 loss_a_train: 11.3214 loss_val: 7.5672 loss_x_val: 5.6269 loss_a_val: 1.9403 time: 0.4431s
# control13 Epoch: 0021 loss_train: 13.1361 loss_kl_train: 0.0011 loss_x_train: 2.0061 loss_a_train: 11.1289 loss_val: 7.4276 loss_x_val: 5.5121 loss_a_val: 1.9155 time: 0.4414s
# control13 Epoch: 0022 loss_train: 13.0425 loss_kl_train: 0.0012 loss_x_train: 1.9755 loss_a_train: 11.0659 loss_val: 7.3196 loss_x_val: 5.4307 loss_a_val: 1.8889 time: 0.4424s
# control13 Epoch: 0023 loss_train: 12.9305 loss_kl_train: 0.0012 loss_x_train: 1.9469 loss_a_train: 10.9823 loss_val: 7.3829 loss_x_val: 5.3412 loss_a_val: 2.0416 time: 0.4420s
# control13 Epoch: 0024 loss_train: 12.7526 loss_kl_train: 0.0014 loss_x_train: 1.9194 loss_a_train: 10.8318 loss_val: 7.2113 loss_x_val: 5.2881 loss_a_val: 1.9232 time: 0.4420s
# control13 Epoch: 0025 loss_train: 12.5936 loss_kl_train: 0.0014 loss_x_train: 1.8935 loss_a_train: 10.6987 loss_val: 7.2153 loss_x_val: 5.2263 loss_a_val: 1.9890 time: 0.4407s
# control13 Epoch: 0026 loss_train: 12.5498 loss_kl_train: 0.0015 loss_x_train: 1.8691 loss_a_train: 10.6792 loss_val: 7.1429 loss_x_val: 5.2020 loss_a_val: 1.9410 time: 0.4439s
# control13 Epoch: 0027 loss_train: 12.2991 loss_kl_train: 0.0016 loss_x_train: 1.8459 loss_a_train: 10.4516 loss_val: 7.0923 loss_x_val: 5.1718 loss_a_val: 1.9205 time: 0.4435s
# control13 Epoch: 0028 loss_train: 12.0762 loss_kl_train: 0.0017 loss_x_train: 1.8238 loss_a_train: 10.2507 loss_val: 7.0078 loss_x_val: 5.1473 loss_a_val: 1.8604 time: 0.4470s
# control13 Epoch: 0029 loss_train: 11.9414 loss_kl_train: 0.0019 loss_x_train: 1.8030 loss_a_train: 10.1365 loss_val: 7.0555 loss_x_val: 5.0950 loss_a_val: 1.9605 time: 0.4433s
# control13 Epoch: 0030 loss_train: 11.7892 loss_kl_train: 0.0021 loss_x_train: 1.7836 loss_a_train: 10.0036 loss_val: 6.8673 loss_x_val: 5.0912 loss_a_val: 1.7760 time: 0.4399s
# control13 Epoch: 0031 loss_train: 11.6128 loss_kl_train: 0.0022 loss_x_train: 1.7651 loss_a_train: 9.8454 loss_val: 7.0634 loss_x_val: 4.9760 loss_a_val: 2.0873 time: 0.4423s
# control13 Epoch: 0032 loss_train: 11.4225 loss_kl_train: 0.0025 loss_x_train: 1.7473 loss_a_train: 9.6726 loss_val: 6.7295 loss_x_val: 5.0202 loss_a_val: 1.7094 time: 0.4417s
# control13 Epoch: 0033 loss_train: 11.1703 loss_kl_train: 0.0027 loss_x_train: 1.7308 loss_a_train: 9.4368 loss_val: 6.9573 loss_x_val: 4.8525 loss_a_val: 2.1049 time: 0.4424s
# control13 Epoch: 0034 loss_train: 11.0850 loss_kl_train: 0.0031 loss_x_train: 1.7149 loss_a_train: 9.3671 loss_val: 6.7174 loss_x_val: 4.9146 loss_a_val: 1.8028 time: 0.4417s
# control13 Epoch: 0035 loss_train: 10.8205 loss_kl_train: 0.0033 loss_x_train: 1.7002 loss_a_train: 9.1170 loss_val: 6.8823 loss_x_val: 4.7632 loss_a_val: 2.1191 time: 0.4429s
# control13 Epoch: 0036 loss_train: 10.6558 loss_kl_train: 0.0038 loss_x_train: 1.6860 loss_a_train: 8.9660 loss_val: 6.7315 loss_x_val: 4.8133 loss_a_val: 1.9182 time: 0.4419s
# control13 Epoch: 0037 loss_train: 10.4031 loss_kl_train: 0.0041 loss_x_train: 1.6730 loss_a_train: 8.7260 loss_val: 6.5908 loss_x_val: 4.7376 loss_a_val: 1.8532 time: 0.4427s
# control13 Epoch: 0038 loss_train: 10.2226 loss_kl_train: 0.0046 loss_x_train: 1.6603 loss_a_train: 8.5576 loss_val: 6.9336 loss_x_val: 4.5798 loss_a_val: 2.3538 time: 0.4451s
# control13 Epoch: 0039 loss_train: 10.1680 loss_kl_train: 0.0053 loss_x_train: 1.6489 loss_a_train: 8.5137 loss_val: 6.4380 loss_x_val: 4.8070 loss_a_val: 1.6310 time: 0.4487s
# control13 Epoch: 0040 loss_train: 9.8673 loss_kl_train: 0.0056 loss_x_train: 1.6382 loss_a_train: 8.2236 loss_val: 6.5306 loss_x_val: 4.6001 loss_a_val: 1.9305 time: 0.4436s
# control13 Epoch: 0041 loss_train: 9.6581 loss_kl_train: 0.0064 loss_x_train: 1.6276 loss_a_train: 8.0240 loss_val: 6.6816 loss_x_val: 4.5292 loss_a_val: 2.1524 time: 0.4442s
# control13 Epoch: 0042 loss_train: 9.5387 loss_kl_train: 0.0072 loss_x_train: 1.6185 loss_a_train: 7.9130 loss_val: 6.2800 loss_x_val: 4.7670 loss_a_val: 1.5130 time: 0.4453s
# control13 Epoch: 0043 loss_train: 9.2456 loss_kl_train: 0.0077 loss_x_train: 1.6094 loss_a_train: 7.6286 loss_val: 6.3108 loss_x_val: 4.6946 loss_a_val: 1.6163 time: 0.4415s
# control13 Epoch: 0044 loss_train: 9.0943 loss_kl_train: 0.0085 loss_x_train: 1.6010 loss_a_train: 7.4848 loss_val: 6.7349 loss_x_val: 4.3776 loss_a_val: 2.3573 time: 0.4420s
# control13 Epoch: 0045 loss_train: 9.0218 loss_kl_train: 0.0097 loss_x_train: 1.5927 loss_a_train: 7.4194 loss_val: 6.1570 loss_x_val: 4.6895 loss_a_val: 1.4675 time: 0.4402s
# control13 Epoch: 0046 loss_train: 8.6696 loss_kl_train: 0.0103 loss_x_train: 1.5860 loss_a_train: 7.0733 loss_val: 6.5207 loss_x_val: 4.7100 loss_a_val: 1.8108 time: 0.4434s
# control13 Epoch: 0047 loss_train: 8.7274 loss_kl_train: 0.0114 loss_x_train: 1.5792 loss_a_train: 7.1368 loss_val: 6.3074 loss_x_val: 4.6665 loss_a_val: 1.6409 time: 0.4437s
# control13 Epoch: 0048 loss_train: 8.4082 loss_kl_train: 0.0124 loss_x_train: 1.5728 loss_a_train: 6.8230 loss_val: 6.2127 loss_x_val: 4.4011 loss_a_val: 1.8116 time: 0.4468s
# control13 Epoch: 0049 loss_train: 8.1766 loss_kl_train: 0.0136 loss_x_train: 1.5658 loss_a_train: 6.5972 loss_val: 6.0664 loss_x_val: 4.4005 loss_a_val: 1.6659 time: 0.4456s
# control13 Epoch: 0050 loss_train: 7.9639 loss_kl_train: 0.0149 loss_x_train: 1.5597 loss_a_train: 6.3893 loss_val: 6.0510 loss_x_val: 4.5203 loss_a_val: 1.5307 time: 0.4428s
# control13 Epoch: 0051 loss_train: 7.7837 loss_kl_train: 0.0160 loss_x_train: 1.5557 loss_a_train: 6.2120 loss_val: 6.2168 loss_x_val: 4.4140 loss_a_val: 1.8028 time: 0.4432s
# control13 Epoch: 0052 loss_train: 7.7484 loss_kl_train: 0.0174 loss_x_train: 1.5510 loss_a_train: 6.1800 loss_val: 6.0759 loss_x_val: 4.3700 loss_a_val: 1.7059 time: 0.4443s
# control13 Epoch: 0053 loss_train: 7.5760 loss_kl_train: 0.0187 loss_x_train: 1.5461 loss_a_train: 6.0112 loss_val: 6.1366 loss_x_val: 4.4348 loss_a_val: 1.7018 time: 0.4437s
# control13 Epoch: 0054 loss_train: 7.4579 loss_kl_train: 0.0201 loss_x_train: 1.5426 loss_a_train: 5.8951 loss_val: 5.8576 loss_x_val: 4.4050 loss_a_val: 1.4526 time: 0.4423s
# control13 Epoch: 0055 loss_train: 7.1926 loss_kl_train: 0.0215 loss_x_train: 1.5389 loss_a_train: 5.6322 loss_val: 5.7100 loss_x_val: 4.1344 loss_a_val: 1.5756 time: 0.4391s
# control13 Epoch: 0056 loss_train: 7.0376 loss_kl_train: 0.0232 loss_x_train: 1.5328 loss_a_train: 5.4817 loss_val: 5.9163 loss_x_val: 4.1990 loss_a_val: 1.7173 time: 0.4382s
# control13 Epoch: 0057 loss_train: 6.9864 loss_kl_train: 0.0247 loss_x_train: 1.5303 loss_a_train: 5.4314 loss_val: 5.8515 loss_x_val: 4.3543 loss_a_val: 1.4972 time: 0.4423s
# control13 Epoch: 0058 loss_train: 6.8548 loss_kl_train: 0.0261 loss_x_train: 1.5288 loss_a_train: 5.2999 loss_val: 5.8149 loss_x_val: 4.3152 loss_a_val: 1.4997 time: 0.4439s
# control13 Epoch: 0059 loss_train: 6.7167 loss_kl_train: 0.0278 loss_x_train: 1.5260 loss_a_train: 5.1628 loss_val: 5.9937 loss_x_val: 3.9632 loss_a_val: 2.0305 time: 0.4431s
# control13 Epoch: 0060 loss_train: 6.7666 loss_kl_train: 0.0297 loss_x_train: 1.5203 loss_a_train: 5.2166 loss_val: 5.5150 loss_x_val: 4.2216 loss_a_val: 1.2934 time: 0.4437s
# control13 Epoch: 0061 loss_train: 6.3581 loss_kl_train: 0.0311 loss_x_train: 1.5212 loss_a_train: 4.8058 loss_val: 5.5485 loss_x_val: 4.0435 loss_a_val: 1.5050 time: 0.4416s
# control13 Epoch: 0062 loss_train: 6.3214 loss_kl_train: 0.0328 loss_x_train: 1.5185 loss_a_train: 4.7702 loss_val: 6.2227 loss_x_val: 3.8386 loss_a_val: 2.3841 time: 0.4418s
# control13 Epoch: 0063 loss_train: 6.6710 loss_kl_train: 0.0349 loss_x_train: 1.5120 loss_a_train: 5.1241 loss_val: 5.3980 loss_x_val: 4.3103 loss_a_val: 1.0877 time: 0.4430s
# control13 Epoch: 0064 loss_train: 6.0519 loss_kl_train: 0.0360 loss_x_train: 1.5136 loss_a_train: 4.5023 loss_val: 6.5890 loss_x_val: 3.9227 loss_a_val: 2.6664 time: 0.4474s
# control13 Epoch: 0065 loss_train: 6.6215 loss_kl_train: 0.0381 loss_x_train: 1.5093 loss_a_train: 5.0741 loss_val: 5.1714 loss_x_val: 4.0897 loss_a_val: 1.0817 time: 0.4455s
# control13 Epoch: 0066 loss_train: 5.8075 loss_kl_train: 0.0393 loss_x_train: 1.5087 loss_a_train: 4.2596 loss_val: 6.2050 loss_x_val: 3.7403 loss_a_val: 2.4648 time: 0.4452s
# control13 Epoch: 0067 loss_train: 6.3676 loss_kl_train: 0.0415 loss_x_train: 1.5033 loss_a_train: 4.8227 loss_val: 5.0352 loss_x_val: 3.7512 loss_a_val: 1.2840 time: 0.4475s
# control13 Epoch: 0068 loss_train: 5.7098 loss_kl_train: 0.0426 loss_x_train: 1.5031 loss_a_train: 4.1641 loss_val: 5.5858 loss_x_val: 3.5453 loss_a_val: 2.0405 time: 0.4455s
# control13 Epoch: 0069 loss_train: 5.9078 loss_kl_train: 0.0444 loss_x_train: 1.4994 loss_a_train: 4.3639 loss_val: 4.9129 loss_x_val: 3.4812 loss_a_val: 1.4318 time: 0.4459s
# control13 Epoch: 0070 loss_train: 5.5695 loss_kl_train: 0.0459 loss_x_train: 1.4963 loss_a_train: 4.0274 loss_val: 5.0287 loss_x_val: 3.3012 loss_a_val: 1.7275 time: 0.4451s
# control13 Epoch: 0071 loss_train: 5.6460 loss_kl_train: 0.0476 loss_x_train: 1.4927 loss_a_train: 4.1057 loss_val: 4.7791 loss_x_val: 3.1999 loss_a_val: 1.5792 time: 0.4409s
# control13 Epoch: 0072 loss_train: 5.4320 loss_kl_train: 0.0491 loss_x_train: 1.4903 loss_a_train: 3.8926 loss_val: 4.9818 loss_x_val: 3.2293 loss_a_val: 1.7525 time: 0.4436s
# control13 Epoch: 0073 loss_train: 5.5235 loss_kl_train: 0.0506 loss_x_train: 1.4886 loss_a_train: 3.9842 loss_val: 4.6560 loss_x_val: 3.2485 loss_a_val: 1.4075 time: 0.4423s
# control13 Epoch: 0074 loss_train: 5.2680 loss_kl_train: 0.0521 loss_x_train: 1.4864 loss_a_train: 3.7295 loss_val: 4.8366 loss_x_val: 3.1194 loss_a_val: 1.7172 time: 0.4439s
# control13 Epoch: 0075 loss_train: 5.3732 loss_kl_train: 0.0537 loss_x_train: 1.4821 loss_a_train: 3.8373 loss_val: 4.3565 loss_x_val: 3.0617 loss_a_val: 1.2948 time: 0.4462s
# control13 Epoch: 0076 loss_train: 5.0804 loss_kl_train: 0.0551 loss_x_train: 1.4795 loss_a_train: 3.5458 loss_val: 5.4417 loss_x_val: 2.8779 loss_a_val: 2.5638 time: 0.4469s
# control13 Epoch: 0077 loss_train: 5.7312 loss_kl_train: 0.0571 loss_x_train: 1.4767 loss_a_train: 4.1974 loss_val: 4.3798 loss_x_val: 3.0769 loss_a_val: 1.3029 time: 0.4448s
# control13 Epoch: 0078 loss_train: 4.9878 loss_kl_train: 0.0581 loss_x_train: 1.4756 loss_a_train: 3.4541 loss_val: 5.1403 loss_x_val: 3.0008 loss_a_val: 2.1394 time: 0.4439s
# control13 Epoch: 0079 loss_train: 5.4270 loss_kl_train: 0.0599 loss_x_train: 1.4726 loss_a_train: 3.8945 loss_val: 4.4161 loss_x_val: 3.0282 loss_a_val: 1.3880 time: 0.4467s
# control13 Epoch: 0080 loss_train: 4.9338 loss_kl_train: 0.0611 loss_x_train: 1.4727 loss_a_train: 3.4001 loss_val: 4.8253 loss_x_val: 2.9696 loss_a_val: 1.8557 time: 0.4464s
# control13 Epoch: 0081 loss_train: 5.1408 loss_kl_train: 0.0626 loss_x_train: 1.4673 loss_a_train: 3.6109 loss_val: 4.4456 loss_x_val: 2.9146 loss_a_val: 1.5310 time: 0.4441s
# control13 Epoch: 0082 loss_train: 4.8936 loss_kl_train: 0.0639 loss_x_train: 1.4662 loss_a_train: 3.3634 loss_val: 4.5534 loss_x_val: 2.8876 loss_a_val: 1.6658 time: 0.4453s
# control13 Epoch: 0083 loss_train: 4.9116 loss_kl_train: 0.0654 loss_x_train: 1.4626 loss_a_train: 3.3836 loss_val: 4.3607 loss_x_val: 2.9211 loss_a_val: 1.4396 time: 0.4457s
# control13 Epoch: 0084 loss_train: 4.7698 loss_kl_train: 0.0666 loss_x_train: 1.4614 loss_a_train: 3.2417 loss_val: 4.9411 loss_x_val: 2.7951 loss_a_val: 2.1459 time: 0.4464s
# control13 Epoch: 0085 loss_train: 5.1462 loss_kl_train: 0.0682 loss_x_train: 1.4580 loss_a_train: 3.6200 loss_val: 4.4014 loss_x_val: 2.9048 loss_a_val: 1.4966 time: 0.4456s
# control13 Epoch: 0086 loss_train: 4.7016 loss_kl_train: 0.0693 loss_x_train: 1.4575 loss_a_train: 3.1748 loss_val: 4.5201 loss_x_val: 2.8820 loss_a_val: 1.6380 time: 0.4467s
# control13 Epoch: 0087 loss_train: 4.7607 loss_kl_train: 0.0707 loss_x_train: 1.4546 loss_a_train: 3.2354 loss_val: 4.4785 loss_x_val: 2.9121 loss_a_val: 1.5665 time: 0.4493s
# control13 Epoch: 0088 loss_train: 4.6605 loss_kl_train: 0.0719 loss_x_train: 1.4532 loss_a_train: 3.1353 loss_val: 4.4991 loss_x_val: 2.9132 loss_a_val: 1.5859 time: 0.4443s
# control13 Epoch: 0089 loss_train: 4.6444 loss_kl_train: 0.0732 loss_x_train: 1.4501 loss_a_train: 3.1211 loss_val: 4.4692 loss_x_val: 2.9206 loss_a_val: 1.5486 time: 0.4431s
# control13 Epoch: 0090 loss_train: 4.5956 loss_kl_train: 0.0745 loss_x_train: 1.4484 loss_a_train: 3.0727 loss_val: 4.4803 loss_x_val: 2.8949 loss_a_val: 1.5854 time: 0.4429s
# control13 Epoch: 0091 loss_train: 4.5741 loss_kl_train: 0.0758 loss_x_train: 1.4461 loss_a_train: 3.0521 loss_val: 4.4853 loss_x_val: 2.9159 loss_a_val: 1.5693 time: 0.4433s
# control13 Epoch: 0092 loss_train: 4.5268 loss_kl_train: 0.0771 loss_x_train: 1.4450 loss_a_train: 3.0047 loss_val: 4.4989 loss_x_val: 2.9183 loss_a_val: 1.5806 time: 0.4443s
# control13 Epoch: 0093 loss_train: 4.5185 loss_kl_train: 0.0783 loss_x_train: 1.4436 loss_a_train: 2.9965 loss_val: 4.5158 loss_x_val: 2.9118 loss_a_val: 1.6040 time: 0.4480s
# control13 Epoch: 0094 loss_train: 4.4705 loss_kl_train: 0.0796 loss_x_train: 1.4413 loss_a_train: 2.9496 loss_val: 4.5145 loss_x_val: 2.9241 loss_a_val: 1.5904 time: 0.4466s
# control13 Epoch: 0095 loss_train: 4.4548 loss_kl_train: 0.0809 loss_x_train: 1.4393 loss_a_train: 2.9346 loss_val: 4.6175 loss_x_val: 2.9127 loss_a_val: 1.7047 time: 0.4452s
# control13 Epoch: 0096 loss_train: 4.4919 loss_kl_train: 0.0822 loss_x_train: 1.4387 loss_a_train: 2.9710 loss_val: 4.5167 loss_x_val: 2.9253 loss_a_val: 1.5914 time: 0.4455s
# control13 Epoch: 0097 loss_train: 4.3785 loss_kl_train: 0.0833 loss_x_train: 1.4369 loss_a_train: 2.8583 loss_val: 4.5094 loss_x_val: 2.9057 loss_a_val: 1.6037 time: 0.4445s
# control13 Epoch: 0098 loss_train: 4.3796 loss_kl_train: 0.0845 loss_x_train: 1.4355 loss_a_train: 2.8596 loss_val: 4.5210 loss_x_val: 2.8899 loss_a_val: 1.6310 time: 0.4466s
# control13 Epoch: 0099 loss_train: 4.3528 loss_kl_train: 0.0857 loss_x_train: 1.4333 loss_a_train: 2.8338 loss_val: 4.4445 loss_x_val: 2.8657 loss_a_val: 1.5788 time: 0.4449s
# disease13 Epoch: 0100 loss_train: 4.5641 loss_kl_train: 0.0783 loss_x_train: 1.5699 loss_a_train: 2.9160 loss_val: 4.8591 loss_x_val: 3.0455 loss_a_val: 1.8136 time: 0.7417s
# disease13 Epoch: 0101 loss_train: 4.4937 loss_kl_train: 0.0790 loss_x_train: 1.5783 loss_a_train: 2.8363 loss_val: 5.0240 loss_x_val: 3.0313 loss_a_val: 1.9927 time: 0.6733s
# disease13 Epoch: 0102 loss_train: 4.6193 loss_kl_train: 0.0800 loss_x_train: 1.5767 loss_a_train: 2.9626 loss_val: 5.5406 loss_x_val: 2.9313 loss_a_val: 2.6094 time: 0.6755s
# disease13 Epoch: 0103 loss_train: 5.0340 loss_kl_train: 0.0810 loss_x_train: 1.5740 loss_a_train: 3.3790 loss_val: 4.7983 loss_x_val: 3.0009 loss_a_val: 1.7974 time: 0.6736s
# disease13 Epoch: 0104 loss_train: 4.4329 loss_kl_train: 0.0816 loss_x_train: 1.5731 loss_a_train: 2.7782 loss_val: 5.4907 loss_x_val: 2.9319 loss_a_val: 2.5588 time: 0.6765s
# disease13 Epoch: 0105 loss_train: 4.9803 loss_kl_train: 0.0825 loss_x_train: 1.5711 loss_a_train: 3.3267 loss_val: 4.8451 loss_x_val: 3.0370 loss_a_val: 1.8081 time: 0.6758s
# disease13 Epoch: 0106 loss_train: 4.4167 loss_kl_train: 0.0830 loss_x_train: 1.5701 loss_a_train: 2.7636 loss_val: 5.4149 loss_x_val: 3.0521 loss_a_val: 2.3628 time: 0.6726s
# disease13 Epoch: 0107 loss_train: 4.8197 loss_kl_train: 0.0837 loss_x_train: 1.5675 loss_a_train: 3.1685 loss_val: 5.0193 loss_x_val: 3.1843 loss_a_val: 1.8350 time: 0.6742s
# disease13 Epoch: 0108 loss_train: 4.4212 loss_kl_train: 0.0841 loss_x_train: 1.5664 loss_a_train: 2.7708 loss_val: 5.5281 loss_x_val: 3.2041 loss_a_val: 2.3240 time: 0.6716s
# disease13 Epoch: 0109 loss_train: 4.7583 loss_kl_train: 0.0847 loss_x_train: 1.5651 loss_a_train: 3.1085 loss_val: 5.2415 loss_x_val: 3.3639 loss_a_val: 1.8776 time: 0.6738s
# disease13 Epoch: 0110 loss_train: 4.4538 loss_kl_train: 0.0850 loss_x_train: 1.5633 loss_a_train: 2.8056 loss_val: 5.4427 loss_x_val: 3.3823 loss_a_val: 2.0604 time: 0.6743s
# disease13 Epoch: 0111 loss_train: 4.5408 loss_kl_train: 0.0854 loss_x_train: 1.5622 loss_a_train: 2.8932 loss_val: 5.3888 loss_x_val: 3.4835 loss_a_val: 1.9054 time: 0.6750s
# disease13 Epoch: 0112 loss_train: 4.4275 loss_kl_train: 0.0858 loss_x_train: 1.5604 loss_a_train: 2.7813 loss_val: 5.4150 loss_x_val: 3.4278 loss_a_val: 1.9872 time: 0.6811s
# disease13 Epoch: 0113 loss_train: 4.4587 loss_kl_train: 0.0862 loss_x_train: 1.5584 loss_a_train: 2.8141 loss_val: 5.4668 loss_x_val: 3.6164 loss_a_val: 1.8504 time: 0.6801s
# disease13 Epoch: 0114 loss_train: 4.3680 loss_kl_train: 0.0864 loss_x_train: 1.5578 loss_a_train: 2.7237 loss_val: 5.9741 loss_x_val: 3.4191 loss_a_val: 2.5550 time: 0.6765s
# disease13 Epoch: 0115 loss_train: 4.9094 loss_kl_train: 0.0868 loss_x_train: 1.5553 loss_a_train: 3.2672 loss_val: 5.4451 loss_x_val: 3.6439 loss_a_val: 1.8012 time: 0.6739s
# disease13 Epoch: 0116 loss_train: 4.3354 loss_kl_train: 0.0869 loss_x_train: 1.5550 loss_a_train: 2.6935 loss_val: 5.4122 loss_x_val: 3.5808 loss_a_val: 1.8315 time: 0.6736s
# disease13 Epoch: 0117 loss_train: 4.3602 loss_kl_train: 0.0871 loss_x_train: 1.5537 loss_a_train: 2.7195 loss_val: 5.4642 loss_x_val: 3.4315 loss_a_val: 2.0327 time: 0.6763s
# disease13 Epoch: 0118 loss_train: 4.4542 loss_kl_train: 0.0873 loss_x_train: 1.5523 loss_a_train: 2.8146 loss_val: 5.3110 loss_x_val: 3.4975 loss_a_val: 1.8136 time: 0.6764s
# disease13 Epoch: 0119 loss_train: 4.3182 loss_kl_train: 0.0875 loss_x_train: 1.5505 loss_a_train: 2.6802 loss_val: 5.2902 loss_x_val: 3.4029 loss_a_val: 1.8873 time: 0.6737s
# disease13 Epoch: 0120 loss_train: 4.3482 loss_kl_train: 0.0877 loss_x_train: 1.5498 loss_a_train: 2.7107 loss_val: 5.2592 loss_x_val: 3.4823 loss_a_val: 1.7770 time: 0.6728s
# disease13 Epoch: 0121 loss_train: 4.2790 loss_kl_train: 0.0878 loss_x_train: 1.5480 loss_a_train: 2.6431 loss_val: 5.7250 loss_x_val: 3.2759 loss_a_val: 2.4491 time: 0.6737s
# disease13 Epoch: 0122 loss_train: 4.8133 loss_kl_train: 0.0881 loss_x_train: 1.5480 loss_a_train: 3.1773 loss_val: 5.2287 loss_x_val: 3.4872 loss_a_val: 1.7415 time: 0.6780s
# disease13 Epoch: 0123 loss_train: 4.2520 loss_kl_train: 0.0881 loss_x_train: 1.5457 loss_a_train: 2.6183 loss_val: 5.1825 loss_x_val: 3.4233 loss_a_val: 1.7592 time: 0.6817s
# disease13 Epoch: 0124 loss_train: 4.2308 loss_kl_train: 0.0882 loss_x_train: 1.5452 loss_a_train: 2.5973 loss_val: 5.2334 loss_x_val: 3.5173 loss_a_val: 1.7161 time: 0.6817s
# disease13 Epoch: 0125 loss_train: 4.2147 loss_kl_train: 0.0883 loss_x_train: 1.5433 loss_a_train: 2.5832 loss_val: 5.4109 loss_x_val: 3.3322 loss_a_val: 2.0787 time: 0.6813s
# disease13 Epoch: 0126 loss_train: 4.4722 loss_kl_train: 0.0885 loss_x_train: 1.5425 loss_a_train: 2.8412 loss_val: 5.2505 loss_x_val: 3.5514 loss_a_val: 1.6991 time: 0.6755s
# disease13 Epoch: 0127 loss_train: 4.1915 loss_kl_train: 0.0886 loss_x_train: 1.5413 loss_a_train: 2.5616 loss_val: 5.1742 loss_x_val: 3.3742 loss_a_val: 1.8000 time: 0.6755s
# disease13 Epoch: 0128 loss_train: 4.2127 loss_kl_train: 0.0888 loss_x_train: 1.5396 loss_a_train: 2.5843 loss_val: 5.2492 loss_x_val: 3.5747 loss_a_val: 1.6745 time: 0.6754s
# disease13 Epoch: 0129 loss_train: 4.1684 loss_kl_train: 0.0889 loss_x_train: 1.5393 loss_a_train: 2.5402 loss_val: 5.2247 loss_x_val: 3.4792 loss_a_val: 1.7456 time: 0.6721s
# disease13 Epoch: 0130 loss_train: 4.1849 loss_kl_train: 0.0890 loss_x_train: 1.5381 loss_a_train: 2.5578 loss_val: 5.1314 loss_x_val: 3.4087 loss_a_val: 1.7227 time: 0.6744s
# disease13 Epoch: 0131 loss_train: 4.1610 loss_kl_train: 0.0893 loss_x_train: 1.5371 loss_a_train: 2.5346 loss_val: 5.1569 loss_x_val: 3.5118 loss_a_val: 1.6451 time: 0.6754s
# disease13 Epoch: 0132 loss_train: 4.1167 loss_kl_train: 0.0894 loss_x_train: 1.5369 loss_a_train: 2.4903 loss_val: 5.3704 loss_x_val: 3.3253 loss_a_val: 2.0452 time: 0.6784s
# disease13 Epoch: 0133 loss_train: 4.4149 loss_kl_train: 0.0897 loss_x_train: 1.5354 loss_a_train: 2.7898 loss_val: 5.1103 loss_x_val: 3.4833 loss_a_val: 1.6269 time: 0.6796s
# disease13 Epoch: 0134 loss_train: 4.1075 loss_kl_train: 0.0897 loss_x_train: 1.5356 loss_a_train: 2.4822 loss_val: 4.9828 loss_x_val: 3.2773 loss_a_val: 1.7054 time: 0.6814s
# disease13 Epoch: 0135 loss_train: 4.1271 loss_kl_train: 0.0899 loss_x_train: 1.5340 loss_a_train: 2.5032 loss_val: 4.9865 loss_x_val: 3.3831 loss_a_val: 1.6035 time: 0.6820s
# disease13 Epoch: 0136 loss_train: 4.0533 loss_kl_train: 0.0901 loss_x_train: 1.5333 loss_a_train: 2.4300 loss_val: 4.9152 loss_x_val: 3.2052 loss_a_val: 1.7100 time: 0.6798s
# disease13 Epoch: 0137 loss_train: 4.0967 loss_kl_train: 0.0903 loss_x_train: 1.5317 loss_a_train: 2.4748 loss_val: 4.9656 loss_x_val: 3.3829 loss_a_val: 1.5827 time: 0.6724s
# disease13 Epoch: 0138 loss_train: 4.0415 loss_kl_train: 0.0904 loss_x_train: 1.5316 loss_a_train: 2.4195 loss_val: 4.8557 loss_x_val: 3.2142 loss_a_val: 1.6415 time: 0.6770s
# disease13 Epoch: 0139 loss_train: 4.0418 loss_kl_train: 0.0907 loss_x_train: 1.5301 loss_a_train: 2.4210 loss_val: 4.8285 loss_x_val: 3.2582 loss_a_val: 1.5703 time: 0.6770s
# disease13 Epoch: 0140 loss_train: 4.0019 loss_kl_train: 0.0909 loss_x_train: 1.5300 loss_a_train: 2.3810 loss_val: 4.6906 loss_x_val: 3.0740 loss_a_val: 1.6166 time: 0.6775s
# disease13 Epoch: 0141 loss_train: 4.0052 loss_kl_train: 0.0912 loss_x_train: 1.5280 loss_a_train: 2.3861 loss_val: 4.7730 loss_x_val: 3.2322 loss_a_val: 1.5408 time: 0.6773s
# disease13 Epoch: 0142 loss_train: 3.9772 loss_kl_train: 0.0914 loss_x_train: 1.5286 loss_a_train: 2.3572 loss_val: 4.6592 loss_x_val: 3.0685 loss_a_val: 1.5908 time: 0.6819s
# disease13 Epoch: 0143 loss_train: 3.9854 loss_kl_train: 0.0917 loss_x_train: 1.5269 loss_a_train: 2.3669 loss_val: 4.7486 loss_x_val: 3.2355 loss_a_val: 1.5130 time: 0.6816s
# disease13 Epoch: 0144 loss_train: 3.9365 loss_kl_train: 0.0919 loss_x_train: 1.5272 loss_a_train: 2.3173 loss_val: 4.6473 loss_x_val: 3.1065 loss_a_val: 1.5408 time: 0.6813s
# disease13 Epoch: 0145 loss_train: 3.9261 loss_kl_train: 0.0922 loss_x_train: 1.5253 loss_a_train: 2.3085 loss_val: 4.6805 loss_x_val: 3.1891 loss_a_val: 1.4914 time: 0.6789s
# disease13 Epoch: 0146 loss_train: 3.8998 loss_kl_train: 0.0925 loss_x_train: 1.5255 loss_a_train: 2.2819 loss_val: 4.6352 loss_x_val: 3.1463 loss_a_val: 1.4889 time: 0.6774s
# disease13 Epoch: 0147 loss_train: 3.8779 loss_kl_train: 0.0928 loss_x_train: 1.5246 loss_a_train: 2.2605 loss_val: 4.5834 loss_x_val: 3.1158 loss_a_val: 1.4675 time: 0.6739s
# disease13 Epoch: 0148 loss_train: 3.8485 loss_kl_train: 0.0931 loss_x_train: 1.5239 loss_a_train: 2.2315 loss_val: 4.5776 loss_x_val: 3.1406 loss_a_val: 1.4369 time: 0.6761s
# disease13 Epoch: 0149 loss_train: 3.8256 loss_kl_train: 0.0934 loss_x_train: 1.5239 loss_a_train: 2.2083 loss_val: 4.5304 loss_x_val: 3.0995 loss_a_val: 1.4309 time: 0.6770s
# disease13 Epoch: 0150 loss_train: 3.8065 loss_kl_train: 0.0938 loss_x_train: 1.5226 loss_a_train: 2.1901 loss_val: 4.5204 loss_x_val: 3.1294 loss_a_val: 1.3910 time: 0.6757s
# disease13 Epoch: 0151 loss_train: 3.7702 loss_kl_train: 0.0941 loss_x_train: 1.5222 loss_a_train: 2.1538 loss_val: 4.4761 loss_x_val: 3.1034 loss_a_val: 1.3728 time: 0.6770s
# disease13 Epoch: 0152 loss_train: 3.7439 loss_kl_train: 0.0945 loss_x_train: 1.5216 loss_a_train: 2.1278 loss_val: 4.4569 loss_x_val: 3.1056 loss_a_val: 1.3513 time: 0.6825s
# disease13 Epoch: 0153 loss_train: 3.7176 loss_kl_train: 0.0949 loss_x_train: 1.5211 loss_a_train: 2.1016 loss_val: 4.3916 loss_x_val: 3.0673 loss_a_val: 1.3243 time: 0.6813s
# disease13 Epoch: 0154 loss_train: 3.6935 loss_kl_train: 0.0953 loss_x_train: 1.5210 loss_a_train: 2.0773 loss_val: 4.3188 loss_x_val: 3.0173 loss_a_val: 1.3015 time: 0.6756s
# disease13 Epoch: 0155 loss_train: 3.6525 loss_kl_train: 0.0957 loss_x_train: 1.5201 loss_a_train: 2.0367 loss_val: 4.3153 loss_x_val: 3.0163 loss_a_val: 1.2990 time: 0.6760s
# disease13 Epoch: 0156 loss_train: 3.6551 loss_kl_train: 0.0961 loss_x_train: 1.5190 loss_a_train: 2.0399 loss_val: 4.2654 loss_x_val: 3.0224 loss_a_val: 1.2431 time: 0.6777s
# disease13 Epoch: 0157 loss_train: 3.6088 loss_kl_train: 0.0966 loss_x_train: 1.5189 loss_a_train: 1.9933 loss_val: 4.1967 loss_x_val: 2.9595 loss_a_val: 1.2372 time: 0.6777s
# disease13 Epoch: 0158 loss_train: 3.5779 loss_kl_train: 0.0971 loss_x_train: 1.5189 loss_a_train: 1.9619 loss_val: 4.2035 loss_x_val: 3.0029 loss_a_val: 1.2006 time: 0.6742s
# disease13 Epoch: 0159 loss_train: 3.5396 loss_kl_train: 0.0975 loss_x_train: 1.5190 loss_a_train: 1.9230 loss_val: 4.1476 loss_x_val: 2.9649 loss_a_val: 1.1827 time: 0.6736s
# disease13 Epoch: 0160 loss_train: 3.5166 loss_kl_train: 0.0980 loss_x_train: 1.5184 loss_a_train: 1.9001 loss_val: 4.1157 loss_x_val: 2.9538 loss_a_val: 1.1619 time: 0.6759s
# disease13 Epoch: 0161 loss_train: 3.4947 loss_kl_train: 0.0986 loss_x_train: 1.5174 loss_a_train: 1.8788 loss_val: 4.0434 loss_x_val: 2.8932 loss_a_val: 1.1501 time: 0.6764s
# disease13 Epoch: 0162 loss_train: 3.4652 loss_kl_train: 0.0992 loss_x_train: 1.5169 loss_a_train: 1.8491 loss_val: 4.0442 loss_x_val: 2.9346 loss_a_val: 1.1096 time: 0.6793s
# disease13 Epoch: 0163 loss_train: 3.4270 loss_kl_train: 0.0997 loss_x_train: 1.5175 loss_a_train: 1.8098 loss_val: 3.9819 loss_x_val: 2.8714 loss_a_val: 1.1105 time: 0.6810s
# disease13 Epoch: 0164 loss_train: 3.4053 loss_kl_train: 0.1003 loss_x_train: 1.5163 loss_a_train: 1.7887 loss_val: 3.9450 loss_x_val: 2.8540 loss_a_val: 1.0910 time: 0.6793s
# disease13 Epoch: 0165 loss_train: 3.3871 loss_kl_train: 0.1009 loss_x_train: 1.5165 loss_a_train: 1.7696 loss_val: 3.8822 loss_x_val: 2.8098 loss_a_val: 1.0725 time: 0.6760s
# disease13 Epoch: 0166 loss_train: 3.3661 loss_kl_train: 0.1015 loss_x_train: 1.5158 loss_a_train: 1.7488 loss_val: 3.8049 loss_x_val: 2.7457 loss_a_val: 1.0592 time: 0.6779s
# disease13 Epoch: 0167 loss_train: 3.3409 loss_kl_train: 0.1022 loss_x_train: 1.5150 loss_a_train: 1.7236 loss_val: 3.7618 loss_x_val: 2.7203 loss_a_val: 1.0415 time: 0.6774s
# disease13 Epoch: 0168 loss_train: 3.3134 loss_kl_train: 0.1028 loss_x_train: 1.5145 loss_a_train: 1.6961 loss_val: 3.7283 loss_x_val: 2.6998 loss_a_val: 1.0286 time: 0.6787s
# disease13 Epoch: 0169 loss_train: 3.2894 loss_kl_train: 0.1035 loss_x_train: 1.5143 loss_a_train: 1.6716 loss_val: 3.6905 loss_x_val: 2.6784 loss_a_val: 1.0120 time: 0.6737s
# disease13 Epoch: 0170 loss_train: 3.2621 loss_kl_train: 0.1042 loss_x_train: 1.5142 loss_a_train: 1.6437 loss_val: 3.6456 loss_x_val: 2.6385 loss_a_val: 1.0071 time: 0.6757s
# disease13 Epoch: 0171 loss_train: 3.2526 loss_kl_train: 0.1049 loss_x_train: 1.5134 loss_a_train: 1.6343 loss_val: 3.6066 loss_x_val: 2.6127 loss_a_val: 0.9939 time: 0.6743s
# disease13 Epoch: 0172 loss_train: 3.2210 loss_kl_train: 0.1057 loss_x_train: 1.5128 loss_a_train: 1.6025 loss_val: 3.5970 loss_x_val: 2.6227 loss_a_val: 0.9743 time: 0.6804s
# disease13 Epoch: 0173 loss_train: 3.2085 loss_kl_train: 0.1064 loss_x_train: 1.5132 loss_a_train: 1.5889 loss_val: 3.5271 loss_x_val: 2.5416 loss_a_val: 0.9855 time: 0.6841s
# disease13 Epoch: 0174 loss_train: 3.1907 loss_kl_train: 0.1072 loss_x_train: 1.5125 loss_a_train: 1.5710 loss_val: 3.5092 loss_x_val: 2.5566 loss_a_val: 0.9526 time: 0.6798s
# disease13 Epoch: 0175 loss_train: 3.1708 loss_kl_train: 0.1079 loss_x_train: 1.5131 loss_a_train: 1.5498 loss_val: 3.4338 loss_x_val: 2.4726 loss_a_val: 0.9612 time: 0.6794s
# disease13 Epoch: 0176 loss_train: 3.1542 loss_kl_train: 0.1087 loss_x_train: 1.5117 loss_a_train: 1.5338 loss_val: 3.4251 loss_x_val: 2.4880 loss_a_val: 0.9371 time: 0.6781s
# disease13 Epoch: 0177 loss_train: 3.1249 loss_kl_train: 0.1095 loss_x_train: 1.5118 loss_a_train: 1.5036 loss_val: 3.3477 loss_x_val: 2.4000 loss_a_val: 0.9477 time: 0.6793s
# disease13 Epoch: 0178 loss_train: 3.1122 loss_kl_train: 0.1103 loss_x_train: 1.5104 loss_a_train: 1.4914 loss_val: 3.3569 loss_x_val: 2.4297 loss_a_val: 0.9272 time: 0.6797s
# disease13 Epoch: 0179 loss_train: 3.0948 loss_kl_train: 0.1111 loss_x_train: 1.5110 loss_a_train: 1.4728 loss_val: 3.2903 loss_x_val: 2.3649 loss_a_val: 0.9254 time: 0.6733s
# disease13 Epoch: 0180 loss_train: 3.0767 loss_kl_train: 0.1119 loss_x_train: 1.5103 loss_a_train: 1.4545 loss_val: 3.2289 loss_x_val: 2.3035 loss_a_val: 0.9254 time: 0.6751s
# disease13 Epoch: 0181 loss_train: 3.0637 loss_kl_train: 0.1127 loss_x_train: 1.5088 loss_a_train: 1.4422 loss_val: 3.2658 loss_x_val: 2.3665 loss_a_val: 0.8993 time: 0.6749s
# disease13 Epoch: 0182 loss_train: 3.0533 loss_kl_train: 0.1135 loss_x_train: 1.5116 loss_a_train: 1.4282 loss_val: 3.1713 loss_x_val: 2.2338 loss_a_val: 0.9375 time: 0.6787s
# disease13 Epoch: 0183 loss_train: 3.0480 loss_kl_train: 0.1144 loss_x_train: 1.5080 loss_a_train: 1.4257 loss_val: 3.2144 loss_x_val: 2.3212 loss_a_val: 0.8931 time: 0.6790s
# disease13 Epoch: 0184 loss_train: 3.0196 loss_kl_train: 0.1152 loss_x_train: 1.5108 loss_a_train: 1.3935 loss_val: 3.1423 loss_x_val: 2.2286 loss_a_val: 0.9137 time: 0.6801s
# disease13 Epoch: 0185 loss_train: 3.0204 loss_kl_train: 0.1161 loss_x_train: 1.5075 loss_a_train: 1.3968 loss_val: 3.1186 loss_x_val: 2.2299 loss_a_val: 0.8888 time: 0.6750s
# disease13 Epoch: 0186 loss_train: 2.9912 loss_kl_train: 0.1169 loss_x_train: 1.5088 loss_a_train: 1.3656 loss_val: 3.0428 loss_x_val: 2.1477 loss_a_val: 0.8950 time: 0.6754s
# disease13 Epoch: 0187 loss_train: 2.9857 loss_kl_train: 0.1177 loss_x_train: 1.5063 loss_a_train: 1.3617 loss_val: 3.0252 loss_x_val: 2.1416 loss_a_val: 0.8836 time: 0.6780s
# disease13 Epoch: 0188 loss_train: 2.9706 loss_kl_train: 0.1186 loss_x_train: 1.5075 loss_a_train: 1.3445 loss_val: 3.0017 loss_x_val: 2.1165 loss_a_val: 0.8853 time: 0.6776s
# disease13 Epoch: 0189 loss_train: 2.9712 loss_kl_train: 0.1194 loss_x_train: 1.5060 loss_a_train: 1.3458 loss_val: 2.9925 loss_x_val: 2.1085 loss_a_val: 0.8840 time: 0.6780s
# disease13 Epoch: 0190 loss_train: 2.9435 loss_kl_train: 0.1202 loss_x_train: 1.5069 loss_a_train: 1.3163 loss_val: 2.9672 loss_x_val: 2.0880 loss_a_val: 0.8792 time: 0.6739s
# disease13 Epoch: 0191 loss_train: 2.9343 loss_kl_train: 0.1211 loss_x_train: 1.5060 loss_a_train: 1.3072 loss_val: 2.9306 loss_x_val: 2.0528 loss_a_val: 0.8778 time: 0.6762s
# disease13 Epoch: 0192 loss_train: 2.9262 loss_kl_train: 0.1220 loss_x_train: 1.5054 loss_a_train: 1.2988 loss_val: 2.9053 loss_x_val: 2.0375 loss_a_val: 0.8678 time: 0.6795s
# disease13 Epoch: 0193 loss_train: 2.9144 loss_kl_train: 0.1228 loss_x_train: 1.5056 loss_a_train: 1.2860 loss_val: 2.8897 loss_x_val: 2.0047 loss_a_val: 0.8850 time: 0.6797s
# disease13 Epoch: 0194 loss_train: 2.9072 loss_kl_train: 0.1236 loss_x_train: 1.5045 loss_a_train: 1.2791 loss_val: 2.9054 loss_x_val: 2.0407 loss_a_val: 0.8647 time: 0.6790s
# disease13 Epoch: 0195 loss_train: 2.8972 loss_kl_train: 0.1245 loss_x_train: 1.5057 loss_a_train: 1.2670 loss_val: 2.8496 loss_x_val: 1.9734 loss_a_val: 0.8761 time: 0.6780s
# disease13 Epoch: 0196 loss_train: 2.8876 loss_kl_train: 0.1253 loss_x_train: 1.5032 loss_a_train: 1.2590 loss_val: 2.8334 loss_x_val: 1.9795 loss_a_val: 0.8540 time: 0.6787s
# disease13 Epoch: 0197 loss_train: 2.8805 loss_kl_train: 0.1261 loss_x_train: 1.5042 loss_a_train: 1.2501 loss_val: 2.8144 loss_x_val: 1.9497 loss_a_val: 0.8647 time: 0.6744s
# disease13 Epoch: 0198 loss_train: 2.8630 loss_kl_train: 0.1270 loss_x_train: 1.5033 loss_a_train: 1.2327 loss_val: 2.7872 loss_x_val: 1.9361 loss_a_val: 0.8511 time: 0.6761s
# disease13 Epoch: 0199 loss_train: 2.8469 loss_kl_train: 0.1278 loss_x_train: 1.5032 loss_a_train: 1.2159 loss_val: 2.7551 loss_x_val: 1.9000 loss_a_val: 0.8551 time: 0.6792s
# disease8 Epoch: 0200 loss_train: 2.9369 loss_kl_train: 0.1450 loss_x_train: 1.3112 loss_a_train: 1.4807 loss_val: 2.6735 loss_x_val: 1.7771 loss_a_val: 0.8964 time: 0.4072s
# disease8 Epoch: 0201 loss_train: 2.8803 loss_kl_train: 0.1461 loss_x_train: 1.3112 loss_a_train: 1.4231 loss_val: 2.6432 loss_x_val: 1.7409 loss_a_val: 0.9023 time: 0.4047s
# disease8 Epoch: 0202 loss_train: 2.8738 loss_kl_train: 0.1471 loss_x_train: 1.3108 loss_a_train: 1.4159 loss_val: 2.5846 loss_x_val: 1.6942 loss_a_val: 0.8905 time: 0.4042s
# disease8 Epoch: 0203 loss_train: 2.8672 loss_kl_train: 0.1482 loss_x_train: 1.3105 loss_a_train: 1.4085 loss_val: 2.5526 loss_x_val: 1.6822 loss_a_val: 0.8704 time: 0.4034s
# disease8 Epoch: 0204 loss_train: 2.8626 loss_kl_train: 0.1494 loss_x_train: 1.3096 loss_a_train: 1.4036 loss_val: 2.5422 loss_x_val: 1.6548 loss_a_val: 0.8874 time: 0.4052s
# disease8 Epoch: 0205 loss_train: 2.8422 loss_kl_train: 0.1506 loss_x_train: 1.3098 loss_a_train: 1.3818 loss_val: 2.5347 loss_x_val: 1.6478 loss_a_val: 0.8869 time: 0.4027s
# disease8 Epoch: 0206 loss_train: 2.8304 loss_kl_train: 0.1518 loss_x_train: 1.3078 loss_a_train: 1.3709 loss_val: 2.4871 loss_x_val: 1.6014 loss_a_val: 0.8857 time: 0.4050s
# disease8 Epoch: 0207 loss_train: 2.8265 loss_kl_train: 0.1530 loss_x_train: 1.3078 loss_a_train: 1.3657 loss_val: 2.4823 loss_x_val: 1.5890 loss_a_val: 0.8933 time: 0.4051s
# disease8 Epoch: 0208 loss_train: 2.8223 loss_kl_train: 0.1542 loss_x_train: 1.3071 loss_a_train: 1.3610 loss_val: 2.4691 loss_x_val: 1.5792 loss_a_val: 0.8899 time: 0.4062s
# disease8 Epoch: 0209 loss_train: 2.8009 loss_kl_train: 0.1554 loss_x_train: 1.3077 loss_a_train: 1.3377 loss_val: 2.4653 loss_x_val: 1.5746 loss_a_val: 0.8907 time: 0.4031s
# disease8 Epoch: 0210 loss_train: 2.8039 loss_kl_train: 0.1567 loss_x_train: 1.3077 loss_a_train: 1.3395 loss_val: 2.4479 loss_x_val: 1.5573 loss_a_val: 0.8906 time: 0.4017s
# disease8 Epoch: 0211 loss_train: 2.7992 loss_kl_train: 0.1580 loss_x_train: 1.3064 loss_a_train: 1.3348 loss_val: 2.4349 loss_x_val: 1.5439 loss_a_val: 0.8910 time: 0.4042s
# disease8 Epoch: 0212 loss_train: 2.7914 loss_kl_train: 0.1592 loss_x_train: 1.3060 loss_a_train: 1.3262 loss_val: 2.4244 loss_x_val: 1.5315 loss_a_val: 0.8929 time: 0.4077s
# disease8 Epoch: 0213 loss_train: 2.7803 loss_kl_train: 0.1604 loss_x_train: 1.3056 loss_a_train: 1.3144 loss_val: 2.4138 loss_x_val: 1.5213 loss_a_val: 0.8925 time: 0.4069s
# disease8 Epoch: 0214 loss_train: 2.7780 loss_kl_train: 0.1617 loss_x_train: 1.3056 loss_a_train: 1.3107 loss_val: 2.4089 loss_x_val: 1.5167 loss_a_val: 0.8922 time: 0.4083s
# disease8 Epoch: 0215 loss_train: 2.7594 loss_kl_train: 0.1630 loss_x_train: 1.3053 loss_a_train: 1.2911 loss_val: 2.4041 loss_x_val: 1.5123 loss_a_val: 0.8918 time: 0.4016s
# disease8 Epoch: 0216 loss_train: 2.7637 loss_kl_train: 0.1642 loss_x_train: 1.3051 loss_a_train: 1.2944 loss_val: 2.4009 loss_x_val: 1.5118 loss_a_val: 0.8891 time: 0.4053s
# disease8 Epoch: 0217 loss_train: 2.7658 loss_kl_train: 0.1654 loss_x_train: 1.3052 loss_a_train: 1.2952 loss_val: 2.3936 loss_x_val: 1.5000 loss_a_val: 0.8936 time: 0.4083s
# disease8 Epoch: 0218 loss_train: 2.7505 loss_kl_train: 0.1667 loss_x_train: 1.3055 loss_a_train: 1.2784 loss_val: 2.3839 loss_x_val: 1.4916 loss_a_val: 0.8923 time: 0.4036s
# disease8 Epoch: 0219 loss_train: 2.7426 loss_kl_train: 0.1678 loss_x_train: 1.3043 loss_a_train: 1.2705 loss_val: 2.3729 loss_x_val: 1.4803 loss_a_val: 0.8926 time: 0.4060s
# disease8 Epoch: 0220 loss_train: 2.7272 loss_kl_train: 0.1690 loss_x_train: 1.3036 loss_a_train: 1.2545 loss_val: 2.3643 loss_x_val: 1.4715 loss_a_val: 0.8928 time: 0.4052s
# disease8 Epoch: 0221 loss_train: 2.7249 loss_kl_train: 0.1703 loss_x_train: 1.3028 loss_a_train: 1.2518 loss_val: 2.3574 loss_x_val: 1.4647 loss_a_val: 0.8927 time: 0.4068s
# disease8 Epoch: 0222 loss_train: 2.7130 loss_kl_train: 0.1713 loss_x_train: 1.3028 loss_a_train: 1.2389 loss_val: 2.3545 loss_x_val: 1.4638 loss_a_val: 0.8907 time: 0.4085s
# disease8 Epoch: 0223 loss_train: 2.7003 loss_kl_train: 0.1726 loss_x_train: 1.3034 loss_a_train: 1.2244 loss_val: 2.3506 loss_x_val: 1.4605 loss_a_val: 0.8901 time: 0.4049s
# disease8 Epoch: 0224 loss_train: 2.6971 loss_kl_train: 0.1737 loss_x_train: 1.3032 loss_a_train: 1.2202 loss_val: 2.3452 loss_x_val: 1.4547 loss_a_val: 0.8905 time: 0.4049s
# disease8 Epoch: 0225 loss_train: 2.6891 loss_kl_train: 0.1749 loss_x_train: 1.3018 loss_a_train: 1.2124 loss_val: 2.3405 loss_x_val: 1.4515 loss_a_val: 0.8891 time: 0.4016s
# disease8 Epoch: 0226 loss_train: 2.6854 loss_kl_train: 0.1760 loss_x_train: 1.3016 loss_a_train: 1.2078 loss_val: 2.3387 loss_x_val: 1.4519 loss_a_val: 0.8868 time: 0.4021s
# disease8 Epoch: 0227 loss_train: 2.6776 loss_kl_train: 0.1771 loss_x_train: 1.3018 loss_a_train: 1.1987 loss_val: 2.3364 loss_x_val: 1.4509 loss_a_val: 0.8854 time: 0.4056s
# disease8 Epoch: 0228 loss_train: 2.6720 loss_kl_train: 0.1782 loss_x_train: 1.3021 loss_a_train: 1.1917 loss_val: 2.3262 loss_x_val: 1.4440 loss_a_val: 0.8822 time: 0.4030s
# disease8 Epoch: 0229 loss_train: 2.6627 loss_kl_train: 0.1793 loss_x_train: 1.3011 loss_a_train: 1.1822 loss_val: 2.3218 loss_x_val: 1.4373 loss_a_val: 0.8845 time: 0.4087s
# disease8 Epoch: 0230 loss_train: 2.6494 loss_kl_train: 0.1804 loss_x_train: 1.3010 loss_a_train: 1.1680 loss_val: 2.3136 loss_x_val: 1.4324 loss_a_val: 0.8812 time: 0.4027s
# disease8 Epoch: 0231 loss_train: 2.6382 loss_kl_train: 0.1816 loss_x_train: 1.3003 loss_a_train: 1.1563 loss_val: 2.3057 loss_x_val: 1.4279 loss_a_val: 0.8778 time: 0.4009s
# disease8 Epoch: 0232 loss_train: 2.6350 loss_kl_train: 0.1826 loss_x_train: 1.3006 loss_a_train: 1.1519 loss_val: 2.3003 loss_x_val: 1.4229 loss_a_val: 0.8774 time: 0.4035s
# disease8 Epoch: 0233 loss_train: 2.6272 loss_kl_train: 0.1837 loss_x_train: 1.3006 loss_a_train: 1.1429 loss_val: 2.2950 loss_x_val: 1.4185 loss_a_val: 0.8765 time: 0.4055s
# disease8 Epoch: 0234 loss_train: 2.6262 loss_kl_train: 0.1846 loss_x_train: 1.2998 loss_a_train: 1.1417 loss_val: 2.2916 loss_x_val: 1.4144 loss_a_val: 0.8772 time: 0.4055s
# disease8 Epoch: 0235 loss_train: 2.6110 loss_kl_train: 0.1857 loss_x_train: 1.2994 loss_a_train: 1.1260 loss_val: 2.2861 loss_x_val: 1.4111 loss_a_val: 0.8751 time: 0.4097s
# disease8 Epoch: 0236 loss_train: 2.6073 loss_kl_train: 0.1867 loss_x_train: 1.2993 loss_a_train: 1.1213 loss_val: 2.2792 loss_x_val: 1.4104 loss_a_val: 0.8688 time: 0.4008s
# disease8 Epoch: 0237 loss_train: 2.6028 loss_kl_train: 0.1877 loss_x_train: 1.2994 loss_a_train: 1.1157 loss_val: 2.2701 loss_x_val: 1.4078 loss_a_val: 0.8623 time: 0.4062s
# disease8 Epoch: 0238 loss_train: 2.6070 loss_kl_train: 0.1887 loss_x_train: 1.2990 loss_a_train: 1.1193 loss_val: 2.2782 loss_x_val: 1.4025 loss_a_val: 0.8757 time: 0.4064s
# disease8 Epoch: 0239 loss_train: 2.5854 loss_kl_train: 0.1896 loss_x_train: 1.2989 loss_a_train: 1.0969 loss_val: 2.2733 loss_x_val: 1.4008 loss_a_val: 0.8725 time: 0.4054s
# disease8 Epoch: 0240 loss_train: 2.5838 loss_kl_train: 0.1906 loss_x_train: 1.2987 loss_a_train: 1.0945 loss_val: 2.2687 loss_x_val: 1.4004 loss_a_val: 0.8683 time: 0.4054s
# disease8 Epoch: 0241 loss_train: 2.5779 loss_kl_train: 0.1915 loss_x_train: 1.2987 loss_a_train: 1.0877 loss_val: 2.2566 loss_x_val: 1.3995 loss_a_val: 0.8571 time: 0.4042s
# disease8 Epoch: 0242 loss_train: 2.5750 loss_kl_train: 0.1925 loss_x_train: 1.2977 loss_a_train: 1.0848 loss_val: 2.2627 loss_x_val: 1.3923 loss_a_val: 0.8704 time: 0.4024s
# disease8 Epoch: 0243 loss_train: 2.5635 loss_kl_train: 0.1934 loss_x_train: 1.2980 loss_a_train: 1.0721 loss_val: 2.2585 loss_x_val: 1.3890 loss_a_val: 0.8695 time: 0.4071s
# disease8 Epoch: 0244 loss_train: 2.5690 loss_kl_train: 0.1943 loss_x_train: 1.2976 loss_a_train: 1.0771 loss_val: 2.2522 loss_x_val: 1.3866 loss_a_val: 0.8656 time: 0.4058s
# disease8 Epoch: 0245 loss_train: 2.5608 loss_kl_train: 0.1951 loss_x_train: 1.2977 loss_a_train: 1.0680 loss_val: 2.2407 loss_x_val: 1.3844 loss_a_val: 0.8563 time: 0.4048s
# disease8 Epoch: 0246 loss_train: 2.5548 loss_kl_train: 0.1960 loss_x_train: 1.2971 loss_a_train: 1.0616 loss_val: 2.2401 loss_x_val: 1.3827 loss_a_val: 0.8574 time: 0.4011s
# disease8 Epoch: 0247 loss_train: 2.5500 loss_kl_train: 0.1969 loss_x_train: 1.2967 loss_a_train: 1.0564 loss_val: 2.2420 loss_x_val: 1.3795 loss_a_val: 0.8625 time: 0.4023s
# disease8 Epoch: 0248 loss_train: 2.5489 loss_kl_train: 0.1977 loss_x_train: 1.2969 loss_a_train: 1.0542 loss_val: 2.2378 loss_x_val: 1.3770 loss_a_val: 0.8607 time: 0.4056s
# disease8 Epoch: 0249 loss_train: 2.5390 loss_kl_train: 0.1986 loss_x_train: 1.2968 loss_a_train: 1.0436 loss_val: 2.2250 loss_x_val: 1.3741 loss_a_val: 0.8509 time: 0.4016s
# disease8 Epoch: 0250 loss_train: 2.5401 loss_kl_train: 0.1995 loss_x_train: 1.2962 loss_a_train: 1.0444 loss_val: 2.2391 loss_x_val: 1.3735 loss_a_val: 0.8656 time: 0.4073s
# disease8 Epoch: 0251 loss_train: 2.5336 loss_kl_train: 0.2003 loss_x_train: 1.2959 loss_a_train: 1.0374 loss_val: 2.2358 loss_x_val: 1.3720 loss_a_val: 0.8637 time: 0.4030s
# disease8 Epoch: 0252 loss_train: 2.5267 loss_kl_train: 0.2010 loss_x_train: 1.2960 loss_a_train: 1.0296 loss_val: 2.2328 loss_x_val: 1.3715 loss_a_val: 0.8614 time: 0.4058s
# disease8 Epoch: 0253 loss_train: 2.5203 loss_kl_train: 0.2019 loss_x_train: 1.2963 loss_a_train: 1.0222 loss_val: 2.2306 loss_x_val: 1.3725 loss_a_val: 0.8581 time: 0.4061s
# disease8 Epoch: 0254 loss_train: 2.5205 loss_kl_train: 0.2028 loss_x_train: 1.2953 loss_a_train: 1.0224 loss_val: 2.2301 loss_x_val: 1.3663 loss_a_val: 0.8638 time: 0.4058s
# disease8 Epoch: 0255 loss_train: 2.5154 loss_kl_train: 0.2035 loss_x_train: 1.2956 loss_a_train: 1.0164 loss_val: 2.2139 loss_x_val: 1.3644 loss_a_val: 0.8495 time: 0.4006s
# disease8 Epoch: 0256 loss_train: 2.5269 loss_kl_train: 0.2043 loss_x_train: 1.2957 loss_a_train: 1.0269 loss_val: 2.2258 loss_x_val: 1.3620 loss_a_val: 0.8639 time: 0.4034s
# disease8 Epoch: 0257 loss_train: 2.5182 loss_kl_train: 0.2049 loss_x_train: 1.2954 loss_a_train: 1.0179 loss_val: 2.2134 loss_x_val: 1.3608 loss_a_val: 0.8526 time: 0.4004s
# disease8 Epoch: 0258 loss_train: 2.5124 loss_kl_train: 0.2057 loss_x_train: 1.2951 loss_a_train: 1.0116 loss_val: 2.2109 loss_x_val: 1.3592 loss_a_val: 0.8517 time: 0.4032s
# disease8 Epoch: 0259 loss_train: 2.5051 loss_kl_train: 0.2064 loss_x_train: 1.2945 loss_a_train: 1.0041 loss_val: 2.2201 loss_x_val: 1.3564 loss_a_val: 0.8636 time: 0.4057s
# disease8 Epoch: 0260 loss_train: 2.5006 loss_kl_train: 0.2071 loss_x_train: 1.2946 loss_a_train: 0.9988 loss_val: 2.2181 loss_x_val: 1.3559 loss_a_val: 0.8621 time: 0.4011s
# disease8 Epoch: 0261 loss_train: 2.5023 loss_kl_train: 0.2078 loss_x_train: 1.2943 loss_a_train: 1.0002 loss_val: 2.2164 loss_x_val: 1.3537 loss_a_val: 0.8628 time: 0.4041s
# disease8 Epoch: 0262 loss_train: 2.4919 loss_kl_train: 0.2086 loss_x_train: 1.2943 loss_a_train: 0.9890 loss_val: 2.2157 loss_x_val: 1.3543 loss_a_val: 0.8614 time: 0.4065s
# disease8 Epoch: 0263 loss_train: 2.4941 loss_kl_train: 0.2093 loss_x_train: 1.2940 loss_a_train: 0.9908 loss_val: 2.2077 loss_x_val: 1.3513 loss_a_val: 0.8563 time: 0.4030s
# disease8 Epoch: 0264 loss_train: 2.4890 loss_kl_train: 0.2100 loss_x_train: 1.2934 loss_a_train: 0.9857 loss_val: 2.1980 loss_x_val: 1.3499 loss_a_val: 0.8481 time: 0.4066s
# disease8 Epoch: 0265 loss_train: 2.4887 loss_kl_train: 0.2107 loss_x_train: 1.2936 loss_a_train: 0.9844 loss_val: 2.2094 loss_x_val: 1.3494 loss_a_val: 0.8600 time: 0.4076s
# disease8 Epoch: 0266 loss_train: 2.4806 loss_kl_train: 0.2114 loss_x_train: 1.2935 loss_a_train: 0.9758 loss_val: 2.2093 loss_x_val: 1.3473 loss_a_val: 0.8620 time: 0.4023s
# disease8 Epoch: 0267 loss_train: 2.4819 loss_kl_train: 0.2120 loss_x_train: 1.2936 loss_a_train: 0.9762 loss_val: 2.2048 loss_x_val: 1.3473 loss_a_val: 0.8575 time: 0.4050s
# disease8 Epoch: 0268 loss_train: 2.4769 loss_kl_train: 0.2128 loss_x_train: 1.2930 loss_a_train: 0.9711 loss_val: 2.2063 loss_x_val: 1.3451 loss_a_val: 0.8612 time: 0.4023s
# disease8 Epoch: 0269 loss_train: 2.4720 loss_kl_train: 0.2134 loss_x_train: 1.2924 loss_a_train: 0.9662 loss_val: 2.2015 loss_x_val: 1.3420 loss_a_val: 0.8594 time: 0.4042s
# disease8 Epoch: 0270 loss_train: 2.4660 loss_kl_train: 0.2141 loss_x_train: 1.2928 loss_a_train: 0.9591 loss_val: 2.1960 loss_x_val: 1.3437 loss_a_val: 0.8523 time: 0.4032s
# disease8 Epoch: 0271 loss_train: 2.4730 loss_kl_train: 0.2148 loss_x_train: 1.2927 loss_a_train: 0.9655 loss_val: 2.1988 loss_x_val: 1.3404 loss_a_val: 0.8584 time: 0.3992s
# disease8 Epoch: 0272 loss_train: 2.4608 loss_kl_train: 0.2154 loss_x_train: 1.2932 loss_a_train: 0.9522 loss_val: 2.1953 loss_x_val: 1.3411 loss_a_val: 0.8542 time: 0.4015s
# disease8 Epoch: 0273 loss_train: 2.4645 loss_kl_train: 0.2160 loss_x_train: 1.2923 loss_a_train: 0.9562 loss_val: 2.1961 loss_x_val: 1.3372 loss_a_val: 0.8588 time: 0.4063s
# disease8 Epoch: 0274 loss_train: 2.4583 loss_kl_train: 0.2166 loss_x_train: 1.2916 loss_a_train: 0.9502 loss_val: 2.1933 loss_x_val: 1.3351 loss_a_val: 0.8582 time: 0.4077s
# ...
# control13 Epoch: 5444 loss_train: 1.9982 loss_kl_train: 0.2415 loss_x_train: 1.3130 loss_a_train: 0.4437 loss_val: 1.7029 loss_x_val: 1.3243 loss_a_val: 0.3786 time: 0.4459s
# control13 Epoch: 5445 loss_train: 1.9974 loss_kl_train: 0.2414 loss_x_train: 1.3129 loss_a_train: 0.4431 loss_val: 1.7035 loss_x_val: 1.3243 loss_a_val: 0.3791 time: 0.4492s
# control13 Epoch: 5446 loss_train: 1.9971 loss_kl_train: 0.2414 loss_x_train: 1.3130 loss_a_train: 0.4426 loss_val: 1.7033 loss_x_val: 1.3243 loss_a_val: 0.3790 time: 0.4475s
# control13 Epoch: 5447 loss_train: 1.9974 loss_kl_train: 0.2414 loss_x_train: 1.3130 loss_a_train: 0.4430 loss_val: 1.7026 loss_x_val: 1.3243 loss_a_val: 0.3782 time: 0.4476s
# control13 Epoch: 5448 loss_train: 1.9972 loss_kl_train: 0.2413 loss_x_train: 1.3129 loss_a_train: 0.4429 loss_val: 1.7019 loss_x_val: 1.3244 loss_a_val: 0.3775 time: 0.4485s
# control13 Epoch: 5449 loss_train: 1.9977 loss_kl_train: 0.2413 loss_x_train: 1.3129 loss_a_train: 0.4435 loss_val: 1.7016 loss_x_val: 1.3244 loss_a_val: 0.3772 time: 0.4456s
# control13 Epoch: 5450 loss_train: 1.9972 loss_kl_train: 0.2411 loss_x_train: 1.3129 loss_a_train: 0.4432 loss_val: 1.7023 loss_x_val: 1.3244 loss_a_val: 0.3779 time: 0.4505s
# control13 Epoch: 5451 loss_train: 1.9968 loss_kl_train: 0.2412 loss_x_train: 1.3129 loss_a_train: 0.4427 loss_val: 1.7030 loss_x_val: 1.3244 loss_a_val: 0.3787 time: 0.4467s
# control13 Epoch: 5452 loss_train: 1.9970 loss_kl_train: 0.2412 loss_x_train: 1.3129 loss_a_train: 0.4429 loss_val: 1.7029 loss_x_val: 1.3244 loss_a_val: 0.3785 time: 0.4480s
# control13 Epoch: 5453 loss_train: 1.9979 loss_kl_train: 0.2413 loss_x_train: 1.3129 loss_a_train: 0.4438 loss_val: 1.7020 loss_x_val: 1.3245 loss_a_val: 0.3776 time: 0.4502s
# control13 Epoch: 5454 loss_train: 1.9980 loss_kl_train: 0.2410 loss_x_train: 1.3128 loss_a_train: 0.4441 loss_val: 1.7014 loss_x_val: 1.3244 loss_a_val: 0.3770 time: 0.4483s
# control13 Epoch: 5455 loss_train: 1.9974 loss_kl_train: 0.2410 loss_x_train: 1.3129 loss_a_train: 0.4435 loss_val: 1.7014 loss_x_val: 1.3244 loss_a_val: 0.3770 time: 0.4482s
# control13 Epoch: 5456 loss_train: 1.9967 loss_kl_train: 0.2413 loss_x_train: 1.3128 loss_a_train: 0.4426 loss_val: 1.7016 loss_x_val: 1.3244 loss_a_val: 0.3772 time: 0.4476s
# control13 Epoch: 5457 loss_train: 1.9971 loss_kl_train: 0.2413 loss_x_train: 1.3128 loss_a_train: 0.4430 loss_val: 1.7017 loss_x_val: 1.3244 loss_a_val: 0.3772 time: 0.4494s
# control13 Epoch: 5458 loss_train: 1.9966 loss_kl_train: 0.2413 loss_x_train: 1.3128 loss_a_train: 0.4425 loss_val: 1.7017 loss_x_val: 1.3245 loss_a_val: 0.3772 time: 0.4465s
# control13 Epoch: 5459 loss_train: 1.9968 loss_kl_train: 0.2414 loss_x_train: 1.3128 loss_a_train: 0.4426 loss_val: 1.7021 loss_x_val: 1.3245 loss_a_val: 0.3776 time: 0.4475s
# control13 Epoch: 5460 loss_train: 1.9968 loss_kl_train: 0.2415 loss_x_train: 1.3128 loss_a_train: 0.4425 loss_val: 1.7023 loss_x_val: 1.3245 loss_a_val: 0.3779 time: 0.4461s
# control13 Epoch: 5461 loss_train: 1.9968 loss_kl_train: 0.2415 loss_x_train: 1.3128 loss_a_train: 0.4425 loss_val: 1.7024 loss_x_val: 1.3245 loss_a_val: 0.3780 time: 0.4463s
# control13 Epoch: 5462 loss_train: 1.9963 loss_kl_train: 0.2416 loss_x_train: 1.3128 loss_a_train: 0.4420 loss_val: 1.7019 loss_x_val: 1.3244 loss_a_val: 0.3774 time: 0.4454s
# control13 Epoch: 5463 loss_train: 1.9966 loss_kl_train: 0.2415 loss_x_train: 1.3127 loss_a_train: 0.4423 loss_val: 1.7012 loss_x_val: 1.3245 loss_a_val: 0.3768 time: 0.4449s
# control13 Epoch: 5464 loss_train: 1.9959 loss_kl_train: 0.2416 loss_x_train: 1.3127 loss_a_train: 0.4417 loss_val: 1.7013 loss_x_val: 1.3245 loss_a_val: 0.3768 time: 0.4473s
# control13 Epoch: 5465 loss_train: 1.9965 loss_kl_train: 0.2417 loss_x_train: 1.3127 loss_a_train: 0.4420 loss_val: 1.7014 loss_x_val: 1.3244 loss_a_val: 0.3769 time: 0.4473s
# control13 Epoch: 5466 loss_train: 1.9966 loss_kl_train: 0.2417 loss_x_train: 1.3127 loss_a_train: 0.4422 loss_val: 1.7016 loss_x_val: 1.3245 loss_a_val: 0.3771 time: 0.4473s
# control13 Epoch: 5467 loss_train: 1.9962 loss_kl_train: 0.2418 loss_x_train: 1.3127 loss_a_train: 0.4417 loss_val: 1.7018 loss_x_val: 1.3244 loss_a_val: 0.3774 time: 0.4477s
# control13 Epoch: 5468 loss_train: 1.9963 loss_kl_train: 0.2417 loss_x_train: 1.3127 loss_a_train: 0.4419 loss_val: 1.7019 loss_x_val: 1.3244 loss_a_val: 0.3774 time: 0.4463s
# control13 Epoch: 5469 loss_train: 1.9959 loss_kl_train: 0.2416 loss_x_train: 1.3127 loss_a_train: 0.4415 loss_val: 1.7015 loss_x_val: 1.3245 loss_a_val: 0.3770 time: 0.4498s
# control13 Epoch: 5470 loss_train: 1.9964 loss_kl_train: 0.2416 loss_x_train: 1.3127 loss_a_train: 0.4421 loss_val: 1.7014 loss_x_val: 1.3245 loss_a_val: 0.3769 time: 0.4489s
# control13 Epoch: 5471 loss_train: 1.9957 loss_kl_train: 0.2417 loss_x_train: 1.3127 loss_a_train: 0.4413 loss_val: 1.7014 loss_x_val: 1.3245 loss_a_val: 0.3769 time: 0.4458s
# control13 Epoch: 5472 loss_train: 1.9954 loss_kl_train: 0.2417 loss_x_train: 1.3127 loss_a_train: 0.4411 loss_val: 1.7016 loss_x_val: 1.3246 loss_a_val: 0.3770 time: 0.4482s
# control13 Epoch: 5473 loss_train: 1.9959 loss_kl_train: 0.2419 loss_x_train: 1.3126 loss_a_train: 0.4414 loss_val: 1.7018 loss_x_val: 1.3245 loss_a_val: 0.3773 time: 0.4485s
# control13 Epoch: 5474 loss_train: 1.9948 loss_kl_train: 0.2417 loss_x_train: 1.3126 loss_a_train: 0.4404 loss_val: 1.7023 loss_x_val: 1.3245 loss_a_val: 0.3778 time: 0.4473s
# control13 Epoch: 5475 loss_train: 1.9957 loss_kl_train: 0.2417 loss_x_train: 1.3126 loss_a_train: 0.4413 loss_val: 1.7020 loss_x_val: 1.3245 loss_a_val: 0.3775 time: 0.4486s
# control13 Epoch: 5476 loss_train: 1.9954 loss_kl_train: 0.2418 loss_x_train: 1.3127 loss_a_train: 0.4409 loss_val: 1.7012 loss_x_val: 1.3245 loss_a_val: 0.3767 time: 0.4481s
# control13 Epoch: 5477 loss_train: 1.9968 loss_kl_train: 0.2416 loss_x_train: 1.3126 loss_a_train: 0.4426 loss_val: 1.7007 loss_x_val: 1.3246 loss_a_val: 0.3762 time: 0.4453s
# control13 Epoch: 5478 loss_train: 1.9960 loss_kl_train: 0.2416 loss_x_train: 1.3126 loss_a_train: 0.4419 loss_val: 1.7009 loss_x_val: 1.3246 loss_a_val: 0.3764 time: 0.4463s
# control13 Epoch: 5479 loss_train: 1.9953 loss_kl_train: 0.2417 loss_x_train: 1.3126 loss_a_train: 0.4410 loss_val: 1.7011 loss_x_val: 1.3245 loss_a_val: 0.3766 time: 0.4475s
# control13 Epoch: 5480 loss_train: 1.9955 loss_kl_train: 0.2417 loss_x_train: 1.3126 loss_a_train: 0.4412 loss_val: 1.7015 loss_x_val: 1.3245 loss_a_val: 0.3770 time: 0.4446s
# control13 Epoch: 5481 loss_train: 1.9955 loss_kl_train: 0.2416 loss_x_train: 1.3126 loss_a_train: 0.4413 loss_val: 1.7016 loss_x_val: 1.3245 loss_a_val: 0.3770 time: 0.4454s
# control13 Epoch: 5482 loss_train: 1.9957 loss_kl_train: 0.2416 loss_x_train: 1.3125 loss_a_train: 0.4416 loss_val: 1.7014 loss_x_val: 1.3245 loss_a_val: 0.3768 time: 0.4481s
# control13 Epoch: 5483 loss_train: 1.9952 loss_kl_train: 0.2415 loss_x_train: 1.3126 loss_a_train: 0.4411 loss_val: 1.7016 loss_x_val: 1.3245 loss_a_val: 0.3771 time: 0.4471s
# control13 Epoch: 5484 loss_train: 1.9957 loss_kl_train: 0.2417 loss_x_train: 1.3126 loss_a_train: 0.4415 loss_val: 1.7018 loss_x_val: 1.3245 loss_a_val: 0.3773 time: 0.4500s
# control13 Epoch: 5485 loss_train: 1.9958 loss_kl_train: 0.2416 loss_x_train: 1.3126 loss_a_train: 0.4417 loss_val: 1.7011 loss_x_val: 1.3246 loss_a_val: 0.3765 time: 0.4477s
# control13 Epoch: 5486 loss_train: 1.9950 loss_kl_train: 0.2415 loss_x_train: 1.3125 loss_a_train: 0.4410 loss_val: 1.7006 loss_x_val: 1.3245 loss_a_val: 0.3761 time: 0.4486s
# control13 Epoch: 5487 loss_train: 1.9959 loss_kl_train: 0.2416 loss_x_train: 1.3125 loss_a_train: 0.4418 loss_val: 1.7007 loss_x_val: 1.3245 loss_a_val: 0.3762 time: 0.4466s
# control13 Epoch: 5488 loss_train: 1.9947 loss_kl_train: 0.2416 loss_x_train: 1.3125 loss_a_train: 0.4407 loss_val: 1.7010 loss_x_val: 1.3245 loss_a_val: 0.3765 time: 0.4478s
# control13 Epoch: 5489 loss_train: 1.9960 loss_kl_train: 0.2416 loss_x_train: 1.3125 loss_a_train: 0.4419 loss_val: 1.7015 loss_x_val: 1.3245 loss_a_val: 0.3770 time: 0.4486s
# control13 Epoch: 5490 loss_train: 1.9958 loss_kl_train: 0.2417 loss_x_train: 1.3125 loss_a_train: 0.4416 loss_val: 1.7013 loss_x_val: 1.3246 loss_a_val: 0.3767 time: 0.4477s
# control13 Epoch: 5491 loss_train: 1.9953 loss_kl_train: 0.2415 loss_x_train: 1.3125 loss_a_train: 0.4412 loss_val: 1.7010 loss_x_val: 1.3247 loss_a_val: 0.3764 time: 0.4463s
# control13 Epoch: 5492 loss_train: 1.9952 loss_kl_train: 0.2415 loss_x_train: 1.3125 loss_a_train: 0.4413 loss_val: 1.7010 loss_x_val: 1.3246 loss_a_val: 0.3764 time: 0.4450s
# control13 Epoch: 5493 loss_train: 1.9948 loss_kl_train: 0.2415 loss_x_train: 1.3125 loss_a_train: 0.4408 loss_val: 1.7012 loss_x_val: 1.3246 loss_a_val: 0.3766 time: 0.4480s
# control13 Epoch: 5494 loss_train: 1.9948 loss_kl_train: 0.2414 loss_x_train: 1.3125 loss_a_train: 0.4409 loss_val: 1.7013 loss_x_val: 1.3246 loss_a_val: 0.3767 time: 0.4502s
# control13 Epoch: 5495 loss_train: 1.9956 loss_kl_train: 0.2415 loss_x_train: 1.3125 loss_a_train: 0.4416 loss_val: 1.7012 loss_x_val: 1.3246 loss_a_val: 0.3767 time: 0.4453s
# control13 Epoch: 5496 loss_train: 1.9948 loss_kl_train: 0.2413 loss_x_train: 1.3125 loss_a_train: 0.4411 loss_val: 1.7012 loss_x_val: 1.3246 loss_a_val: 0.3766 time: 0.4485s
# control13 Epoch: 5497 loss_train: 1.9949 loss_kl_train: 0.2414 loss_x_train: 1.3124 loss_a_train: 0.4410 loss_val: 1.7012 loss_x_val: 1.3246 loss_a_val: 0.3766 time: 0.4484s
# control13 Epoch: 5498 loss_train: 1.9950 loss_kl_train: 0.2414 loss_x_train: 1.3124 loss_a_train: 0.4412 loss_val: 1.7014 loss_x_val: 1.3246 loss_a_val: 0.3768 time: 0.4506s
# control13 Epoch: 5499 loss_train: 1.9955 loss_kl_train: 0.2414 loss_x_train: 1.3125 loss_a_train: 0.4416 loss_val: 1.7011 loss_x_val: 1.3246 loss_a_val: 0.3765 time: 0.4493s
# disease13 Epoch: 5500 loss_train: 2.1547 loss_kl_train: 0.2171 loss_x_train: 1.4434 loss_a_train: 0.4942 loss_val: 1.8869 loss_x_val: 1.4573 loss_a_val: 0.4296 time: 0.6716s
# disease13 Epoch: 5501 loss_train: 2.1196 loss_kl_train: 0.2163 loss_x_train: 1.4439 loss_a_train: 0.4594 loss_val: 1.8779 loss_x_val: 1.4573 loss_a_val: 0.4206 time: 0.6764s
# disease13 Epoch: 5502 loss_train: 2.1136 loss_kl_train: 0.2155 loss_x_train: 1.4436 loss_a_train: 0.4545 loss_val: 1.8698 loss_x_val: 1.4571 loss_a_val: 0.4127 time: 0.6759s
# disease13 Epoch: 5503 loss_train: 2.1013 loss_kl_train: 0.2152 loss_x_train: 1.4434 loss_a_train: 0.4427 loss_val: 1.8715 loss_x_val: 1.4566 loss_a_val: 0.4149 time: 0.6809s
# disease13 Epoch: 5504 loss_train: 2.1009 loss_kl_train: 0.2146 loss_x_train: 1.4431 loss_a_train: 0.4433 loss_val: 1.8663 loss_x_val: 1.4564 loss_a_val: 0.4098 time: 0.6798s
# disease13 Epoch: 5505 loss_train: 2.1014 loss_kl_train: 0.2136 loss_x_train: 1.4427 loss_a_train: 0.4451 loss_val: 1.8624 loss_x_val: 1.4565 loss_a_val: 0.4059 time: 0.6797s
# disease13 Epoch: 5506 loss_train: 2.1032 loss_kl_train: 0.2125 loss_x_train: 1.4425 loss_a_train: 0.4482 loss_val: 1.8574 loss_x_val: 1.4563 loss_a_val: 0.4011 time: 0.6821s
# disease13 Epoch: 5507 loss_train: 2.0945 loss_kl_train: 0.2116 loss_x_train: 1.4424 loss_a_train: 0.4405 loss_val: 1.8595 loss_x_val: 1.4560 loss_a_val: 0.4035 time: 0.6832s
# disease13 Epoch: 5508 loss_train: 2.0943 loss_kl_train: 0.2107 loss_x_train: 1.4422 loss_a_train: 0.4414 loss_val: 1.8556 loss_x_val: 1.4560 loss_a_val: 0.3996 time: 0.6818s
# disease13 Epoch: 5509 loss_train: 2.0937 loss_kl_train: 0.2097 loss_x_train: 1.4420 loss_a_train: 0.4420 loss_val: 1.8527 loss_x_val: 1.4561 loss_a_val: 0.3966 time: 0.6856s
# disease13 Epoch: 5510 loss_train: 2.0924 loss_kl_train: 0.2086 loss_x_train: 1.4419 loss_a_train: 0.4419 loss_val: 1.8527 loss_x_val: 1.4559 loss_a_val: 0.3969 time: 0.6864s
# disease13 Epoch: 5511 loss_train: 2.0922 loss_kl_train: 0.2076 loss_x_train: 1.4417 loss_a_train: 0.4429 loss_val: 1.8541 loss_x_val: 1.4557 loss_a_val: 0.3983 time: 0.6796s
# disease13 Epoch: 5512 loss_train: 2.0903 loss_kl_train: 0.2066 loss_x_train: 1.4416 loss_a_train: 0.4421 loss_val: 1.8528 loss_x_val: 1.4556 loss_a_val: 0.3972 time: 0.6801s
# disease13 Epoch: 5513 loss_train: 2.0887 loss_kl_train: 0.2054 loss_x_train: 1.4416 loss_a_train: 0.4417 loss_val: 1.8499 loss_x_val: 1.4556 loss_a_val: 0.3944 time: 0.6808s
# disease13 Epoch: 5514 loss_train: 2.0879 loss_kl_train: 0.2042 loss_x_train: 1.4413 loss_a_train: 0.4424 loss_val: 1.8487 loss_x_val: 1.4556 loss_a_val: 0.3931 time: 0.6736s
# disease13 Epoch: 5515 loss_train: 2.0884 loss_kl_train: 0.2031 loss_x_train: 1.4413 loss_a_train: 0.4441 loss_val: 1.8494 loss_x_val: 1.4554 loss_a_val: 0.3940 time: 0.6788s
# disease13 Epoch: 5516 loss_train: 2.0857 loss_kl_train: 0.2022 loss_x_train: 1.4412 loss_a_train: 0.4422 loss_val: 1.8502 loss_x_val: 1.4554 loss_a_val: 0.3948 time: 0.6850s
# disease13 Epoch: 5517 loss_train: 2.0845 loss_kl_train: 0.2013 loss_x_train: 1.4411 loss_a_train: 0.4421 loss_val: 1.8486 loss_x_val: 1.4554 loss_a_val: 0.3932 time: 0.6849s
# disease13 Epoch: 5518 loss_train: 2.0839 loss_kl_train: 0.2006 loss_x_train: 1.4410 loss_a_train: 0.4423 loss_val: 1.8468 loss_x_val: 1.4554 loss_a_val: 0.3914 time: 0.6820s
# disease13 Epoch: 5519 loss_train: 2.0830 loss_kl_train: 0.1998 loss_x_train: 1.4409 loss_a_train: 0.4424 loss_val: 1.8458 loss_x_val: 1.4554 loss_a_val: 0.3904 time: 0.6830s
# disease13 Epoch: 5520 loss_train: 2.0827 loss_kl_train: 0.1992 loss_x_train: 1.4408 loss_a_train: 0.4427 loss_val: 1.8461 loss_x_val: 1.4554 loss_a_val: 0.3908 time: 0.6827s
# disease13 Epoch: 5521 loss_train: 2.0815 loss_kl_train: 0.1988 loss_x_train: 1.4408 loss_a_train: 0.4419 loss_val: 1.8451 loss_x_val: 1.4554 loss_a_val: 0.3897 time: 0.6749s
# disease13 Epoch: 5522 loss_train: 2.0807 loss_kl_train: 0.1984 loss_x_train: 1.4408 loss_a_train: 0.4416 loss_val: 1.8429 loss_x_val: 1.4554 loss_a_val: 0.3875 time: 0.6830s
# disease13 Epoch: 5523 loss_train: 2.0799 loss_kl_train: 0.1982 loss_x_train: 1.4407 loss_a_train: 0.4410 loss_val: 1.8417 loss_x_val: 1.4554 loss_a_val: 0.3863 time: 0.6893s
# disease13 Epoch: 5524 loss_train: 2.0796 loss_kl_train: 0.1980 loss_x_train: 1.4406 loss_a_train: 0.4410 loss_val: 1.8412 loss_x_val: 1.4554 loss_a_val: 0.3857 time: 0.6845s
# disease13 Epoch: 5525 loss_train: 2.0781 loss_kl_train: 0.1979 loss_x_train: 1.4406 loss_a_train: 0.4396 loss_val: 1.8425 loss_x_val: 1.4554 loss_a_val: 0.3871 time: 0.6835s
# disease13 Epoch: 5526 loss_train: 2.0779 loss_kl_train: 0.1979 loss_x_train: 1.4405 loss_a_train: 0.4395 loss_val: 1.8416 loss_x_val: 1.4553 loss_a_val: 0.3862 time: 0.6830s
# disease13 Epoch: 5527 loss_train: 2.0781 loss_kl_train: 0.1979 loss_x_train: 1.4405 loss_a_train: 0.4398 loss_val: 1.8400 loss_x_val: 1.4554 loss_a_val: 0.3846 time: 0.6804s
# disease13 Epoch: 5528 loss_train: 2.0765 loss_kl_train: 0.1980 loss_x_train: 1.4404 loss_a_train: 0.4381 loss_val: 1.8396 loss_x_val: 1.4554 loss_a_val: 0.3842 time: 0.6777s
# disease13 Epoch: 5529 loss_train: 2.0763 loss_kl_train: 0.1981 loss_x_train: 1.4404 loss_a_train: 0.4379 loss_val: 1.8404 loss_x_val: 1.4553 loss_a_val: 0.3850 time: 0.6798s
# disease13 Epoch: 5530 loss_train: 2.0757 loss_kl_train: 0.1984 loss_x_train: 1.4403 loss_a_train: 0.4370 loss_val: 1.8399 loss_x_val: 1.4554 loss_a_val: 0.3846 time: 0.6811s
# disease13 Epoch: 5531 loss_train: 2.0749 loss_kl_train: 0.1986 loss_x_train: 1.4403 loss_a_train: 0.4360 loss_val: 1.8381 loss_x_val: 1.4554 loss_a_val: 0.3827 time: 0.6782s
# disease13 Epoch: 5532 loss_train: 2.0756 loss_kl_train: 0.1988 loss_x_train: 1.4402 loss_a_train: 0.4366 loss_val: 1.8376 loss_x_val: 1.4554 loss_a_val: 0.3822 time: 0.6815s
# disease13 Epoch: 5533 loss_train: 2.0751 loss_kl_train: 0.1989 loss_x_train: 1.4402 loss_a_train: 0.4361 loss_val: 1.8382 loss_x_val: 1.4553 loss_a_val: 0.3829 time: 0.6805s
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
with open(os.path.join(logsavepath,'train_loss'), 'wb') as output:
    pickle.dump(train_loss_ep, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_loss_kl'), 'wb') as output:
    pickle.dump(train_loss_kl_ep, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_loss_x'), 'wb') as output:
    pickle.dump(train_loss_x_ep, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'train_loss_a'), 'wb') as output:
    pickle.dump(train_loss_a_ep, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'val_loss'), 'wb') as output:
    pickle.dump(val_loss_ep, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'val_loss_x'), 'wb') as output:
    pickle.dump(val_loss_x_ep, output, pickle.HIGHEST_PROTOCOL)
with open(os.path.join(logsavepath,'val_loss_a'), 'wb') as output:
    pickle.dump(val_loss_a_ep, output, pickle.HIGHEST_PROTOCOL)
# with open(os.path.join(logsavepath,'ct_unique'), 'wb') as output:
#     pickle.dump(ct_unique, output, pickle.HIGHEST_PROTOCOL)
    
model.cuda()
model.eval()
if adj_decodeName==None:
    # features_recon, z, mu, logvar=model(features)
    adj_recon,mu,logvar,z, features_recon = model(features, adj_norm)
else:
    adj_recon,mu,logvar,z, features_recon = model(features, adj_norm,adj_decode)
if clf:
        modelClf.eval()
        clfOut=modelClf(z)
if 'dca' in model_str:
    loss_x_test=loss_x(features_recon, features,test_nodes_idx,XreconWeight,ridgeL,features_raw)
else:
    loss_x_test=loss_x(features_recon, features,test_nodes_idx,XreconWeight,mse)
loss_a_test=loss_a(adj_recon, adj_label, pos_weight, norm,test_nodes_idx)
loss_test = loss_x_test+loss_a_test
if clf:
    loss_clf_test=loss_clf(clfOut[test_nodes_idx],ct_train[test_nodes_idx])
    loss_test=loss_test+clfweight*loss_clf_test
print('test results',
      'loss_test: {:.4f}'.format(loss_test.item()),
      'loss_x_test: {:.4f}'.format(loss_x_test.item()),
      'loss_a_test: {:.4f}'.format(loss_a_test.item()))
#      'loss_clf_test: {:.4f}'.format(loss_clf_test.item()),)
# Out:
# test results loss_test: 1.7068 loss_x_test: 1.3487 loss_a_test: 0.3580

# %%
plt.plot(np.arange(epochs),train_loss_ep)
plt.plot(np.arange(epochs),val_loss_ep)
plt.plot(np.arange(epochs),train_loss_x_ep)
plt.plot(np.arange(epochs),val_loss_x_ep)
plt.plot(np.arange(epochs),train_loss_a_ep)
plt.plot(np.arange(epochs),val_loss_a_ep)
plt.plot(np.arange(epochs),train_loss_kl_ep)
# plt.plot(np.arange(epochs),np.array(train_loss_clf_ep)*clfweight)
# plt.plot(np.arange(epochs),np.array(val_loss_clf_ep)*clfweight)
# plt.ylim((0,5))
# plt.xlim((0,1000))
# plt.legend(['training loss','validation loss','training x recon loss','validation x recon loss','training kl loss'],loc='upper right')
plt.legend(['training loss','validation loss','training x recon loss','validation x recon loss','training a recon loss','validation a recon loss','training kl loss','training classifier loss','validation classifier loss'],loc='upper right')
plt.savefig(os.path.join(plotsavepath,'loss_seed3.jpg'))
plt.show()

# %%
# name='c13k20XA_07_dca'
# logsavepath='/mnt/xinyi/pamrats/log/train_gae_starmap/'+name
# with open(os.path.join(logsavepath,'val_loss_a'), 'rb') as output:
#     val_loss_a_ep=pickle.load(output)
# np.argmin(loss[:3280])
np.argmin(val_loss_x_ep[:])
# val_loss_a_ep[1040]
# Out:
# 8611

# %%
testepoch=5590
model.load_state_dict(torch.load(os.path.join(modelsavepath,str(testepoch)+'.pt')))
model.eval()
for s in sampleidx.keys():
    print(s)
    
    adj_norm=adjnormlist[s]
    adj_label=adj_list[s]
    features=featureslist[s+'X_'+training_sample_X]
    pos_weight=pos_weightlist[s]
    norm=normlist[s]
    if 'dca' in model_str:
        features_raw=features_raw_list[s+'X_raw']
    num_nodes,num_features = features.shape
    maskpath=os.path.join(savedir,'trainMask',s+'_'+maskedgeName+'_seed'+str(seed)+'.pkl')
    if useSavedMaskedEdges and os.path.exists(maskpath):
#         print('opening saved')
        with open(maskpath, 'rb') as input:
            maskedgeres = pickle.load(input)
    else:
        # construct training, validation, and test sets
        maskedgeres= preprocessing.mask_nodes_edges(features.shape[0],testNodeSize=testNodes,valNodeSize=valNodes)
        with open(maskpath, 'wb') as output:
            pickle.dump(maskedgeres, output, pickle.HIGHEST_PROTOCOL)
    train_nodes_idx,val_nodes_idx,test_nodes_idx = maskedgeres
    
    if s in training_samples:
        test_nodes_idx_s=test_nodes_idx
    else:
        test_nodes_idx_s=torch.tensor(np.arange(num_nodes))
        
#     adj_decode=None
#     if adj_decodeName == 'gala':
#         adj_decode=preprocessing.preprocess_graph_sharp(adj)

    if adj_decodeName==None:
        adj_recon,mu,logvar,z, features_recon = model(features, adj_norm)
    else:
        adj_decode=adj_decode.cuda()
        adj_recon,mu,logvar,z, features_recon = model(features, adj_norm,adj_decode)
    if 'dca' in model_str:
        loss_x_test=loss_x(features_recon, features,test_nodes_idx_s,XreconWeight,ridgeL,features_raw)
    else:
        loss_x_test=loss_x(features_recon, features,test_nodes_idx_s,XreconWeight,mse)
    loss_a_test=loss_a(adj_recon, adj_label, pos_weight, norm,test_nodes_idx_s)
    loss_test = loss_x_test+loss_a_test
    
    if 'dca' in model_str:
        features_raw=features_raw.cpu()
    print('test results',
          'loss_test: {:.4f}'.format(loss_test.item()),
          'loss_x_test: {:.4f}'.format(loss_x_test.item()),
          'loss_a_test: {:.4f}'.format(loss_a_test.item()))
# Out:
# disease13
# test results loss_test: 1.8199 loss_x_test: 1.4420 loss_a_test: 0.3779
# control13
# test results loss_test: 1.8469 loss_x_test: 1.3507 loss_a_test: 0.4961
# disease8
# test results loss_test: 1.7678 loss_x_test: 1.2722 loss_a_test: 0.4956
# control8
# test results loss_test: 1.9536 loss_x_test: 1.3934 loss_a_test: 0.5602

# %%
y_true=features
y_true_raw=features_raw
preds=features_recon
mask=nodesmask=torch.tensor(np.arange(num_nodes))
reconWeight=20
eps = 1e-10

output,pi,theta,y_pred=preds
nb_case=optimizer.optimizer_nb(preds,y_true,mask,reconWeight,eps = 1e-10,ifmean=False)- torch.log(pi+eps)

zero_nb = torch.pow(theta/(theta+y_pred+eps), theta)
zero_case = -torch.log(pi + ((1.0-pi)*zero_nb)+eps)
result = torch.where(torch.lt(y_true_raw.cuda(), 1), zero_case, nb_case)

# %%
result[:8,:8]
# Out:
# tensor([[-0.0000e+00, 2.1077e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00,
#          -0.0000e+00, -0.0000e+00],
#         [-0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00,
#          -0.0000e+00, -0.0000e+00],
#         [1.1921e-07, -0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00,
#          1.1921e-07, -0.0000e+00],
#         [1.7968e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00, 1.7740e+00,
#          1.1915e+00, -0.0000e+00],
#         [-0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00,
#          1.1921e-07, -0.0000e+00],
#         [1.1921e-07, 1.1921e-07, 1.1921e-07, -0.0000e+00, 1.1921e-07, 1.1921e-07,
#          1.1921e-07, 1.1921e-07],
#         [-0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00,
#          -0.0000e+00, -0.0000e+00],
#         [-0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00, -0.0000e+00,
#          1.4272e+00, -0.0000e+00]], device='cuda:0', grad_fn=<SliceBackward>)

# %%
features[:8,:8]
# Out:
# tensor([[-0.2504,  8.5853, -0.1941, -0.1474, -0.1934, -0.2717, -0.5645, -0.3465],
#         [-0.2504, -0.1938, -0.1941, -0.1474, -0.1934, -0.2717, -0.5645, -0.3465],
#         [-0.2504, -0.1938, -0.1941, -0.1474, -0.1934, -0.2717, -0.5645, -0.3465],
#         [ 5.5540, -0.1938, -0.1941, -0.1474, -0.1934,  3.1612,  1.2601, -0.3465],
#         [-0.2504, -0.1938, -0.1941, -0.1474, -0.1934, -0.2717, -0.5645, -0.3465],
#         [-0.2504, -0.1938, -0.1941, -0.1474, -0.1934, -0.2717, -0.5645, -0.3465],
#         [-0.2504, -0.1938, -0.1941, -0.1474, -0.1934, -0.2717, -0.5645, -0.3465],
#         [-0.2504, -0.1938, -0.1941, -0.1474, -0.1934, -0.2717,  2.5718, -0.3465]],
#        device='cuda:0')

# %%
zeroidx=(features_raw==0)
nonzeroidx=(features_raw!=0)
torch.sum(result[zeroidx])/torch.sum(result)
# Out:
# tensor(2.8589e-09, device='cuda:0', grad_fn=<DivBackward0>)

# %%
torch.sum(result[zeroidx])
# Out:
# tensor(0., device='cuda:0', grad_fn=<SumBackward0>)

# %%
# model.pi.weight[:8,:8]
model_str
# Out:
# 'gcn_vae_xa_e2_d1_dca'
